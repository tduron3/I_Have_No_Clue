# %%
# Set Dependencies

import csv
import pandas as pd
import numpy as np
import requests
import json
import urllib
import IPython
import lib

# %%
# Output File CSV

output_data_file = "output.proj1.csv"

# %%
# Name CSV Files

df = pd.read_csv(r'C:\users\tony duron\Project1-TD\Resources\1976-2020-president.csv')
df.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4  1976  ALABAMA       AL           1         63        41  US PRESIDENT
#
#                  candidate              party_detailed writein  \
# 0            CARTER, JIMMY                    DEMOCRAT   False
# 1             FORD, GERALD                  REPUBLICAN   False
# 2           MADDOX, LESTER  AMERICAN INDEPENDENT PARTY   False
# 3  BUBAR, BENJAMIN ""BEN""                 PROHIBITION   False
# 4                HALL, GUS         COMMUNIST PARTY USE   False
#
#    candidatevotes  totalvotes   version  notes party_simplified
# 0          659170     1182850  20210113    NaN         DEMOCRAT
# 1          504070     1182850  20210113    NaN       REPUBLICAN
# 2            9198     1182850  20210113    NaN            OTHER
# 3            6669     1182850  20210113    NaN            OTHER
# 4            1954     1182850  20210113    NaN            OTHER

# %%
#Retrieve Data of Cases and Deaths Per State

url = "https://data.cdc.gov/resource/9mfq-cb36.json"

# query_url2 = f"{url}"

# print(query_url)
print(url)

# vacc_response = requests.get(query_url2)
st_case_death_json = requests.get(url).json()

st_case_death_json
# Out:
# https://data.cdc.gov/resource/9mfq-cb36.json
# [{'submission_date': '2020-05-04T00:00:00.000',
#   'state': 'KY',
#   'tot_cases': '5245',
#   'conf_cases': '5245.0',
#   'prob_cases': '0',
#   'new_case': '115.0',
#   'pnew_case': '0',
#   'tot_death': '261',
#   'conf_death': '261.0',
#   'prob_death': '0',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-05T17:25:08.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-23T00:00:00.000',
#   'state': 'NH',
#   'tot_cases': '101',
#   'new_case': '23.0',
#   'tot_death': '1',
#   'new_death': '1.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-12-08T00:00:00.000',
#   'state': 'OK',
#   'tot_cases': '205999',
#   'conf_cases': '171497.0',
#   'prob_cases': '34502',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '1752',
#   'conf_death': '1680.0',
#   'prob_death': '72',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-09T14:45:40.234',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-28T00:00:00.000',
#   'state': 'RI',
#   'tot_cases': '31944',
#   'new_case': '499.0',
#   'pnew_case': '0',
#   'tot_death': '1192',
#   'new_death': '4.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-29T14:11:33.577',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-04-09T00:00:00.000',
#   'state': 'MT',
#   'tot_cases': '365',
#   'new_case': '13.0',
#   'tot_death': '6',
#   'new_death': '0.0',
#   'created_at': '2020-04-08T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-30T00:00:00.000',
#   'state': 'IA',
#   'tot_cases': '7145',
#   'new_case': '302.0',
#   'pnew_case': '0',
#   'tot_death': '162',
#   'new_death': '14.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-01T21:00:19.025',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-26T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-12T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '29',
#   'new_case': '6.0',
#   'tot_death': '1',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-21T00:00:00.000',
#   'state': 'MP',
#   'tot_cases': '69',
#   'conf_cases': '69.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '2',
#   'conf_death': '2.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-22T13:51:57.795',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-25T00:00:00.000',
#   'state': 'NE',
#   'tot_cases': '18346',
#   'new_case': '125.0',
#   'pnew_case': '0',
#   'tot_death': '260',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-26T19:18:27.809',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-24T00:00:00.000',
#   'state': 'CA',
#   'tot_cases': '10',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-06-28T00:00:00.000',
#   'state': 'PA',
#   'tot_cases': '85988',
#   'conf_cases': '83529.0',
#   'prob_cases': '2459',
#   'new_case': '492.0',
#   'pnew_case': '13',
#   'tot_death': '6614',
#   'new_death': '8.0',
#   'pnew_death': '4',
#   'created_at': '2020-06-29T14:37:31.240',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-05-04T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '1224',
#   'conf_cases': '1224.0',
#   'prob_cases': '0',
#   'new_case': '29.0',
#   'pnew_case': '0',
#   'tot_death': '50',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-05T17:25:08.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-01T00:00:00.000',
#   'state': 'FSM',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-02T15:10:03.527',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-02T00:00:00.000',
#   'state': 'NY',
#   'tot_cases': '346492',
#   'new_case': '5775.0',
#   'pnew_case': '0',
#   'tot_death': '10117',
#   'new_death': '56.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-03T15:21:08.669',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-01-23T00:00:00.000',
#   'state': 'WY',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-05T00:00:00.000',
#   'state': 'GA',
#   'tot_cases': '28196',
#   'conf_cases': '28182.0',
#   'prob_cases': '14',
#   'new_case': '602.0',
#   'pnew_case': '1',
#   'tot_death': '1258',
#   'conf_death': '1258.0',
#   'prob_death': '0',
#   'new_death': '47.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-06T12:23:08.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-24T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '611039',
#   'new_case': '2520.0',
#   'pnew_case': '0',
#   'tot_death': '9716',
#   'conf_death': '9340.0',
#   'prob_death': '376',
#   'new_death': '23.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-25T14:42:40.885',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-13T00:00:00.000',
#   'state': 'AR',
#   'tot_cases': '1410',
#   'new_case': '103.0',
#   'tot_death': '30',
#   'new_death': '1.0',
#   'created_at': '2020-04-12T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-01-24T00:00:00.000',
#   'state': 'NH',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-06-21T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '6937',
#   'conf_cases': '6700.0',
#   'prob_cases': '237',
#   'new_case': '187.0',
#   'pnew_case': '237',
#   'tot_death': '190',
#   'conf_death': '188.0',
#   'prob_death': '2',
#   'new_death': '1.0',
#   'pnew_death': '2',
#   'created_at': '2020-06-22T15:24:02.542',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-26T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-27T13:39:49.124'},
#  {'submission_date': '2020-05-16T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-17T15:27:46.000'},
#  {'submission_date': '2020-03-13T00:00:00.000',
#   'state': 'MS',
#   'tot_cases': '1',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-08T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-09T13:47:50.836'},
#  {'submission_date': '2020-05-26T00:00:00.000',
#   'state': 'MA',
#   'tot_cases': '93693',
#   'conf_cases': '93693.0',
#   'prob_cases': '0',
#   'new_case': '422.0',
#   'pnew_case': '0',
#   'tot_death': '6473',
#   'conf_death': '6473.0',
#   'prob_death': '0',
#   'new_death': '57.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-27T15:37:59.621',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-19T00:00:00.000',
#   'state': 'MA',
#   'tot_cases': '151370',
#   'conf_cases': '141474.0',
#   'prob_cases': '9896',
#   'new_case': '827.0',
#   'pnew_case': '0',
#   'tot_death': '9740',
#   'conf_death': '9532.0',
#   'prob_death': '208',
#   'new_death': '15.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-20T14:59:27.967',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-27T00:00:00.000',
#   'state': 'NYC',
#   'tot_cases': '592471',
#   'conf_cases': '508530.0',
#   'prob_cases': '83941',
#   'new_case': '6182.0',
#   'pnew_case': '1473',
#   'tot_death': '26858',
#   'conf_death': '21887.0',
#   'prob_death': '4971',
#   'new_death': '93.0',
#   'pnew_death': '26',
#   'created_at': '2021-01-28T14:49:07.741',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-14T00:00:00.000',
#   'state': 'OK',
#   'tot_cases': '20922',
#   'conf_cases': '20755.0',
#   'prob_cases': '167',
#   'new_case': '521.0',
#   'pnew_case': '11',
#   'tot_death': '424',
#   'conf_death': '424.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-15T15:05:12.266',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-18T00:00:00.000',
#   'state': 'IL',
#   'tot_cases': '1072214',
#   'conf_cases': '1072214.0',
#   'prob_cases': '0',
#   'new_case': '3385.0',
#   'pnew_case': '0',
#   'tot_death': '20118',
#   'conf_death': '18258.0',
#   'prob_death': '1860',
#   'new_death': '68.0',
#   'pnew_death': '18',
#   'created_at': '2021-01-19T14:37:00.036',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-07T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-08T14:55:08.000'},
#  {'submission_date': '2020-04-13T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '1584',
#   'new_case': '57.0',
#   'tot_death': '53',
#   'new_death': '1.0',
#   'created_at': '2020-04-12T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-14T00:00:00.000',
#   'state': 'VA',
#   'tot_cases': '28672',
#   'conf_cases': '27293.0',
#   'prob_cases': '1379',
#   'new_case': '859.0',
#   'pnew_case': '35',
#   'tot_death': '977',
#   'conf_death': '944.0',
#   'prob_death': '33',
#   'new_death': '22.0',
#   'pnew_death': '5',
#   'created_at': '2020-05-15T16:11:22.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-09T00:00:00.000',
#   'state': 'AR',
#   'tot_cases': '251746',
#   'new_case': '2886.0',
#   'pnew_case': '735',
#   'tot_death': '4010',
#   'new_death': '44.0',
#   'pnew_death': '10',
#   'created_at': '2021-01-10T16:10:55.461',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-03-15T00:00:00.000',
#   'state': 'MA',
#   'tot_cases': '164',
#   'new_case': '55.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-28T00:00:00.000',
#   'state': 'IL',
#   'tot_cases': '115833',
#   'conf_cases': '115833.0',
#   'prob_cases': '0',
#   'new_case': '1527.0',
#   'pnew_case': '0',
#   'tot_death': '5186',
#   'conf_death': '5186.0',
#   'prob_death': '0',
#   'new_death': '103.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-29T14:19:55.781',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-05T00:00:00.000',
#   'state': 'WY',
#   'tot_cases': '2923',
#   'conf_cases': '2424.0',
#   'prob_cases': '499',
#   'new_case': '39.0',
#   'pnew_case': '7',
#   'tot_death': '27',
#   'conf_death': '27.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-06T14:12:27.571',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-28T00:00:00.000',
#   'state': 'ID',
#   'tot_cases': '61785',
#   'conf_cases': '54193.0',
#   'prob_cases': '7592',
#   'new_case': '862.0',
#   'pnew_case': '208',
#   'tot_death': '599',
#   'conf_death': '555.0',
#   'prob_death': '44',
#   'new_death': '14.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-29T14:11:33.577',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-31T00:00:00.000',
#   'state': 'DC',
#   'tot_cases': '8801',
#   'new_case': '84.0',
#   'pnew_case': '0',
#   'tot_death': '466',
#   'new_death': '4.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-01T14:17:42.906'},
#  {'submission_date': '2020-05-21T00:00:00.000',
#   'state': 'CO',
#   'tot_cases': '23121',
#   'conf_cases': '20903.0',
#   'prob_cases': '2218',
#   'new_case': '369.0',
#   'pnew_case': '61',
#   'tot_death': '1309',
#   'conf_death': '1036.0',
#   'prob_death': '273',
#   'new_death': '10.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-22T15:31:45.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-17T00:00:00.000',
#   'state': 'GA',
#   'tot_cases': '430571',
#   'conf_cases': '391466.0',
#   'prob_cases': '39105',
#   'new_case': '4335.0',
#   'pnew_case': '799',
#   'tot_death': '9008',
#   'conf_death': '8496.0',
#   'prob_death': '512',
#   'new_death': '41.0',
#   'pnew_death': '16',
#   'created_at': '2020-11-18T14:57:46.366',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-09T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-07T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '53976',
#   'new_case': '1337.0',
#   'pnew_case': '242',
#   'tot_death': '523',
#   'conf_death': '486.0',
#   'prob_death': '37',
#   'new_death': '13.0',
#   'pnew_death': '3',
#   'created_at': '2020-11-08T14:40:34.096',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-09T00:00:00.000',
#   'state': 'TX',
#   'tot_cases': '1038964',
#   'new_case': '4849.0',
#   'pnew_case': '-1936',
#   'tot_death': '18769',
#   'new_death': '26.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-22T22:17:06.352',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-10-14T00:00:00.000',
#   'state': 'DE',
#   'tot_cases': '22465',
#   'conf_cases': '21380.0',
#   'prob_cases': '1085',
#   'new_case': '71.0',
#   'pnew_case': '2',
#   'tot_death': '660',
#   'conf_death': '580.0',
#   'prob_death': '80',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-15T13:30:46.649',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-22T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '3864',
#   'conf_cases': '3770.0',
#   'prob_cases': '94',
#   'new_case': '47.0',
#   'pnew_case': '2',
#   'tot_death': '147',
#   'conf_death': '147.0',
#   'prob_death': '0',
#   'new_death': '2.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-23T17:58:16.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-08T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-23T00:00:00.000',
#   'state': 'NC',
#   'tot_cases': '22726',
#   'conf_cases': '22725.0',
#   'prob_cases': '1',
#   'new_case': '1107.0',
#   'pnew_case': '0',
#   'tot_death': '737',
#   'conf_death': '737.0',
#   'prob_death': '0',
#   'new_death': '9.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-13T19:10:12.893',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-28T00:00:00.000',
#   'state': 'SC',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-14T00:00:00.000',
#   'state': 'RI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-04-21T00:00:00.000',
#   'state': 'CO',
#   'tot_cases': '10368',
#   'conf_cases': '9536.0',
#   'prob_cases': '832',
#   'new_case': '349.0',
#   'pnew_case': '73',
#   'tot_death': '485',
#   'conf_death': '471.0',
#   'prob_death': '14',
#   'new_death': '37.0',
#   'pnew_death': '1',
#   'created_at': '2020-04-21T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-23T00:00:00.000',
#   'state': 'ME',
#   'tot_cases': '109',
#   'new_case': '16.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-19T00:00:00.000',
#   'state': 'TX',
#   'tot_cases': '1573888',
#   'new_case': '17907.0',
#   'pnew_case': '4102',
#   'tot_death': '25226',
#   'new_death': '272.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-22T22:17:06.352',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-05-01T00:00:00.000',
#   'state': 'MO',
#   'tot_cases': '7835',
#   'new_case': '273.0',
#   'pnew_case': '0',
#   'tot_death': '337',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-02T15:47:19.352',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-09-13T00:00:00.000',
#   'state': 'MS',
#   'tot_cases': '90018',
#   'conf_cases': '84557.0',
#   'prob_cases': '5461',
#   'new_case': '144.0',
#   'pnew_case': '38',
#   'tot_death': '2706',
#   'conf_death': '2523.0',
#   'prob_death': '183',
#   'new_death': '9.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-14T14:01:21.851',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-19T00:00:00.000',
#   'state': 'VT',
#   'tot_cases': '812',
#   'new_case': '9.0',
#   'pnew_case': '0',
#   'tot_death': '38',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-04-19T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-02-07T00:00:00.000',
#   'state': 'RMI',
#   'tot_cases': '4',
#   'conf_cases': '4.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-02-08T14:53:12.094',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-06T00:00:00.000',
#   'state': 'MT',
#   'tot_cases': '15723',
#   'conf_cases': '15723.0',
#   'prob_cases': '0',
#   'new_case': '425.0',
#   'pnew_case': '0',
#   'tot_death': '192',
#   'conf_death': '192.0',
#   'prob_death': '0',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-07T13:45:01.309',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-03T00:00:00.000',
#   'state': 'NY',
#   'tot_cases': '248091',
#   'new_case': '1519.0',
#   'pnew_case': '0',
#   'tot_death': '9290',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-04T15:03:00.406',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-14T00:00:00.000',
#   'state': 'MS',
#   'tot_cases': '37542',
#   'conf_cases': '37198.0',
#   'prob_cases': '344',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '1272',
#   'conf_death': '1249.0',
#   'prob_death': '23',
#   'new_death': '-1.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-15T15:05:12.266',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-21T00:00:00.000',
#   'state': 'ND',
#   'tot_cases': '9736',
#   'conf_cases': '9736.0',
#   'prob_cases': '0',
#   'new_case': '262.0',
#   'pnew_case': '0',
#   'tot_death': '135',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-22T14:21:09.869',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-10-06T00:00:00.000',
#   'state': 'ID',
#   'tot_cases': '45082',
#   'conf_cases': '40685.0',
#   'prob_cases': '4397',
#   'new_case': '660.0',
#   'pnew_case': '106',
#   'tot_death': '492',
#   'conf_death': '452.0',
#   'prob_death': '40',
#   'new_death': '5.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-07T13:45:01.309',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-20T00:00:00.000',
#   'state': 'LA',
#   'tot_cases': '140821',
#   'new_case': '918.0',
#   'pnew_case': '0',
#   'tot_death': '4637',
#   'conf_death': '4496.0',
#   'prob_death': '141',
#   'new_death': '28.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-21T14:27:34.675',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-27T00:00:00.000',
#   'state': 'WI',
#   'tot_cases': '16462',
#   'conf_cases': '16462.0',
#   'prob_cases': '0',
#   'new_case': '599.0',
#   'pnew_case': '0',
#   'tot_death': '539',
#   'conf_death': '539.0',
#   'prob_death': '0',
#   'new_death': '22.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-28T15:12:25.989',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-12T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '3',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-13T14:44:58.633'},
#  {'submission_date': '2020-03-17T00:00:00.000',
#   'state': 'NM',
#   'tot_cases': '23',
#   'new_case': '2.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-08-31T00:00:00.000',
#   'state': 'KS',
#   'tot_cases': '42612',
#   'conf_cases': '41425.0',
#   'prob_cases': '1187',
#   'new_case': '1564.0',
#   'pnew_case': '0',
#   'tot_death': '446',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-01T14:09:34.811',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-03-11T00:00:00.000',
#   'state': 'NY',
#   'tot_cases': '164',
#   'new_case': '27.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-28T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-29T00:00:00.000',
#   'state': 'TX',
#   'tot_cases': '1715978',
#   'new_case': '32552.0',
#   'pnew_case': '4532',
#   'tot_death': '26762',
#   'new_death': '241.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-30T14:56:20.759',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-11-17T00:00:00.000',
#   'state': 'OK',
#   'tot_cases': '169762',
#   'conf_cases': '143221.0',
#   'prob_cases': '26541',
#   'new_case': '7389.0',
#   'pnew_case': '1406',
#   'tot_death': '1592',
#   'conf_death': '1531.0',
#   'prob_death': '61',
#   'new_death': '49.0',
#   'pnew_death': '6',
#   'created_at': '2020-11-18T14:57:46.366',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-16T00:00:00.000',
#   'state': 'AZ',
#   'tot_cases': '18',
#   'new_case': '5.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-15T00:00:00.000',
#   'state': 'CT',
#   'tot_cases': '223422',
#   'conf_cases': '210193.0',
#   'prob_cases': '13229',
#   'new_case': '1878.0',
#   'pnew_case': '174',
#   'tot_death': '6594',
#   'conf_death': '5355.0',
#   'prob_death': '1239',
#   'new_death': '41.0',
#   'pnew_death': '5',
#   'created_at': '2021-01-16T14:46:10.803',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-28T00:00:00.000',
#   'state': 'WI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-08T00:00:00.000',
#   'state': 'WI',
#   'tot_cases': '281910',
#   'conf_cases': '267410.0',
#   'prob_cases': '14500',
#   'new_case': '4407.0',
#   'pnew_case': '127',
#   'tot_death': '2392',
#   'conf_death': '2312.0',
#   'prob_death': '80',
#   'new_death': '11.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-09T14:38:54.660',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-24T00:00:00.000',
#   'state': 'ND',
#   'tot_cases': '91222',
#   'conf_cases': '88587.0',
#   'prob_cases': '2635',
#   'new_case': '274.0',
#   'pnew_case': '4',
#   'tot_death': '1264',
#   'new_death': '4.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-25T14:25:34.696',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-11-03T00:00:00.000',
#   'state': 'MP',
#   'tot_cases': '96',
#   'conf_cases': '96.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '2',
#   'conf_death': '2.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-04T15:03:00.406',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-22T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '65044',
#   'conf_cases': '65044.0',
#   'prob_cases': '0',
#   'new_case': '650.0',
#   'pnew_case': '0',
#   'tot_death': '443',
#   'conf_death': '443.0',
#   'prob_death': '0',
#   'new_death': '3.0',
#   'pnew_death': '-1',
#   'created_at': '2020-09-23T13:51:22.296',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-08T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '129677',
#   'new_case': '1450.0',
#   'pnew_case': '0',
#   'tot_death': '3742',
#   'conf_death': '3515.0',
#   'prob_death': '227',
#   'new_death': '15.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-09T13:43:36.023',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-05T00:00:00.000',
#   'state': 'NYC',
#   'tot_cases': '462668',
#   'conf_cases': '405805.0',
#   'prob_cases': '56863',
#   'new_case': '5299.0',
#   'pnew_case': '1171',
#   'tot_death': '25363',
#   'conf_death': '20521.0',
#   'prob_death': '4842',
#   'new_death': '54.0',
#   'pnew_death': '16',
#   'created_at': '2021-01-06T14:58:26.308',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-23T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '644822',
#   'conf_cases': '583118.0',
#   'prob_cases': '61704',
#   'new_case': '7790.0',
#   'pnew_case': '1474',
#   'tot_death': '8361',
#   'conf_death': '7613.0',
#   'prob_death': '748',
#   'new_death': '109.0',
#   'pnew_death': '26',
#   'created_at': '2020-12-24T14:31:20.111',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-09T00:00:00.000',
#   'state': 'RI',
#   'tot_cases': '97614',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '1916',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-10T16:10:55.461',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-10-22T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '21057',
#   'conf_cases': '19907.0',
#   'prob_cases': '1150',
#   'new_case': '323.0',
#   'pnew_case': '80',
#   'tot_death': '418',
#   'new_death': '5.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-23T13:44:31.471',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-01-27T00:00:00.000',
#   'state': 'AL',
#   'tot_cases': '449086',
#   'conf_cases': '354967.0',
#   'prob_cases': '94119',
#   'new_case': '3177.0',
#   'pnew_case': '1128',
#   'tot_death': '7172',
#   'conf_death': '5817.0',
#   'prob_death': '1355',
#   'new_death': '276.0',
#   'pnew_death': '97',
#   'created_at': '2021-01-28T14:49:07.741',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-21T00:00:00.000',
#   'state': 'KS',
#   'tot_cases': '36856',
#   'conf_cases': '35895.0',
#   'prob_cases': '961',
#   'new_case': '966.0',
#   'pnew_case': '13',
#   'tot_death': '419',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-22T14:21:09.869',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-08-30T00:00:00.000',
#   'state': 'NC',
#   'tot_cases': '168797',
#   'conf_cases': '166127.0',
#   'prob_cases': '2670',
#   'new_case': '1952.0',
#   'pnew_case': '15',
#   'tot_death': '2692',
#   'conf_death': '2684.0',
#   'prob_death': '8',
#   'new_death': '9.0',
#   'pnew_death': '1',
#   'created_at': '2020-11-13T19:10:12.893',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-15T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-19T00:00:00.000',
#   'state': 'VI',
#   'tot_cases': '53',
#   'new_case': '-1.0',
#   'pnew_case': '0',
#   'tot_death': '3',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-04-19T16:22:39.452'},
#  {'submission_date': '2021-01-23T00:00:00.000',
#   'state': 'AL',
#   'tot_cases': '439442',
#   'conf_cases': '348017.0',
#   'prob_cases': '91425',
#   'new_case': '3355.0',
#   'pnew_case': '1015',
#   'tot_death': '6657',
#   'conf_death': '5464.0',
#   'prob_death': '1193',
#   'new_death': '171.0',
#   'pnew_death': '57',
#   'created_at': '2021-01-24T14:36:49.208',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-29T00:00:00.000',
#   'state': 'HI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-12-28T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '3',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-29T14:56:32.090'},
#  {'submission_date': '2020-01-23T00:00:00.000',
#   'state': 'FL',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-10-29T00:00:00.000',
#   'state': 'NM',
#   'tot_cases': '44904',
#   'new_case': '1078.0',
#   'pnew_case': '0',
#   'tot_death': '994',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-30T13:37:23.555',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-03-13T00:00:00.000',
#   'state': 'ID',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-23T00:00:00.000',
#   'state': 'MN',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-04T00:00:00.000',
#   'state': 'LA',
#   'tot_cases': '152369',
#   'new_case': '822.0',
#   'pnew_case': '0',
#   'tot_death': '5035',
#   'conf_death': '4872.0',
#   'prob_death': '163',
#   'new_death': '14.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-05T14:09:45.109',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-21T00:00:00.000',
#   'state': 'NYC',
#   'tot_cases': '232789',
#   'conf_cases': '228144.0',
#   'prob_cases': '4645',
#   'new_case': '217.0',
#   'pnew_case': '0',
#   'tot_death': '23646',
#   'conf_death': '19014.0',
#   'prob_death': '4632',
#   'new_death': '5.0',
#   'pnew_death': '-2',
#   'created_at': '2020-08-22T14:21:09.869',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-18T00:00:00.000',
#   'state': 'SC',
#   'tot_cases': '136318',
#   'conf_cases': '133310.0',
#   'prob_cases': '3008',
#   'new_case': '872.0',
#   'pnew_case': '127',
#   'tot_death': '3177',
#   'conf_death': '3010.0',
#   'prob_death': '167',
#   'new_death': '19.0',
#   'pnew_death': '1',
#   'created_at': '2020-09-19T14:00:26.273',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-05T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '288951',
#   'conf_cases': '288951.0',
#   'prob_cases': '0',
#   'new_case': '3318.0',
#   'pnew_case': '0',
#   'tot_death': '1312',
#   'conf_death': '1283.0',
#   'prob_death': '29',
#   'new_death': '7.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-06T14:58:26.308',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-02T00:00:00.000',
#   'state': 'AR',
#   'tot_cases': '231442',
#   'new_case': '2000.0',
#   'pnew_case': '403',
#   'tot_death': '3729',
#   'new_death': '18.0',
#   'pnew_death': '3',
#   'created_at': '2021-01-03T14:53:25.031',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-03-12T00:00:00.000',
#   'state': 'PR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-19T00:00:00.000',
#   'state': 'FL',
#   'tot_cases': '673194',
#   'new_case': '3510.0',
#   'pnew_case': '339',
#   'tot_death': '13287',
#   'new_death': '62.0',
#   'pnew_death': '9',
#   'created_at': '2020-09-20T13:53:10.094',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-04-21T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-04-21T16:22:39.452'},
#  {'submission_date': '2020-09-26T00:00:00.000',
#   'state': 'ID',
#   'tot_cases': '40296',
#   'conf_cases': '36721.0',
#   'prob_cases': '3575',
#   'new_case': '539.0',
#   'pnew_case': '50',
#   'tot_death': '460',
#   'conf_death': '423.0',
#   'prob_death': '37',
#   'new_death': '2.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-27T13:39:49.124',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-24T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '102196',
#   'conf_cases': '102196.0',
#   'prob_cases': '0',
#   'new_case': '2207.0',
#   'pnew_case': '0',
#   'tot_death': '5617',
#   'conf_death': '5617.0',
#   'prob_death': '0',
#   'new_death': '249.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-25T15:38:40.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-03T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-04T22:49:24.344'},
#  {'submission_date': '2020-08-11T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '102826',
#   'conf_cases': '97373.0',
#   'prob_cases': '5453',
#   'new_case': '1095.0',
#   'pnew_case': '80',
#   'tot_death': '3708',
#   'conf_death': '3435.0',
#   'prob_death': '273',
#   'new_death': '35.0',
#   'pnew_death': '5',
#   'created_at': '2020-08-12T13:50:14.465',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-12T00:00:00.000',
#   'state': 'SC',
#   'tot_cases': '12',
#   'new_case': '2.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-12T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-08T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '1916',
#   'new_case': '112.0',
#   'tot_death': '13',
#   'new_death': '0.0',
#   'created_at': '2020-04-07T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-05T00:00:00.000',
#   'state': 'NV',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
#  {'submission_date': '2020-04-28T00:00:00.000',
#   'state': 'DE',
#   'tot_cases': '4655',
#   'conf_cases': '4526.0',
#   'prob_cases': '129',
#   'new_case': '80.0',
#   'pnew_case': '0',
#   'tot_death': '144',
#   'conf_death': '133.0',
#   'prob_death': '11',
#   'new_death': '7.0',
#   'pnew_death': '0',
#   'created_at': '2020-04-29T18:12:08.477',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-28T00:00:00.000',
#   'state': 'MI',
#   'tot_cases': '135702',
#   'conf_cases': '122735.0',
#   'prob_cases': '12967',
#   'new_case': '1329.0',
#   'pnew_case': '21',
#   'tot_death': '7051',
#   'conf_death': '6731.0',
#   'prob_death': '320',
#   'new_death': '7.0',
#   'pnew_death': '-1',
#   'created_at': '2020-09-29T13:50:42.951',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-13T00:00:00.000',
#   'state': 'PA',
#   'tot_cases': '78462',
#   'conf_cases': '76237.0',
#   'prob_cases': '2225',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '6211',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-14T14:19:43.716',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-05-24T00:00:00.000',
#   'state': 'NY',
#   'tot_cases': '163392',
#   'new_case': '732.0',
#   'pnew_case': '0',
#   'tot_death': '7830',
#   'new_death': '68.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-25T14:12:49.524',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-08-17T00:00:00.000',
#   'state': 'AR',
#   'tot_cases': '53077',
#   'new_case': '412.0',
#   'pnew_case': '0',
#   'tot_death': '603',
#   'new_death': '4.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-18T14:26:55.280',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-12-19T00:00:00.000',
#   'state': 'VT',
#   'tot_cases': '6343',
#   'new_case': '100.0',
#   'pnew_case': '2',
#   'tot_death': '108',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-20T14:32:33.200',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-06T00:00:00.000',
#   'state': 'AL',
#   'tot_cases': '44909',
#   'conf_cases': '44405.0',
#   'prob_cases': '504',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '1009',
#   'conf_death': '986.0',
#   'prob_death': '23',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-07T14:58:02.598',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-25T00:00:00.000',
#   'state': 'MN',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-11T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '102282',
#   'conf_cases': '82440.0',
#   'prob_cases': '19842',
#   'new_case': '1070.0',
#   'pnew_case': '211',
#   'tot_death': '1594',
#   'new_death': '12.0',
#   'pnew_death': '3',
#   'created_at': '2021-01-12T14:48:35.544',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-12-11T00:00:00.000',
#   'state': 'MO',
#   'tot_cases': '338604',
#   'new_case': '3900.0',
#   'pnew_case': '0',
#   'tot_death': '4481',
#   'new_death': '31.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-12T14:59:37.544',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-06-06T00:00:00.000',
#   'state': 'RMI',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-07T14:23:35.373',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-13T00:00:00.000',
#   'state': 'VI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
#  {'submission_date': '2020-04-29T00:00:00.000',
#   'state': 'AZ',
#   'tot_cases': '7202',
#   'conf_cases': '7202.0',
#   'prob_cases': '0',
#   'new_case': '254.0',
#   'pnew_case': '0',
#   'tot_death': '254',
#   'conf_death': '254.0',
#   'prob_death': '0',
#   'new_death': '-39.0',
#   'pnew_death': '0',
#   'created_at': '2020-04-30T16:07:01.546',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-08T00:00:00.000',
#   'state': 'CO',
#   'tot_cases': '59674',
#   'conf_cases': '55642.0',
#   'prob_cases': '4032',
#   'new_case': '187.0',
#   'pnew_case': '3',
#   'tot_death': '1973',
#   'conf_death': '1623.0',
#   'prob_death': '350',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-09T13:47:50.836',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-22T00:00:00.000',
#   'state': 'KY',
#   'tot_cases': '8426',
#   'conf_cases': '8305.0',
#   'prob_cases': '121',
#   'new_case': '140.0',
#   'pnew_case': '10',
#   'tot_death': '391',
#   'conf_death': '390.0',
#   'prob_death': '1',
#   'new_death': '5.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-23T17:58:16.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-19T00:00:00.000',
#   'state': 'MA',
#   'tot_cases': '316824',
#   'conf_cases': '306928.0',
#   'prob_cases': '9896',
#   'new_case': '3995.0',
#   'pnew_case': '0',
#   'tot_death': '11613',
#   'conf_death': '11405.0',
#   'prob_death': '208',
#   'new_death': '47.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-20T14:32:33.200',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-19T00:00:00.000',
#   'state': 'KY',
#   'tot_cases': '43',
#   'new_case': '8.0',
#   'tot_death': '2',
#   'new_death': '1.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-14T00:00:00.000',
#   'state': 'NH',
#   'tot_cases': '31875',
#   'new_case': '919.0',
#   'pnew_case': '307',
#   'tot_death': '604',
#   'new_death': '1.0',
#   'pnew_death': '1',
#   'created_at': '2020-12-15T14:39:02.350',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-04-16T00:00:00.000',
#   'state': 'NV',
#   'tot_cases': '3321',
#   'new_case': '110.0',
#   'tot_death': '142',
#   'new_death': '5.0',
#   'created_at': '2020-04-16T16:22:39.452'},
#  {'submission_date': '2020-11-28T00:00:00.000',
#   'state': 'ME',
#   'tot_cases': '11508',
#   'conf_cases': '10315.0',
#   'prob_cases': '1193',
#   'new_case': '220.0',
#   'pnew_case': '30',
#   'tot_death': '191',
#   'conf_death': '190.0',
#   'prob_death': '1',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-29T14:49:08.286',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-31T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '91159',
#   'conf_cases': '86333.0',
#   'prob_cases': '4826',
#   'new_case': '1533.0',
#   'pnew_case': '62',
#   'tot_death': '3489',
#   'conf_death': '3222.0',
#   'prob_death': '267',
#   'new_death': '47.0',
#   'pnew_death': '2',
#   'created_at': '2020-08-01T14:38:12.337',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-19T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '105786',
#   'new_case': '127.0',
#   'pnew_case': '15',
#   'tot_death': '1667',
#   'conf_death': '1346.0',
#   'prob_death': '321',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-20T14:44:03.544',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-19T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-21T00:00:00.000',
#   'state': 'PA',
#   'tot_cases': '82186',
#   'conf_cases': '79859.0',
#   'prob_cases': '2327',
#   'new_case': '456.0',
#   'pnew_case': '2',
#   'tot_death': '6426',
#   'new_death': '3.0',
#   'pnew_death': '-2',
#   'created_at': '2020-06-22T15:24:02.542',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-01-17T00:00:00.000',
#   'state': 'MO',
#   'tot_cases': '437549',
#   'new_case': '1350.0',
#   'pnew_case': '0',
#   'tot_death': '6254',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-18T14:39:32.141',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-10-06T00:00:00.000',
#   'state': 'WY',
#   'tot_cases': '6770',
#   'conf_cases': '5751.0',
#   'prob_cases': '1019',
#   'new_case': '141.0',
#   'pnew_case': '50',
#   'tot_death': '53',
#   'conf_death': '53.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-07T13:45:01.309',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-27T00:00:00.000',
#   'state': 'MD',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-31T00:00:00.000',
#   'state': 'GA',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-27T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '21541',
#   'new_case': '408.0',
#   'pnew_case': '0',
#   'tot_death': '218',
#   'conf_death': '216.0',
#   'prob_death': '2',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-28T13:50:59.474',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-22T00:00:00.000',
#   'state': 'CO',
#   'tot_cases': '41698',
#   'conf_cases': '38562.0',
#   'prob_cases': '3136',
#   'new_case': '639.0',
#   'pnew_case': '24',
#   'tot_death': '1771',
#   'conf_death': '1435.0',
#   'prob_death': '336',
#   'new_death': '8.0',
#   'pnew_death': '3',
#   'created_at': '2020-07-23T14:48:19.028',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-26T00:00:00.000',
#   'state': 'PR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-14T00:00:00.000',
#   'state': 'TN',
#   'tot_cases': '670482',
#   'conf_cases': '576406.0',
#   'prob_cases': '94076',
#   'new_case': '4983.0',
#   'pnew_case': '1196',
#   'tot_death': '8232',
#   'conf_death': '6909.0',
#   'prob_death': '1323',
#   'new_death': '84.0',
#   'pnew_death': '31',
#   'created_at': '2021-01-15T14:46:04.456',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-06T00:00:00.000',
#   'state': 'ID',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-26T00:00:00.000',
#   'state': 'RI',
#   'tot_cases': '112396',
#   'new_case': '642.0',
#   'pnew_case': '0',
#   'tot_death': '2126',
#   'new_death': '16.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-27T14:53:24.793',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-02-11T00:00:00.000',
#   'state': 'NYC',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-02T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-08T00:00:00.000',
#   'state': 'DC',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
# ...
#   'prob_cases': '1450',
#   'new_case': '1011.0',
#   'pnew_case': '71',
#   'tot_death': '1002',
#   'conf_death': '968.0',
#   'prob_death': '34',
#   'new_death': '25.0',
#   'pnew_death': '1',
#   'created_at': '2020-05-16T15:46:44.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-30T00:00:00.000',
#   'state': 'MT',
#   'tot_cases': '31916',
#   'conf_cases': '31916.0',
#   'prob_cases': '0',
#   'new_case': '1063.0',
#   'pnew_case': '0',
#   'tot_death': '364',
#   'conf_death': '364.0',
#   'prob_death': '0',
#   'new_death': '27.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-31T13:30:31.395',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-26T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '116978',
#   'conf_cases': '93905.0',
#   'prob_cases': '23073',
#   'new_case': '1139.0',
#   'pnew_case': '348',
#   'tot_death': '1928',
#   'new_death': '29.0',
#   'pnew_death': '9',
#   'created_at': '2021-01-27T14:53:24.793',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-05-18T00:00:00.000',
#   'state': 'TX',
#   'tot_cases': '48693',
#   'new_case': '909.0',
#   'pnew_case': '0',
#   'tot_death': '1347',
#   'new_death': '11.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-19T15:45:23.000',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-01-07T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '3',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-08T15:56:01.472'},
#  {'submission_date': '2020-06-15T00:00:00.000',
#   'state': 'OK',
#   'tot_cases': '8251',
#   'conf_cases': '8237.0',
#   'prob_cases': '14',
#   'new_case': '20.0',
#   'pnew_case': '14',
#   'tot_death': '371',
#   'conf_death': '371.0',
#   'prob_death': '0',
#   'new_death': '12.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-16T14:10:11.939',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-21T00:00:00.000',
#   'state': 'DC',
#   'tot_cases': '3098',
#   'new_case': '171.0',
#   'pnew_case': '0',
#   'tot_death': '112',
#   'new_death': '7.0',
#   'pnew_death': '0',
#   'created_at': '2020-04-21T16:22:39.452'},
#  {'submission_date': '2020-03-02T00:00:00.000',
#   'state': 'NC',
#   'tot_cases': '1',
#   'conf_cases': '1.0',
#   'prob_cases': '0',
#   'new_case': '1.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-13T19:10:12.893',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-15T00:00:00.000',
#   'state': 'MN',
#   'tot_cases': '117106',
#   'new_case': '1163.0',
#   'pnew_case': '61',
#   'tot_death': '2199',
#   'conf_death': '2192.0',
#   'prob_death': '7',
#   'new_death': '-28.0',
#   'pnew_death': '-46',
#   'created_at': '2020-10-16T13:33:55.808',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-10T00:00:00.000',
#   'state': 'OK',
#   'tot_cases': '103382',
#   'conf_cases': '91591.0',
#   'prob_cases': '11791',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '1097',
#   'conf_death': '1077.0',
#   'prob_death': '20',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-11T13:47:22.472',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-27T00:00:00.000',
#   'state': 'CT',
#   'tot_cases': '1291',
#   'new_case': '279.0',
#   'tot_death': '27',
#   'new_death': '6.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-06T00:00:00.000',
#   'state': 'CT',
#   'tot_cases': '46976',
#   'conf_cases': '44997.0',
#   'prob_cases': '1979',
#   'new_case': '259.0',
#   'pnew_case': '3',
#   'tot_death': '4338',
#   'conf_death': '3466.0',
#   'prob_death': '872',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-07T14:58:02.598',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-29T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-10T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '9663',
#   'new_case': '58.0',
#   'pnew_case': '0',
#   'tot_death': '146',
#   'conf_death': '144.0',
#   'prob_death': '2',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-11T14:16:27.891',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-23T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-05T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-06T14:12:27.571'},
#  {'submission_date': '2020-11-09T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-10T14:45:45.196'},
#  {'submission_date': '2020-03-31T00:00:00.000',
#   'state': 'AL',
#   'tot_cases': '999',
#   'new_case': '52.0',
#   'tot_death': '13',
#   'new_death': '7.0',
#   'created_at': '2020-03-30T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-09T00:00:00.000',
#   'state': 'RI',
#   'tot_cases': '38009',
#   'new_case': '1629.0',
#   'pnew_case': '0',
#   'tot_death': '1233',
#   'new_death': '9.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-10T14:45:45.196',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-10-21T00:00:00.000',
#   'state': 'NH',
#   'tot_cases': '9917',
#   'new_case': '89.0',
#   'pnew_case': '40',
#   'tot_death': '469',
#   'new_death': '1.0',
#   'pnew_death': '1',
#   'created_at': '2020-10-22T13:34:46.095',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-01-15T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '616032',
#   'conf_cases': '555299.0',
#   'prob_cases': '60733',
#   'new_case': '6311.0',
#   'pnew_case': '852',
#   'tot_death': '20320',
#   'conf_death': '18229.0',
#   'prob_death': '2091',
#   'new_death': '67.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-16T14:46:10.803',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-06T00:00:00.000',
#   'state': 'RI',
#   'tot_cases': '95463',
#   'new_case': '1611.0',
#   'pnew_case': '0',
#   'tot_death': '1890',
#   'new_death': '20.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-07T14:56:59.705',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-09-10T00:00:00.000',
#   'state': 'MO',
#   'tot_cases': '97591',
#   'new_case': '1116.0',
#   'pnew_case': '0',
#   'tot_death': '1691',
#   'new_death': '18.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-11T13:51:03.398',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-03-18T00:00:00.000',
#   'state': 'CO',
#   'tot_cases': '216',
#   'new_case': '33.0',
#   'tot_death': '2',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-06T00:00:00.000',
#   'state': 'TX',
#   'tot_cases': '1867163',
#   'new_case': '24010.0',
#   'pnew_case': '4196',
#   'tot_death': '28545',
#   'new_death': '326.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-07T14:56:59.705',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-11-13T00:00:00.000',
#   'state': 'KS',
#   'tot_cases': '115507',
#   'conf_cases': '101914.0',
#   'prob_cases': '13593',
#   'new_case': '6282.0',
#   'pnew_case': '1220',
#   'tot_death': '1259',
#   'new_death': '44.0',
#   'pnew_death': '9',
#   'created_at': '2020-11-14T14:44:40.037',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-03-04T00:00:00.000',
#   'state': 'CT',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-31T00:00:00.000',
#   'state': 'IA',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-12-04T00:00:00.000',
#   'state': 'NM',
#   'tot_cases': '104935',
#   'new_case': '2073.0',
#   'pnew_case': '0',
#   'tot_death': '1706',
#   'new_death': '33.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-05T14:29:17.537',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-17T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '54813',
#   'new_case': '733.0',
#   'pnew_case': '0',
#   'tot_death': '2803',
#   'conf_death': '2610.0',
#   'prob_death': '193',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-18T16:14:26.601',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-29T00:00:00.000',
#   'state': 'VI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
#  {'submission_date': '2020-03-07T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '7',
#   'new_case': '4.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-12T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '140851',
#   'new_case': '814.0',
#   'pnew_case': '16',
#   'tot_death': '9508',
#   'conf_death': '9508.0',
#   'prob_death': '0',
#   'new_death': '198.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-07T18:54:20.981',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-22T00:00:00.000',
#   'state': 'MD',
#   'tot_cases': '0',
#   'new_case': '0',
#   'tot_death': '0',
#   'new_death': '0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-02-01T00:00:00.000',
#   'state': 'IA',
#   'tot_cases': '319814',
#   'new_case': '567.0',
#   'pnew_case': '216',
#   'tot_death': '4906',
#   'new_death': '5.0',
#   'pnew_death': '5',
#   'created_at': '2021-02-02T14:51:51.706',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-11-07T00:00:00.000',
#   'state': 'GU',
#   'tot_cases': '5077',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '88',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-08T14:40:34.096',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-04-30T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '18027',
#   'conf_cases': '17285.0',
#   'prob_cases': '742',
#   'new_case': '724.0',
#   'pnew_case': '40',
#   'tot_death': '975',
#   'conf_death': '898.0',
#   'prob_death': '77',
#   'new_death': '38.0',
#   'pnew_death': '-4',
#   'created_at': '2020-05-01T21:00:19.025',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-04T00:00:00.000',
#   'state': 'WA',
#   'tot_cases': '7591',
#   'new_case': '625.0',
#   'tot_death': '310',
#   'new_death': '26.0',
#   'created_at': '2020-04-03T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-06-10T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '38337',
#   'new_case': '304.0',
#   'pnew_case': '0',
#   'tot_death': '2355',
#   'conf_death': '2173.0',
#   'prob_death': '182',
#   'new_death': '16.0',
#   'pnew_death': '1',
#   'created_at': '2020-06-11T14:48:51.509',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-16T00:00:00.000',
#   'state': 'TN',
#   'tot_cases': '52',
#   'new_case': '13.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-21T00:00:00.000',
#   'state': 'VI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
#  {'submission_date': '2021-01-28T00:00:00.000',
#   'state': 'VA',
#   'tot_cases': '497912',
#   'conf_cases': '399577.0',
#   'prob_cases': '98335',
#   'new_case': '4238.0',
#   'pnew_case': '1101',
#   'tot_death': '6379',
#   'conf_death': '5606.0',
#   'prob_death': '773',
#   'new_death': '71.0',
#   'pnew_death': '31',
#   'created_at': '2021-01-29T14:42:19.981',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-06T00:00:00.000',
#   'state': 'WA',
#   'tot_cases': '90663',
#   'new_case': '387.0',
#   'pnew_case': '0',
#   'tot_death': '2165',
#   'new_death': '7.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-07T13:45:01.309',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-03-23T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
#  {'submission_date': '2021-01-05T00:00:00.000',
#   'state': 'TN',
#   'tot_cases': '617649',
#   'conf_cases': '537128.0',
#   'prob_cases': '80521',
#   'new_case': '5399.0',
#   'pnew_case': '2745',
#   'tot_death': '7267',
#   'conf_death': '6241.0',
#   'prob_death': '1026',
#   'new_death': '99.0',
#   'pnew_death': '40',
#   'created_at': '2021-01-06T14:58:26.308',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-24T00:00:00.000',
#   'state': 'ND',
#   'tot_cases': '75478',
#   'conf_cases': '75478.0',
#   'prob_cases': '0',
#   'new_case': '1077.0',
#   'pnew_case': '0',
#   'tot_death': '887',
#   'new_death': '4.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-25T14:53:15.184',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-12-14T00:00:00.000',
#   'state': 'NV',
#   'tot_cases': '189412',
#   'new_case': '2579.0',
#   'pnew_case': '0',
#   'tot_death': '2548',
#   'new_death': '9.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-15T14:39:02.350'},
#  {'submission_date': '2020-02-21T00:00:00.000',
#   'state': 'SC',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-18T00:00:00.000',
#   'state': 'IL',
#   'tot_cases': '96485',
#   'conf_cases': '96485.0',
#   'prob_cases': '0',
#   'new_case': '2294.0',
#   'pnew_case': '0',
#   'tot_death': '4234',
#   'conf_death': '4234.0',
#   'prob_death': '0',
#   'new_death': '57.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-19T15:45:23.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-21T00:00:00.000',
#   'state': 'FSM',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-22T13:34:46.095',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-08T00:00:00.000',
#   'state': 'FL',
#   'tot_cases': '63378',
#   'new_case': '962.0',
#   'pnew_case': '0',
#   'tot_death': '2712',
#   'new_death': '12.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-09T16:49:08.000',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-11-24T00:00:00.000',
#   'state': 'ID',
#   'tot_cases': '94730',
#   'conf_cases': '80709.0',
#   'prob_cases': '14021',
#   'new_case': '1640.0',
#   'pnew_case': '341',
#   'tot_death': '874',
#   'conf_death': '808.0',
#   'prob_death': '66',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-25T14:53:15.184',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'}]

# %%
df_state_data = pd.DataFrame(st_case_death_json)
df_state_data.head()
# Out:
#            submission_date state tot_cases conf_cases prob_cases new_case  \
# 0  2020-05-04T00:00:00.000    KY      5245     5245.0          0    115.0
# 1  2020-03-23T00:00:00.000    NH       101        NaN        NaN     23.0
# 2  2020-12-08T00:00:00.000    OK    205999   171497.0      34502      0.0
# 3  2020-10-28T00:00:00.000    RI     31944        NaN        NaN    499.0
# 4  2020-04-09T00:00:00.000    MT       365        NaN        NaN     13.0
#
#   pnew_case tot_death conf_death prob_death new_death pnew_death  \
# 0         0       261      261.0          0       8.0          0
# 1       NaN         1        NaN        NaN       1.0        NaN
# 2         0      1752     1680.0         72       0.0          0
# 3         0      1192        NaN        NaN       4.0          0
# 4       NaN         6        NaN        NaN       0.0        NaN
#
#                 created_at consent_cases consent_deaths
# 0  2020-05-05T17:25:08.000         Agree          Agree
# 1  2020-03-26T16:22:39.452     Not agree      Not agree
# 2  2020-12-09T14:45:40.234         Agree          Agree
# 3  2020-10-29T14:11:33.577     Not agree            N/A
# 4  2020-04-08T16:22:39.452         Agree          Agree

# %%
# Create DataFrame of Vaccination Data per State

# Moderna API
url2 = "https://data.cdc.gov/resource/b7pe-5nws.json"

# query_url2 = f"{url2}"

# print(query_url2)
print(url2)

# vacc_response = requests.get(query_url2)
vacc_json = requests.get(url2).json()

vacc_json[0]

df_vaccine = pd.DataFrame(vacc_json)
df_vaccine.head()
# Out:
# https://data.cdc.gov/resource/b7pe-5nws.json
#     jurisdiction hhs_region doses_allocated_week_12_21  \
# 0    Connecticut   Region 1                     63,300
# 1          Maine   Region 1                     24,200
# 2  Massachusetts   Region 1                    121,900
# 3  New Hampshire   Region 1                     24,200
# 4   Rhode Island   Region 1                     19,000
#
#   second_dose_shipment_12_21 doses_allocated_week_12_28  \
# 0                     63,300                     21,900
# 1                     24,200                      8,400
# 2                    121,900                     42,100
# 3                     24,200                      8,400
# 4                     19,000                      6,600
#
#   second_dose_shipment_12_28 doses_allocated_week_01_04  \
# 0                     21,900                     21,800
# 1                      8,400                      8,300
# 2                     42,100                     42,000
# 3                      8,400                      8,400
# 4                      6,600                      6,600
#
#   second_dose_shipment_01_04 doses_allocated_week_of_01_10  \
# 0                     21,800                        21,900
# 1                      8,300                         8,400
# 2                     42,000                        42,100
# 3                      8,400                         8,400
# 4                      6,600                         6,600
#
#   second_dose_shipment_week_of_01_10  ... doses_allocated_week_of_01_25  \
# 0                             21,900  ...                        23,000
# 1                              8,400  ...                         8,800
# 2                             42,100  ...                        44,300
# 3                              8,400  ...                         8,800
# 4                              6,600  ...                         6,900
#
#   second_dose_week_of_01_25 doses_allocated_week_of_02_01  \
# 0                    23,000                        30,300
# 1                     8,800                        11,600
# 2                    44,300                        58,400
# 3                     8,800                        11,600
# 4                     6,900                         9,100
#
#   second_dose_shipment_week_of_02_01 doses_allocated_week_of_02_08  \
# 0                             30,300                        33,100
# 1                             11,600                        12,700
# 2                             58,400                        63,800
# 3                             11,600                        12,700
# 4                              9,100                        10,000
#
#   second_dose_shipment_week_of_02_08 doses_allocated_week_of_02_15  \
# 0                             33,100                        35,800
# 1                             12,700                        13,700
# 2                             63,800                        69,000
# 3                             12,700                        13,700
# 4                             10,000                        10,800
#
#   second_dose_shipment_week_of_02_15  \
# 0                             35,800
# 1                             13,700
# 2                             69,000
# 3                             13,700
# 4                             10,800
#
#   total_moderna_allocation_first_dose_shipments  \
# 0                                       274,100
# 1                                       104,900
# 2                                       527,900
# 3                                       105,000
# 4                                        82,500
#
#   total_allocation_moderna_second_dose_shipments
# 0                                        274,100
# 1                                        104,900
# 2                                        527,900
# 3                                        105,000
# 4                                         82,500
#
# [5 rows x 22 columns]

# %%
# Filter Out Necessary Data and Create New DataFrame

df_vaccine1 = pd.DataFrame(df_vaccine, columns=['jurisdiction','total_allocation_moderna_second_dose_shipments','total_moderna_allocation_first_dose_shipments'])
df_vaccine1
# Out:
#              jurisdiction total_allocation_moderna_second_dose_shipments  \
# 0             Connecticut                                        274,100
# 1                   Maine                                        104,900
# 2           Massachusetts                                        527,900
# 3           New Hampshire                                        105,000
# 4            Rhode Island                                         82,500
# ..                    ...                                            ...
# 61                  Idaho                                        121,400
# 62              Oregon***                                        312,500
# 63          Washington***                                        554,400
# 64  Federal Entities ****                                      1,584,200
# 65                  Total                                            NaN
#
#    total_moderna_allocation_first_dose_shipments
# 0                                        274,100
# 1                                        104,900
# 2                                        527,900
# 3                                        105,000
# 4                                         82,500
# ..                                           ...
# 61                                       121,400
# 62                                       312,500
# 63                                       554,400
# 64                                     1,612,800
# 65                                           NaN
#
# [66 rows x 3 columns]

# %%
#Set Index Info to Have States as Row Data

df_vaccine1.set_index('jurisdiction')
# Out:
#                       total_allocation_moderna_second_dose_shipments  \
# jurisdiction
# Connecticut                                                  274,100
# Maine                                                        104,900
# Massachusetts                                                527,900
# New Hampshire                                                105,000
# Rhode Island                                                  82,500
# ...                                                              ...
# Idaho                                                        121,400
# Oregon***                                                    312,500
# Washington***                                                554,400
# Federal Entities ****                                      1,584,200
# Total                                                            NaN
#
#                       total_moderna_allocation_first_dose_shipments
# jurisdiction
# Connecticut                                                 274,100
# Maine                                                       104,900
# Massachusetts                                               527,900
# New Hampshire                                               105,000
# Rhode Island                                                 82,500
# ...                                                             ...
# Idaho                                                       121,400
# Oregon***                                                   312,500
# Washington***                                               554,400
# Federal Entities ****                                     1,612,800
# Total                                                           NaN
#
# [66 rows x 2 columns]

# %%
# Build Query

url = "https://opendata.socrata.com/resource/asset_id.json"

api_key = "ZG1vYjBocHRqenc0NTA4M3d1bDhlaWUzMzoyeHRxcmpkd2Q3YXdtcXpvdHZrejNtYmt0bWZkY3dwNnR1d3c0djF6eHBrZ"

query_url = f"{url}appid={api_key}&q={year}"

print(query_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-228e0554e71c> in <module>
#       5 api_key = "ZG1vYjBocHRqenc0NTA4M3d1bDhlaWUzMzoyeHRxcmpkd2Q3YXdtcXpvdHZrejNtYmt0bWZkY3dwNnR1d3c0djF6eHBrZ"
#       6
# ----> 7 query_url = f"{url}appid={api_key}&q={year}"
#       8
#       9 print(query_url)
#
# NameError: name 'year' is not defined

# %%
url = "https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_time_series"
query_url = f"{url}&
# Out:
#   File "<ipython-input-4-ec996c32ce9b>", line 2
#     query_url = f"{url}&
#                         ^
# SyntaxError: EOL while scanning string literal

# %%
# Establish Base URL and Build Query

url = "https://dataverse.harvard.edu/api/access/datafile/4299753"

year = "2020"

query_url = f"{url}&q{year}"

print(query_url)
# Out:
# https://dataverse.harvard.edu/api/access/datafile/4299753&q2020

# %%
GEThttps://private-anon-50b08f9405-socrataapikeys.apiary-proxy.com/resource/asset_id.json

# %%
Iframe = '<Iframe src=' + url2 + 'width=700 height=350></Iframe>'
IPython.display.IFrame

# %%
# Save Config Information

urllib2 = "https://opendata.socrata.com/resource/asset_id.json"

# Build Partial Query URL

query_url = f"{urllib2}"

# %%
df_connecticut = df_vaccine[df_vaccine.jurisdiction=="Connecticut"][['jurisdiction','total_allocation_moderna_second_dose_shipments','total_moderna_allocation_first_dose_shipments']]

df_connecticut
# Out:
#   jurisdiction total_allocation_moderna_second_dose_shipments  \
# 0  Connecticut                                        274,100
#
#   total_moderna_allocation_first_dose_shipments
# 0                                       274,100
