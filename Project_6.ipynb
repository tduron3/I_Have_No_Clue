# %%
# Set Dependencies

import csv
import pandas as pd
import numpy as np
import requests
import json
import urllib
import IPython
import lib
import math
import os
import string

# %%
# Output File CSV
output_data_file = "output.proj1.csv"

# %%
# 2020 Presidential Analysis

# Name CSV File and Print
df = pd.read_csv(r'C:\users\tony duron\Project1-TD\Resources\1976-2020-president.csv')
df.head()

# Select Necessary Data
df = pd.DataFrame(df, columns=['year','state','candidate','candidatevotes','party_simplified'])

# Print DataFrame
df

# Rename Columns and Print
df.rename(columns = {'year':'Year','state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#       Year    State                Candidate  Cand_Votes Political_Party
# 0     1976  ALABAMA            CARTER, JIMMY      659170        DEMOCRAT
# 1     1976  ALABAMA             FORD, GERALD      504070      REPUBLICAN
# 2     1976  ALABAMA           MADDOX, LESTER        9198           OTHER
# 3     1976  ALABAMA  BUBAR, BENJAMIN ""BEN""        6669           OTHER
# 4     1976  ALABAMA                HALL, GUS        1954           OTHER
# ...    ...      ...                      ...         ...             ...
# 4282  2020  WYOMING            JORGENSEN, JO        5768     LIBERTARIAN
# 4283  2020  WYOMING            PIERCE, BROCK        2208           OTHER
# 4284  2020  WYOMING                      NaN        1739           OTHER
# 4285  2020  WYOMING                OVERVOTES         279           OTHER
# 4286  2020  WYOMING               UNDERVOTES        1459           OTHER
#
# [4287 rows x 5 columns]

# %%
# 2020 Presidential Analysis (cont.)
# Select 2020 Presidential Election Year
is_2020 = df['year']==2020

# Print
is_2020.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: year, dtype: bool

# %%
# 2020 Presidential Analysis (cont.)
# Select 2020 Presidential Election Year (cont.)
df_2020 = df[is_2020]
df_2020.head()

# Filtering Out Primary Political Parties
value_list = ["DEMOCRAT","REPUBLICAN"]
boolean_series = df_2020.party_simplified.isin(value_list)
dem_rep_df = df_2020[boolean_series]

# Rename Index
dem_rep_df.index.names = ['Def_Index']

# Print New DataFrame
dem_rep_df
dem_rep_df.head()

# Insert New Column for Result
dem_rep_df.insert(5, "Final_Result (%)", True)
dem_rep_df.head()

dem_rep_df.insert(4, "Total_State_Votes", True)
dem_rep_df

dem_rep_df.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#            year          State            Candidate  Cand_Votes  \
# Def_Index
# 3740       2020        ALABAMA  BIDEN, JOSEPH R. JR      849624
# 3741       2020        ALABAMA     TRUMP, DONALD J.     1441170
# 3744       2020         ALASKA  BIDEN, JOSEPH R. JR      153778
# 3745       2020         ALASKA     TRUMP, DONALD J.      189951
# 3752       2020        ARIZONA  BIDEN, JOSEPH R. JR     1672143
# ...         ...            ...                  ...         ...
# 4264       2020  WEST VIRGINIA     TRUMP, DONALD J.      545382
# 4267       2020      WISCONSIN  BIDEN, JOSEPH R. JR     1630866
# 4268       2020      WISCONSIN     TRUMP, DONALD J.     1610184
# 4280       2020        WYOMING  BIDEN, JOSEPH R. JR       73491
# 4281       2020        WYOMING     TRUMP, DONALD J.      193559
#
#            Total_State_Votes Political_Party  Final_Result (%)
# Def_Index
# 3740                    True        DEMOCRAT              True
# 3741                    True      REPUBLICAN              True
# 3744                    True        DEMOCRAT              True
# 3745                    True      REPUBLICAN              True
# 3752                    True        DEMOCRAT              True
# ...                      ...             ...               ...
# 4264                    True      REPUBLICAN              True
# 4267                    True        DEMOCRAT              True
# 4268                    True      REPUBLICAN              True
# 4280                    True        DEMOCRAT              True
# 4281                    True      REPUBLICAN              True
#
# [102 rows x 7 columns]

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_al = dem_rep_df[dem_rep_df.state=="ALABAMA"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_al
df_al.head()

# Total Votes for Both Parties in Alabama
total_al = df_al['candidatevotes'].sum()

# Print
total_al

# Create New column and Add Result 
df_al['Total_State_Votes'] = df_al['candidatevotes'].sum()

# Print
df_al
df_al.head()

# Insert New Column for Result
df_al.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_al['Final_Result (%)']=round((df_al['candidatevotes']).div(df_al['Total_State_Votes']) * 100, 2)

# Print
df_al
df_al.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#              State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 3740       ALABAMA  BIDEN, JOSEPH R. JR        DEMOCRAT      849624
# 3741       ALABAMA     TRUMP, DONALD J.      REPUBLICAN     1441170
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 3740                 2290794             37.09
# 3741                 2290794             62.91

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_ak = dem_rep_df[dem_rep_df.state=="ALASKA"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_ak
df_ak.head()

# Total Votes for Both Parties in Alabama
total_ak = df_ak['candidatevotes'].sum()

# Print
total_ak

# Create New column and Add Result 
df_ak['Total_State_Votes'] = df_ak['candidatevotes'].sum()

# Print
df_ak
df_ak.head()

# Insert New Column for Result
df_ak.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_ak['Final_Result (%)']=round((df_ak['candidatevotes']).div(df_ak['Total_State_Votes']) * 100, 2)

# Print
df_ak
df_ak.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#             State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 3744       ALASKA  BIDEN, JOSEPH R. JR        DEMOCRAT      153778
# 3745       ALASKA     TRUMP, DONALD J.      REPUBLICAN      189951
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 3744                  343729             44.74
# 3745                  343729             55.26

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_mn = dem_rep_df[dem_rep_df.state=="MINNESOTA"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_mn
df_mn.head()

# Total Votes for Both Parties in Alabama
total_mn = df_mn['candidatevotes'].sum()

# Print
total_mn

# Create New column and Add Result 
df_mn['Total_State_Votes'] = df_mn['candidatevotes'].sum()

# Print
df_mn
df_mn.head()

# Insert New Column for Result
df_mn.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_mn['Final_Result (%)']=round((df_mn['candidatevotes']).div(df_mn['Total_State_Votes']) * 100, 2)

# Print
df_mn
df_mn.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#                State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 4031       MINNESOTA     TRUMP, DONALD J.      REPUBLICAN     1484065
# 4032       MINNESOTA  BIDEN, JOSEPH R. JR        DEMOCRAT     1717077
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 4031                 3201142             46.36
# 4032                 3201142             53.64

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_tx = dem_rep_df[dem_rep_df.state=="TEXAS"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_tx
df_tx.head()

# Total Votes for Both Parties in Alabama
total_tx = df_tx['candidatevotes'].sum()

# Print
total_tx

# Create New column and Add Result 
df_tx['Total_State_Votes'] = df_tx['candidatevotes'].sum()

# Print
df_tx
df_tx.head()

# Insert New Column for Result
df_tx.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_tx['Final_Result (%)']=round((df_tx['candidatevotes']).div(df_tx['Total_State_Votes']) * 100, 2)

# Print
df_tx
df_tx.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#            State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 4201       TEXAS     TRUMP, DONALD J.      REPUBLICAN     5890347
# 4202       TEXAS  BIDEN, JOSEPH R. JR        DEMOCRAT     5259126
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 4201                11149473             52.83
# 4202                11149473             47.17

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_fl = dem_rep_df[dem_rep_df.state=="FLORIDA"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_fl
df_fl.head()

# Total Votes for Both Parties in Alabama
total_fl = df_fl['candidatevotes'].sum()

# Print
total_fl

# Create New column and Add Result 
df_fl['Total_State_Votes'] = df_fl['candidatevotes'].sum()

# Print
df_fl
df_fl.head()

# Insert New Column for Result
df_fl.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_fl['Final_Result (%)']=round((df_fl['candidatevotes']).div(df_fl['Total_State_Votes']) * 100, 2)

# Print
df_fl
df_fl.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#              State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 3849       FLORIDA  BIDEN, JOSEPH R. JR        DEMOCRAT     5297045
# 3850       FLORIDA     TRUMP, DONALD J.      REPUBLICAN     5668731
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 3849                10965776             48.31
# 3850                10965776             51.69

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_wy = dem_rep_df[dem_rep_df.state=="WYOMING"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_wy
df_wy.head()

# Total Votes for Both Parties in Alabama
total_wy = df_wy['candidatevotes'].sum()

# Print
total_wy

# Create New column and Add Result 
df_wy['Total_State_Votes'] = df_wy['candidatevotes'].sum()

# Print
df_wy
df_wy.head()

# Insert New Column for Result
df_wy.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_wy['Final_Result (%)']=round((df_wy['candidatevotes']).div(df_wy['Total_State_Votes']) * 100, 2)

# Print
df_wy
df_wy.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#              State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 4280       WYOMING  BIDEN, JOSEPH R. JR        DEMOCRAT       73491
# 4281       WYOMING     TRUMP, DONALD J.      REPUBLICAN      193559
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 4280                  267050             27.52
# 4281                  267050             72.48

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_wi = dem_rep_df[dem_rep_df.state=="WISCONSIN"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_wi
df_wi.head()

# Total Votes for Both Parties in Alabama
total_wi = df_wi['candidatevotes'].sum()

# Print
total_wi

# Create New column and Add Result 
df_wi['Total_State_Votes'] = df_wi['candidatevotes'].sum()

# Print
df_wi
df_wi.head()

# Insert New Column for Result
df_wi.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_wi['Final_Result (%)']=round((df_wi['candidatevotes']).div(df_wi['Total_State_Votes']) * 100, 2)

# Print
df_wi
df_wi.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#                State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 4267       WISCONSIN  BIDEN, JOSEPH R. JR        DEMOCRAT     1630866
# 4268       WISCONSIN     TRUMP, DONALD J.      REPUBLICAN     1610184
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 4267                 3241050             50.32
# 4268                 3241050             49.68

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_wv = dem_rep_df[dem_rep_df.state=="WEST VIRGINIA"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_wv
df_wv.head()

# Total Votes for Both Parties in Alabama
total_wv = df_wv['candidatevotes'].sum()

# Print
total_wv

# Create New column and Add Result 
df_wv['Total_State_Votes'] = df_wv['candidatevotes'].sum()

# Print
df_wv
df_wv.head()

# Insert New Column for Result
df_wv.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_wv['Final_Result (%)']=round((df_wv['candidatevotes']).div(df_wv['Total_State_Votes']) * 100, 2)

# Print
df_wv
df_wv.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#                    State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 4263       WEST VIRGINIA  BIDEN, JOSEPH R. JR        DEMOCRAT      235984
# 4264       WEST VIRGINIA     TRUMP, DONALD J.      REPUBLICAN      545382
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 4263                  781366              30.2
# 4264                  781366              69.8

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_ne = dem_rep_df[dem_rep_df.state=="NEBRASKA"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_ne
df_ne.head()

# Total Votes for Both Parties in Alabama
total_ne = df_ne['candidatevotes'].sum()

# Print
total_ne

# Create New column and Add Result 
df_ne['Total_State_Votes'] = df_ne['candidatevotes'].sum()

# Print
df_ne
df_ne.head()

# Insert New Column for Result
df_ne.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_ne['Final_Result (%)']=round((df_ne['candidatevotes']).div(df_ne['Total_State_Votes']) * 100, 2)

# Print
df_ne
df_ne.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#               State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 4067       NEBRASKA     TRUMP, DONALD J.      REPUBLICAN      556846
# 4068       NEBRASKA  BIDEN, JOSEPH R. JR        DEMOCRAT      374583
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 4067                  931429             59.78
# 4068                  931429             40.22

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_ok = dem_rep_df[dem_rep_df.state=="OKLAHOMA"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_ok
df_ok.head()

# Total Votes for Both Parties in Alabama
total_ok = df_ok['candidatevotes'].sum()

# Print
total_ok

# Create New column and Add Result 
df_ok['Total_State_Votes'] = df_ok['candidatevotes'].sum()

# Print
df_ok
df_ok.head()

# Insert New Column for Result
df_ok.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_ok['Final_Result (%)']=round((df_ok['candidatevotes']).div(df_ok['Total_State_Votes']) * 100, 2)

# Print
df_ok
df_ok.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#               State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 4158       OKLAHOMA     TRUMP, DONALD J.      REPUBLICAN     1020280
# 4159       OKLAHOMA  BIDEN, JOSEPH R. JR        DEMOCRAT      503890
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 4158                 1524170             66.94
# 4159                 1524170             33.06

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_la = dem_rep_df[dem_rep_df.state=="LOUISIANA"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_la
df_la.head()

# Total Votes for Both Parties in Alabama
total_la = df_la['candidatevotes'].sum()

# Print
total_la

# Create New column and Add Result 
df_la['Total_State_Votes'] = df_la['candidatevotes'].sum()

# Print
df_la
df_la.head()

# Insert New Column for Result
df_la.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_la['Final_Result (%)']=round((df_la['candidatevotes']).div(df_la['Total_State_Votes']) * 100, 2)

# Print
df_la
df_la.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#                State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 3968       LOUISIANA  BIDEN, JOSEPH R. JR        DEMOCRAT      856034
# 3970       LOUISIANA     TRUMP, DONALD J.      REPUBLICAN     1255776
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 3968                 2111810             40.54
# 3970                 2111810             59.46

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_ms = dem_rep_df[dem_rep_df.state=="MISSISSIPPI"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_ms
df_ok.head()

# Total Votes for Both Parties in Alabama
total_ms = df_ms['candidatevotes'].sum()

# Print
total_ms

# Create New column and Add Result 
df_ms['Total_State_Votes'] = df_ms['candidatevotes'].sum()

# Print
df_ms
df_ms.head()

# Insert New Column for Result
df_ms.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_ms['Final_Result (%)']=round((df_ms['candidatevotes']).div(df_ms['Total_State_Votes']) * 100, 2)

# Print
df_ms
df_ms.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#                  State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 4041       MISSISSIPPI  BIDEN, JOSEPH R. JR        DEMOCRAT      539398
# 4042       MISSISSIPPI     TRUMP, DONALD J.      REPUBLICAN      756764
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 4041                 1296162             41.62
# 4042                 1296162             58.38

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_ny = dem_rep_df[dem_rep_df.state=="NEW YORK"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_ny
df_ny.head()

# Total Votes for Both Parties in Alabama
total_ny = df_ny['candidatevotes'].sum()

# Print
total_ny

# Create New column and Add Result 
df_ny['Total_State_Votes'] = df_ny['candidatevotes'].sum()

# Print
df_ny
df_ny.head()

# Insert New Column for Result
df_ny.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_ny['Final_Result (%)']=round((df_ny['candidatevotes']).div(df_ny['Total_State_Votes']) * 100, 2)

# Print
df_ny
df_ny.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#               State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 4113       NEW YORK  BIDEN, JOSEPH R. JR        DEMOCRAT     5230985
# 4114       NEW YORK     TRUMP, DONALD J.      REPUBLICAN     3244798
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 4113                 8475783             61.72
# 4114                 8475783             38.28

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_nj = dem_rep_df[dem_rep_df.state=="NEW JERSEY"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_nj
df_ok.head()

# Total Votes for Both Parties in Alabama
total_nj = df_nj['candidatevotes'].sum()

# Print
total_nj

# Create New column and Add Result 
df_nj['Total_State_Votes'] = df_nj['candidatevotes'].sum()

# Print
df_nj
df_nj.head()

# Insert New Column for Result
df_nj.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_nj['Final_Result (%)']=round((df_nj['candidatevotes']).div(df_nj['Total_State_Votes']) * 100, 2)

# Print
df_nj
df_nj.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#                 State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 4099       NEW JERSEY     TRUMP, DONALD J.      REPUBLICAN     1883274
# 4100       NEW JERSEY  BIDEN, JOSEPH R. JR        DEMOCRAT     2608335
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 4099                 4491609             41.93
# 4100                 4491609             58.07

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_sd = dem_rep_df[dem_rep_df.state=="SOUTH DAKOTA"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_sd
df_sd.head()

# Total Votes for Both Parties in Alabama
total_sd = df_sd['candidatevotes'].sum()

# Print
total_sd

# Create New column and Add Result 
df_sd['Total_State_Votes'] = df_sd['candidatevotes'].sum()

# Print
df_sd
df_sd.head()

# Insert New Column for Result
df_sd.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_sd['Final_Result (%)']=round((df_sd['candidatevotes']).div(df_sd['Total_State_Votes']) * 100, 2)

# Print
df_sd
df_sd.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#                   State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 4185       SOUTH DAKOTA     TRUMP, DONALD J.      REPUBLICAN      261043
# 4186       SOUTH DAKOTA  BIDEN, JOSEPH R. JR        DEMOCRAT      150471
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 4185                  411514             63.43
# 4186                  411514             36.57

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_nd = dem_rep_df[dem_rep_df.state=="NORTH DAKOTA"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_nd
df_nd.head()

# Total Votes for Both Parties in Alabama
total_nd = df_nd['candidatevotes'].sum()

# Print
total_nd

# Create New column and Add Result 
df_nd['Total_State_Votes'] = df_nd['candidatevotes'].sum()

# Print
df_nd
df_nd.head()

# Insert New Column for Result
df_nd.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_nd['Final_Result (%)']=round((df_nd['candidatevotes']).div(df_nd['Total_State_Votes']) * 100, 2)

# Print
df_nd
df_nd.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#                   State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 4144       NORTH DAKOTA     TRUMP, DONALD J.      REPUBLICAN      235595
# 4145       NORTH DAKOTA  BIDEN, JOSEPH R. JR        DEMOCRAT      114902
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 4144                  350497             67.22
# 4145                  350497             32.78

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_nv = dem_rep_df[dem_rep_df.state=="NEVADA"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_nv
df_nv.head()

# Total Votes for Both Parties in Alabama
total_nv = df_nv['candidatevotes'].sum()

# Print
total_nv

# Create New column and Add Result 
df_nv['Total_State_Votes'] = df_nv['candidatevotes'].sum()

# Print
df_nv
df_nv.head()

# Insert New Column for Result
df_nv.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_nv['Final_Result (%)']=round((df_nv['candidatevotes']).div(df_nv['Total_State_Votes']) * 100, 2)

# Print
df_nv
df_nv.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#             State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 4072       NEVADA     TRUMP, DONALD J.      REPUBLICAN      669890
# 4073       NEVADA  BIDEN, JOSEPH R. JR        DEMOCRAT      703486
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 4072                 1373376             48.78
# 4073                 1373376             51.22

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_ca = dem_rep_df[dem_rep_df.state=="CALIFORNIA"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_ca
df_ca.head()

# Total Votes for Both Parties in Alabama
total_ca = df_ca['candidatevotes'].sum()

# Print
total_ca

# Create New column and Add Result 
df_ca['Total_State_Votes'] = df_ca['candidatevotes'].sum()

# Print
df_ca
df_ca.head()

# Insert New Column for Result
df_ca.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_ca['Final_Result (%)']=round((df_ca['candidatevotes']).div(df_ca['Total_State_Votes']) * 100, 2)

# Print
df_ca
df_ca.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#                 State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 3773       CALIFORNIA  BIDEN, JOSEPH R. JR        DEMOCRAT    11110250
# 3774       CALIFORNIA     TRUMP, DONALD J.      REPUBLICAN     6006429
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 3773                17116679             64.91
# 3774                17116679             35.09

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_id = dem_rep_df[dem_rep_df.state=="IDAHO"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_id
df_id.head()

# Total Votes for Both Parties in Alabama
total_id = df_id['candidatevotes'].sum()

# Print
total_id

# Create New column and Add Result 
df_id['Total_State_Votes'] = df_id['candidatevotes'].sum()

# Print
df_id
df_id.head()

# Insert New Column for Result
df_id.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_id['Final_Result (%)']=round((df_id['candidatevotes']).div(df_id['Total_State_Votes']) * 100, 2)

# Print
df_id
df_id.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#            State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 3889       IDAHO  BIDEN, JOSEPH R. JR        DEMOCRAT      287021
# 3890       IDAHO     TRUMP, DONALD J.      REPUBLICAN      554119
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 3889                  841140             34.12
# 3890                  841140             65.88

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_ga = dem_rep_df[dem_rep_df.state=="GEORGIA"][['state','candidate','party_simplified','candidatevotes']]

# Print
df_ga
df_ga.head()

# Total Votes for Both Parties in Alabama
total_ga = df_ga['candidatevotes'].sum()

# Print
total_ga

# Create New column and Add Result 
df_ga['Total_State_Votes'] = df_ga['candidatevotes'].sum()

# Print
df_ga
df_ga.head()

# Insert New Column for Result
df_ga.insert(5, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_ga['Final_Result (%)']=round((df_ga['candidatevotes']).div(df_ga['Total_State_Votes']) * 100, 2)

# Print
df_ga
df_ga.rename(columns = {'state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#              State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 3878       GEORGIA  BIDEN, JOSEPH R. JR        DEMOCRAT     2473633
# 3879       GEORGIA     TRUMP, DONALD J.      REPUBLICAN     2461854
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 3878                 4935487             50.12
# 3879                 4935487             49.88

# %%
bigdata = df_tx.append([df_al,df_tx,df_ak,df_fl,df_wv,df_wi,df_ne,df_mn,df_ok,df_ga,df_ny,df_nj,df_nv,df_id,df_ca,df_la,df_ms], ignore_index=True)

bigdata
# Out:
#             state            candidate party_simplified  candidatevotes  \
# 0           TEXAS     TRUMP, DONALD J.       REPUBLICAN         5890347
# 1           TEXAS  BIDEN, JOSEPH R. JR         DEMOCRAT         5259126
# 2         ALABAMA  BIDEN, JOSEPH R. JR         DEMOCRAT          849624
# 3         ALABAMA     TRUMP, DONALD J.       REPUBLICAN         1441170
# 4           TEXAS     TRUMP, DONALD J.       REPUBLICAN         5890347
# 5           TEXAS  BIDEN, JOSEPH R. JR         DEMOCRAT         5259126
# 6          ALASKA  BIDEN, JOSEPH R. JR         DEMOCRAT          153778
# 7          ALASKA     TRUMP, DONALD J.       REPUBLICAN          189951
# 8         FLORIDA  BIDEN, JOSEPH R. JR         DEMOCRAT         5297045
# 9         FLORIDA     TRUMP, DONALD J.       REPUBLICAN         5668731
# 10  WEST VIRGINIA  BIDEN, JOSEPH R. JR         DEMOCRAT          235984
# 11  WEST VIRGINIA     TRUMP, DONALD J.       REPUBLICAN          545382
# 12      WISCONSIN  BIDEN, JOSEPH R. JR         DEMOCRAT         1630866
# 13      WISCONSIN     TRUMP, DONALD J.       REPUBLICAN         1610184
# 14       NEBRASKA     TRUMP, DONALD J.       REPUBLICAN          556846
# 15       NEBRASKA  BIDEN, JOSEPH R. JR         DEMOCRAT          374583
# 16      MINNESOTA     TRUMP, DONALD J.       REPUBLICAN         1484065
# 17      MINNESOTA  BIDEN, JOSEPH R. JR         DEMOCRAT         1717077
# 18       OKLAHOMA     TRUMP, DONALD J.       REPUBLICAN         1020280
# 19       OKLAHOMA  BIDEN, JOSEPH R. JR         DEMOCRAT          503890
# 20        GEORGIA  BIDEN, JOSEPH R. JR         DEMOCRAT         2473633
# 21        GEORGIA     TRUMP, DONALD J.       REPUBLICAN         2461854
# 22       NEW YORK  BIDEN, JOSEPH R. JR         DEMOCRAT         5230985
# 23       NEW YORK     TRUMP, DONALD J.       REPUBLICAN         3244798
# 24     NEW JERSEY     TRUMP, DONALD J.       REPUBLICAN         1883274
# 25     NEW JERSEY  BIDEN, JOSEPH R. JR         DEMOCRAT         2608335
# 26         NEVADA     TRUMP, DONALD J.       REPUBLICAN          669890
# 27         NEVADA  BIDEN, JOSEPH R. JR         DEMOCRAT          703486
# 28          IDAHO  BIDEN, JOSEPH R. JR         DEMOCRAT          287021
# 29          IDAHO     TRUMP, DONALD J.       REPUBLICAN          554119
# 30     CALIFORNIA  BIDEN, JOSEPH R. JR         DEMOCRAT        11110250
# 31     CALIFORNIA     TRUMP, DONALD J.       REPUBLICAN         6006429
# 32      LOUISIANA  BIDEN, JOSEPH R. JR         DEMOCRAT          856034
# 33      LOUISIANA     TRUMP, DONALD J.       REPUBLICAN         1255776
# 34    MISSISSIPPI  BIDEN, JOSEPH R. JR         DEMOCRAT          539398
# 35    MISSISSIPPI     TRUMP, DONALD J.       REPUBLICAN          756764
#
#     Total_State_Votes  Final_Result (%)
# 0            11149473             52.83
# 1            11149473             47.17
# 2             2290794             37.09
# 3             2290794             62.91
# 4            11149473             52.83
# 5            11149473             47.17
# 6              343729             44.74
# 7              343729             55.26
# 8            10965776             48.31
# 9            10965776             51.69
# 10             781366             30.20
# 11             781366             69.80
# 12            3241050             50.32
# 13            3241050             49.68
# 14             931429             59.78
# 15             931429             40.22
# 16            3201142             46.36
# 17            3201142             53.64
# 18            1524170             66.94
# 19            1524170             33.06
# 20            4935487             50.12
# 21            4935487             49.88
# 22            8475783             61.72
# 23            8475783             38.28
# 24            4491609             41.93
# 25            4491609             58.07
# 26            1373376             48.78
# 27            1373376             51.22
# 28             841140             34.12
# 29             841140             65.88
# 30           17116679             64.91
# 31           17116679             35.09
# 32            2111810             40.54
# 33            2111810             59.46
# 34            1296162             41.62
# 35            1296162             58.38

# %%
# Retrieve Data of COVID Cases and Deaths Per State
url = "https://data.cdc.gov/resource/9mfq-cb36.json"

# Print Query_URL
query_url = f"{url}"

# print
print(query_url)

# vacc_response = requests.get(query_url2)
st_case_death_json = requests.get(url).json()

# Print
st_case_death_json
# Out:
# https://data.cdc.gov/resource/9mfq-cb36.json
# [{'submission_date': '2020-05-04T00:00:00.000',
#   'state': 'KY',
#   'tot_cases': '5245',
#   'conf_cases': '5245.0',
#   'prob_cases': '0',
#   'new_case': '115.0',
#   'pnew_case': '0',
#   'tot_death': '261',
#   'conf_death': '261.0',
#   'prob_death': '0',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-05T17:25:08.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-23T00:00:00.000',
#   'state': 'NH',
#   'tot_cases': '101',
#   'new_case': '23.0',
#   'tot_death': '1',
#   'new_death': '1.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-04-11T00:00:00.000',
#   'state': 'IL',
#   'tot_cases': '19180',
#   'new_case': '1293.0',
#   'tot_death': '677',
#   'new_death': '81.0',
#   'created_at': '2020-04-10T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-01T00:00:00.000',
#   'state': 'FL',
#   'tot_cases': '1300528',
#   'new_case': '0.0',
#   'pnew_case': '6063',
#   'tot_death': '21673',
#   'new_death': '0.0',
#   'pnew_death': '7',
#   'created_at': '2021-01-02T14:50:51.219',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-04-09T00:00:00.000',
#   'state': 'PA',
#   'tot_cases': '18228',
#   'new_case': '1989.0',
#   'tot_death': '338',
#   'new_death': '28.0',
#   'created_at': '2020-04-08T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-08-21T00:00:00.000',
#   'state': 'MD',
#   'tot_cases': '103523',
#   'new_case': '624.0',
#   'pnew_case': '0',
#   'tot_death': '3685',
#   'conf_death': '3546.0',
#   'prob_death': '139',
#   'new_death': '11.0',
#   'pnew_death': '1',
#   'created_at': '2020-08-22T14:21:09.869',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-30T00:00:00.000',
#   'state': 'IA',
#   'tot_cases': '7145',
#   'new_case': '302.0',
#   'pnew_case': '0',
#   'tot_death': '162',
#   'new_death': '14.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-01T21:00:19.025',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-26T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-12T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '29',
#   'new_case': '6.0',
#   'tot_death': '1',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-21T00:00:00.000',
#   'state': 'MP',
#   'tot_cases': '69',
#   'conf_cases': '69.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '2',
#   'conf_death': '2.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-22T13:51:57.795',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-25T00:00:00.000',
#   'state': 'NE',
#   'tot_cases': '18346',
#   'new_case': '125.0',
#   'pnew_case': '0',
#   'tot_death': '260',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-26T19:18:27.809',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-24T00:00:00.000',
#   'state': 'CA',
#   'tot_cases': '10',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-06-28T00:00:00.000',
#   'state': 'PA',
#   'tot_cases': '85988',
#   'conf_cases': '83529.0',
#   'prob_cases': '2459',
#   'new_case': '492.0',
#   'pnew_case': '13',
#   'tot_death': '6614',
#   'new_death': '8.0',
#   'pnew_death': '4',
#   'created_at': '2020-06-29T14:37:31.240',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-05-04T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '1224',
#   'conf_cases': '1224.0',
#   'prob_cases': '0',
#   'new_case': '29.0',
#   'pnew_case': '0',
#   'tot_death': '50',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-05T17:25:08.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-04-07T00:00:00.000',
#   'state': 'GU',
#   'tot_cases': '122',
#   'new_case': '11.0',
#   'tot_death': '4',
#   'new_death': '0.0',
#   'created_at': '2020-04-07T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-01T00:00:00.000',
#   'state': 'FSM',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-02T15:10:03.527',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-02T00:00:00.000',
#   'state': 'NY',
#   'tot_cases': '346492',
#   'new_case': '5775.0',
#   'pnew_case': '0',
#   'tot_death': '10117',
#   'new_death': '56.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-03T15:21:08.669',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-01-23T00:00:00.000',
#   'state': 'WY',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-14T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '295012',
#   'new_case': '4856.0',
#   'pnew_case': '503',
#   'tot_death': '16548',
#   'conf_death': '14747.0',
#   'prob_death': '1801',
#   'new_death': '26.0',
#   'pnew_death': '0',
#   'created_at': '2021-02-19T13:38:31.100',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-15T00:00:00.000',
#   'state': 'WA',
#   'tot_cases': '130040',
#   'new_case': '2309.0',
#   'pnew_case': '0',
#   'tot_death': '2519',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-16T18:40:02.302',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-01-29T00:00:00.000',
#   'state': 'MA',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-23T00:00:00.000',
#   'state': 'TN',
#   'tot_cases': '143937',
#   'conf_cases': '141000.0',
#   'prob_cases': '2937',
#   'new_case': '1854.0',
#   'pnew_case': '38',
#   'tot_death': '1567',
#   'conf_death': '1527.0',
#   'prob_death': '40',
#   'new_death': '4.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-24T13:54:34.344',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-24T00:00:00.000',
#   'state': 'NH',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-06-21T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '6937',
#   'conf_cases': '6700.0',
#   'prob_cases': '237',
#   'new_case': '187.0',
#   'pnew_case': '237',
#   'tot_death': '190',
#   'conf_death': '188.0',
#   'prob_death': '2',
#   'new_death': '1.0',
#   'pnew_death': '2',
#   'created_at': '2020-06-22T15:24:02.542',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-26T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-27T13:39:49.124'},
#  {'submission_date': '2020-05-16T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-17T15:27:46.000'},
#  {'submission_date': '2020-03-13T00:00:00.000',
#   'state': 'MS',
#   'tot_cases': '1',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-08T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-09T13:47:50.836'},
#  {'submission_date': '2020-05-26T00:00:00.000',
#   'state': 'MA',
#   'tot_cases': '93693',
#   'conf_cases': '93693.0',
#   'prob_cases': '0',
#   'new_case': '422.0',
#   'pnew_case': '0',
#   'tot_death': '6473',
#   'conf_death': '6473.0',
#   'prob_death': '0',
#   'new_death': '57.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-27T15:37:59.621',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-29T00:00:00.000',
#   'state': 'NV',
#   'tot_cases': '46021',
#   'new_case': '870.0',
#   'pnew_case': '0',
#   'tot_death': '806',
#   'new_death': '21.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-30T14:42:43.801'},
#  {'submission_date': '2020-08-01T00:00:00.000',
#   'state': 'ME',
#   'tot_cases': '3958',
#   'conf_cases': '3535.0',
#   'prob_cases': '423',
#   'new_case': '21.0',
#   'pnew_case': '2',
#   'tot_death': '123',
#   'conf_death': '122.0',
#   'prob_death': '1',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-02T14:54:37.126',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-28T00:00:00.000',
#   'state': 'NH',
#   'tot_cases': '214',
#   'new_case': '27.0',
#   'tot_death': '2',
#   'new_death': '0.0',
#   'created_at': '2020-03-28T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-05-04T00:00:00.000',
#   'state': 'MP',
#   'tot_cases': '14',
#   'conf_cases': '14.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '2',
#   'conf_death': '2.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-05T17:25:08.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-02T00:00:00.000',
#   'state': 'AR',
#   'tot_cases': '161521',
#   'new_case': '2212.0',
#   'pnew_case': '705',
#   'tot_death': '2522',
#   'new_death': '10.0',
#   'pnew_death': '2',
#   'created_at': '2020-12-03T15:21:08.669',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-06-07T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-08T14:55:08.000'},
#  {'submission_date': '2020-05-08T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '135519',
#   'new_case': '1834.0',
#   'pnew_case': '15',
#   'tot_death': '8952',
#   'conf_death': '8952.0',
#   'prob_death': '0',
#   'new_death': '151.0',
#   'pnew_death': '0',
#   'created_at': '2021-02-19T13:38:31.100',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-14T00:00:00.000',
#   'state': 'VA',
#   'tot_cases': '28672',
#   'conf_cases': '27293.0',
#   'prob_cases': '1379',
#   'new_case': '859.0',
#   'pnew_case': '35',
#   'tot_death': '977',
#   'conf_death': '944.0',
#   'prob_death': '33',
#   'new_death': '22.0',
#   'pnew_death': '5',
#   'created_at': '2020-05-15T16:11:22.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-09T00:00:00.000',
#   'state': 'AR',
#   'tot_cases': '251746',
#   'new_case': '2886.0',
#   'pnew_case': '735',
#   'tot_death': '4010',
#   'new_death': '44.0',
#   'pnew_death': '10',
#   'created_at': '2021-01-10T16:10:55.461',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-03-15T00:00:00.000',
#   'state': 'MA',
#   'tot_cases': '164',
#   'new_case': '55.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-28T00:00:00.000',
#   'state': 'IL',
#   'tot_cases': '115833',
#   'conf_cases': '115833.0',
#   'prob_cases': '0',
#   'new_case': '1527.0',
#   'pnew_case': '0',
#   'tot_death': '5186',
#   'conf_death': '5186.0',
#   'prob_death': '0',
#   'new_death': '103.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-29T14:19:55.781',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-05T00:00:00.000',
#   'state': 'WY',
#   'tot_cases': '2923',
#   'conf_cases': '2424.0',
#   'prob_cases': '499',
#   'new_case': '39.0',
#   'pnew_case': '7',
#   'tot_death': '27',
#   'conf_death': '27.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-06T14:12:27.571',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-28T00:00:00.000',
#   'state': 'ID',
#   'tot_cases': '61785',
#   'conf_cases': '54193.0',
#   'prob_cases': '7592',
#   'new_case': '862.0',
#   'pnew_case': '208',
#   'tot_death': '599',
#   'conf_death': '555.0',
#   'prob_death': '44',
#   'new_death': '14.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-29T14:11:33.577',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-31T00:00:00.000',
#   'state': 'DC',
#   'tot_cases': '8801',
#   'new_case': '84.0',
#   'pnew_case': '0',
#   'tot_death': '466',
#   'new_death': '4.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-01T14:17:42.906'},
#  {'submission_date': '2020-08-18T00:00:00.000',
#   'state': 'AZ',
#   'tot_cases': '194920',
#   'conf_cases': '193416.0',
#   'prob_cases': '1504',
#   'new_case': '915.0',
#   'pnew_case': '13',
#   'tot_death': '4529',
#   'conf_death': '4273.0',
#   'prob_death': '256',
#   'new_death': '23.0',
#   'pnew_death': '2',
#   'created_at': '2020-08-19T14:23:51.835',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-12T00:00:00.000',
#   'state': 'DE',
#   'tot_cases': '12879',
#   'conf_cases': '11898.0',
#   'prob_cases': '981',
#   'new_case': '-99.0',
#   'pnew_case': '-63',
#   'tot_death': '517',
#   'conf_death': '459.0',
#   'prob_death': '58',
#   'new_death': '-1.0',
#   'pnew_death': '1',
#   'created_at': '2020-07-13T15:19:34.972',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-19T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '110759',
#   'new_case': '1076.0',
#   'pnew_case': '0',
#   'tot_death': '3503',
#   'conf_death': '3278.0',
#   'prob_death': '225',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-20T13:53:10.094',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-29T00:00:00.000',
#   'state': 'MP',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-09T00:00:00.000',
#   'state': 'NV',
#   'tot_cases': '10030',
#   'new_case': '225.0',
#   'pnew_case': '-19',
#   'tot_death': '444',
#   'new_death': '-17.0',
#   'pnew_death': '-19',
#   'created_at': '2020-06-10T20:56:25.490'},
#  {'submission_date': '2020-10-14T00:00:00.000',
#   'state': 'DE',
#   'tot_cases': '22465',
#   'conf_cases': '21380.0',
#   'prob_cases': '1085',
#   'new_case': '71.0',
#   'pnew_case': '2',
#   'tot_death': '660',
#   'conf_death': '580.0',
#   'prob_death': '80',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-15T13:30:46.649',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-22T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '3864',
#   'conf_cases': '3770.0',
#   'prob_cases': '94',
#   'new_case': '47.0',
#   'pnew_case': '2',
#   'tot_death': '147',
#   'conf_death': '147.0',
#   'prob_death': '0',
#   'new_death': '2.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-23T17:58:16.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-08T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-18T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '75',
#   'new_case': '10.0',
#   'tot_death': '3',
#   'new_death': '2.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-14T00:00:00.000',
#   'state': 'RI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2021-01-30T00:00:00.000',
#   'state': 'FSM',
#   'tot_cases': '1',
#   'conf_cases': '1.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-31T14:48:12.513',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-23T00:00:00.000',
#   'state': 'ME',
#   'tot_cases': '109',
#   'new_case': '16.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-02-11T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '149082',
#   'conf_cases': '147362.0',
#   'prob_cases': '1720',
#   'new_case': '607.0',
#   'pnew_case': '0',
#   'tot_death': '2056',
#   'conf_death': '2041.0',
#   'prob_death': '15',
#   'new_death': '12.0',
#   'pnew_death': '0',
#   'created_at': '2021-02-12T14:56:38.403',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-04T00:00:00.000',
#   'state': 'PR',
#   'tot_cases': '55532',
#   'conf_cases': '53633.0',
#   'prob_cases': '1899',
#   'new_case': '935.0',
#   'pnew_case': '86',
#   'tot_death': '1184',
#   'conf_death': '955.0',
#   'prob_death': '229',
#   'new_death': '12.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-05T14:29:17.537',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-22T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '95865',
#   'conf_cases': '95865.0',
#   'prob_cases': '0',
#   'new_case': '3478.0',
#   'pnew_case': '0',
#   'tot_death': '5063',
#   'conf_death': '5063.0',
#   'prob_death': '0',
#   'new_death': '310.0',
#   'pnew_death': '0',
#   'created_at': '2020-04-22T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-02-07T00:00:00.000',
#   'state': 'RMI',
#   'tot_cases': '4',
#   'conf_cases': '4.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-02-08T14:53:12.094',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-06T00:00:00.000',
#   'state': 'MT',
#   'tot_cases': '15723',
#   'conf_cases': '15723.0',
#   'prob_cases': '0',
#   'new_case': '425.0',
#   'pnew_case': '0',
#   'tot_death': '192',
#   'conf_death': '192.0',
#   'prob_death': '0',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-07T13:45:01.309',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-03T00:00:00.000',
#   'state': 'NY',
#   'tot_cases': '248091',
#   'new_case': '1519.0',
#   'pnew_case': '0',
#   'tot_death': '9290',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-04T15:03:00.406',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-14T00:00:00.000',
#   'state': 'MS',
#   'tot_cases': '37542',
#   'conf_cases': '37198.0',
#   'prob_cases': '344',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '1272',
#   'conf_death': '1249.0',
#   'prob_death': '23',
#   'new_death': '-1.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-15T15:05:12.266',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-23T00:00:00.000',
#   'state': 'NE',
#   'tot_cases': '42278',
#   'new_case': '493.0',
#   'pnew_case': '0',
#   'tot_death': '462',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-24T13:54:02.843',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-08-13T00:00:00.000',
#   'state': 'VT',
#   'tot_cases': '1484',
#   'new_case': '6.0',
#   'pnew_case': '0',
#   'tot_death': '58',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-14T14:30:03.326',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-06-18T00:00:00.000',
#   'state': 'WA',
#   'tot_cases': '27192',
#   'new_case': '408.0',
#   'pnew_case': '0',
#   'tot_death': '1245',
#   'new_death': '19.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-19T15:01:11.041',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-02-27T00:00:00.000',
#   'state': 'ND',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-12-06T00:00:00.000',
#   'state': 'AK',
#   'tot_cases': '35720',
#   'new_case': '757.0',
#   'pnew_case': '0',
#   'tot_death': '142',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-07T14:38:33.257',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2021-01-12T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '3',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-13T14:44:58.633'},
#  {'submission_date': '2020-03-17T00:00:00.000',
#   'state': 'NM',
#   'tot_cases': '23',
#   'new_case': '2.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-08-31T00:00:00.000',
#   'state': 'KS',
#   'tot_cases': '42612',
#   'conf_cases': '41425.0',
#   'prob_cases': '1187',
#   'new_case': '1564.0',
#   'pnew_case': '0',
#   'tot_death': '446',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-01T14:09:34.811',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-03-11T00:00:00.000',
#   'state': 'NY',
#   'tot_cases': '164',
#   'new_case': '27.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-28T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-29T00:00:00.000',
#   'state': 'TX',
#   'tot_cases': '1715978',
#   'new_case': '32552.0',
#   'pnew_case': '4532',
#   'tot_death': '26762',
#   'new_death': '241.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-30T14:56:20.759',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-11-17T00:00:00.000',
#   'state': 'OK',
#   'tot_cases': '169762',
#   'conf_cases': '143221.0',
#   'prob_cases': '26541',
#   'new_case': '7389.0',
#   'pnew_case': '1406',
#   'tot_death': '1592',
#   'conf_death': '1531.0',
#   'prob_death': '61',
#   'new_death': '49.0',
#   'pnew_death': '6',
#   'created_at': '2020-11-18T14:57:46.366',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-12T00:00:00.000',
#   'state': 'IA',
#   'tot_cases': '298406',
#   'new_case': '1105.0',
#   'pnew_case': '460',
#   'tot_death': '4222',
#   'new_death': '83.0',
#   'pnew_death': '83',
#   'created_at': '2021-01-13T14:44:58.633',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-03-09T00:00:00.000',
#   'state': 'NYC',
#   'tot_cases': '17',
#   'new_case': '5.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-11T00:00:00.000',
#   'state': 'ND',
#   'tot_cases': '94968',
#   'conf_cases': '91357.0',
#   'prob_cases': '3611',
#   'new_case': '138.0',
#   'pnew_case': '89',
#   'tot_death': '1355',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-12T14:48:35.544',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-12-15T00:00:00.000',
#   'state': 'FSM',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-16T14:28:57.146',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-23T00:00:00.000',
#   'state': 'MP',
#   'tot_cases': '38',
#   'conf_cases': '38.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '2',
#   'conf_death': '2.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-24T14:18:40.590',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-30T00:00:00.000',
#   'state': 'TN',
#   'tot_cases': '259488',
#   'conf_cases': '244886.0',
#   'prob_cases': '14602',
#   'new_case': '2608.0',
#   'pnew_case': '297',
#   'tot_death': '3341',
#   'conf_death': '3156.0',
#   'prob_death': '185',
#   'new_death': '78.0',
#   'pnew_death': '9',
#   'created_at': '2020-10-31T13:30:31.395',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-02T00:00:00.000',
#   'state': 'HI',
#   'tot_cases': '956',
#   'new_case': '28.0',
#   'pnew_case': '0',
#   'tot_death': '18',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-03T11:01:33.000',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-10-28T00:00:00.000',
#   'state': 'AR',
#   'tot_cases': '108640',
#   'new_case': '961.0',
#   'pnew_case': '271',
#   'tot_death': '1875',
#   'new_death': '18.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-29T14:11:33.577',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-09-07T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '11575',
#   'conf_cases': '11368.0',
#   'prob_cases': '207',
#   'new_case': '163.0',
#   'pnew_case': '9',
#   'tot_death': '247',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-08T14:47:00.875',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-31T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '66154',
#   'new_case': '901.0',
#   'pnew_case': '0',
#   'tot_death': '2965',
#   'conf_death': '2765.0',
#   'prob_death': '200',
#   'new_death': '19.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-01T14:38:12.337',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-22T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '21057',
#   'conf_cases': '19907.0',
#   'prob_cases': '1150',
#   'new_case': '323.0',
#   'pnew_case': '80',
#   'tot_death': '418',
#   'new_death': '5.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-23T13:44:31.471',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-01-27T00:00:00.000',
#   'state': 'AL',
#   'tot_cases': '449086',
#   'conf_cases': '354967.0',
#   'prob_cases': '94119',
#   'new_case': '3177.0',
#   'pnew_case': '1128',
#   'tot_death': '7172',
#   'conf_death': '5817.0',
#   'prob_death': '1355',
#   'new_death': '276.0',
#   'pnew_death': '97',
#   'created_at': '2021-01-28T14:49:07.741',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-21T00:00:00.000',
#   'state': 'KS',
#   'tot_cases': '36856',
#   'conf_cases': '35895.0',
#   'prob_cases': '961',
#   'new_case': '966.0',
#   'pnew_case': '13',
#   'tot_death': '419',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-22T14:21:09.869',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-11-27T00:00:00.000',
#   'state': 'KS',
#   'tot_cases': '153021',
#   'conf_cases': '132785.0',
#   'prob_cases': '20236',
#   'new_case': '5224.0',
#   'pnew_case': '588',
#   'tot_death': '1529',
#   'new_death': '26.0',
#   'pnew_death': '5',
#   'created_at': '2020-11-28T14:46:47.693',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-08-17T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-18T14:26:55.280'},
#  {'submission_date': '2021-01-23T00:00:00.000',
#   'state': 'AL',
#   'tot_cases': '439442',
#   'conf_cases': '348017.0',
#   'prob_cases': '91425',
#   'new_case': '3355.0',
#   'pnew_case': '1015',
#   'tot_death': '6657',
#   'conf_death': '5464.0',
#   'prob_death': '1193',
#   'new_death': '171.0',
#   'pnew_death': '57',
#   'created_at': '2021-01-24T14:36:49.208',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-29T00:00:00.000',
#   'state': 'HI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-09T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-08-02T00:00:00.000',
#   'state': 'VT',
#   'tot_cases': '1426',
#   'new_case': '5.0',
#   'pnew_case': '0',
#   'tot_death': '57',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-03T14:31:01.928',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-06-23T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-24T15:03:27.381'},
#  {'submission_date': '2020-09-06T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '55347',
#   'conf_cases': '54878.0',
#   'prob_cases': '469',
#   'new_case': '341.0',
#   'pnew_case': '3',
#   'tot_death': '421',
#   'conf_death': '421.0',
#   'prob_death': '0',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-07T13:37:36.613',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-23T00:00:00.000',
#   'state': 'MN',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-24T00:00:00.000',
#   'state': 'MD',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-06T00:00:00.000',
#   'state': 'NM',
#   'tot_cases': '52394',
#   'new_case': '1284.0',
#   'pnew_case': '0',
#   'tot_death': '1088',
#   'new_death': '6.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-07T14:45:17.940',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-01-05T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '288951',
#   'conf_cases': '288951.0',
#   'prob_cases': '0',
#   'new_case': '3318.0',
#   'pnew_case': '0',
#   'tot_death': '1312',
#   'conf_death': '1283.0',
#   'prob_death': '29',
#   'new_death': '7.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-06T14:58:26.308',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-09T00:00:00.000',
#   'state': 'ND',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-03-12T00:00:00.000',
#   'state': 'PR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-19T00:00:00.000',
#   'state': 'FL',
#   'tot_cases': '673194',
#   'new_case': '3510.0',
#   'pnew_case': '339',
#   'tot_death': '13287',
#   'new_death': '62.0',
#   'pnew_death': '9',
#   'created_at': '2020-09-20T13:53:10.094',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-09-23T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '113337',
#   'new_case': '711.0',
#   'pnew_case': '0',
#   'tot_death': '3530',
#   'conf_death': '3305.0',
#   'prob_death': '225',
#   'new_death': '10.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-24T13:54:02.843',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-12T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '200405',
#   'new_case': '476.0',
#   'pnew_case': '27',
#   'tot_death': '16027',
#   'conf_death': '14238.0',
#   'prob_death': '1789',
#   'new_death': '4.0',
#   'pnew_death': '0',
#   'created_at': '2021-02-19T13:38:31.100',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-19T00:00:00.000',
#   'state': 'FL',
#   'tot_cases': '25598',
#   'new_case': '801.0',
#   'pnew_case': '0',
#   'tot_death': '774',
#   'new_death': '26.0',
#   'pnew_death': '0',
#   'created_at': '2020-04-19T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-10-10T00:00:00.000',
#   'state': 'AL',
#   'tot_cases': '164526',
#   'conf_cases': '144901.0',
#   'prob_cases': '19625',
#   'new_case': '1061.0',
#   'pnew_case': '60',
#   'tot_death': '2664',
#   'conf_death': '2508.0',
#   'prob_death': '156',
#   'new_death': '11.0',
#   'pnew_death': '-1',
#   'created_at': '2020-10-11T13:47:22.472',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-15T00:00:00.000',
#   'state': 'KS',
#   'tot_cases': '7886',
#   'conf_cases': '7886.0',
#   'prob_cases': '0',
#   'new_case': '418.0',
#   'pnew_case': '0',
#   'tot_death': '172',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-16T15:46:44.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-12-26T00:00:00.000',
#   'state': 'FSM',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-27T14:44:47.209',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-12T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-05T00:00:00.000',
#   'state': 'NV',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
#  {'submission_date': '2020-04-28T00:00:00.000',
#   'state': 'DE',
#   'tot_cases': '4655',
#   'conf_cases': '4526.0',
#   'prob_cases': '129',
#   'new_case': '80.0',
#   'pnew_case': '0',
#   'tot_death': '144',
#   'conf_death': '133.0',
#   'prob_death': '11',
#   'new_death': '7.0',
#   'pnew_death': '0',
#   'created_at': '2020-04-29T18:12:08.477',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-07T00:00:00.000',
#   'state': 'PA',
#   'tot_cases': '166552',
#   'conf_cases': '160772.0',
#   'prob_cases': '5780',
#   'new_case': '1309.0',
#   'pnew_case': '127',
#   'tot_death': '8272',
#   'new_death': '28.0',
#   'pnew_death': '-16',
#   'created_at': '2020-10-08T13:56:57.885',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-10-20T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '96643',
#   'conf_cases': '96643.0',
#   'prob_cases': '0',
#   'new_case': '1081.0',
#   'pnew_case': '0',
#   'tot_death': '551',
#   'conf_death': '546.0',
#   'prob_death': '5',
#   'new_death': '5.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-21T13:34:31.370',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-26T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-16T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '821507',
#   'conf_cases': '725111.0',
#   'prob_cases': '96396',
#   'new_case': '7065.0',
#   'pnew_case': '1596',
#   'tot_death': '10135',
#   'conf_death': '9080.0',
#   'prob_death': '1055',
#   'new_death': '78.0',
#   'pnew_death': '28',
#   'created_at': '2021-01-17T15:43:14.832',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-19T00:00:00.000',
#   'state': 'VT',
#   'tot_cases': '6343',
#   'new_case': '100.0',
#   'pnew_case': '2',
#   'tot_death': '108',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-20T14:32:33.200',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-02-14T00:00:00.000',
#   'state': 'AR',
#   'tot_cases': '313028',
#   'new_case': '466.0',
#   'pnew_case': '33',
#   'tot_death': '5265',
#   'new_death': '13.0',
#   'pnew_death': '2',
#   'created_at': '2021-02-15T14:46:24.739',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-30T00:00:00.000',
#   'state': 'CO',
#   'tot_cases': '46204',
#   'conf_cases': '43032.0',
#   'prob_cases': '3172',
#   'new_case': '408.0',
#   'pnew_case': '2',
#   'tot_death': '1822',
#   'conf_death': '1483.0',
#   'prob_death': '339',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-31T14:35:06.518',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-15T00:00:00.000',
#   'state': 'MT',
#   'tot_cases': '5659',
#   'conf_cases': '5659.0',
#   'prob_cases': '0',
#   'new_case': '118.0',
#   'pnew_case': '0',
#   'tot_death': '82',
#   'conf_death': '82.0',
#   'prob_death': '0',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-16T14:57:14.578',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-02T00:00:00.000',
#   'state': 'PA',
#   'tot_cases': '657292',
#   'conf_cases': '589213.0',
#   'prob_cases': '68079',
#   'new_case': '9253.0',
#   'pnew_case': '1300',
#   'tot_death': '16239',
#   'new_death': '25.0',
#   'pnew_death': '23',
#   'created_at': '2021-01-03T14:53:25.031',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-05-05T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '21033',
#   'new_case': '526.0',
#   'pnew_case': '0',
#   'tot_death': '1326',
#   'conf_death': '1213.0',
#   'prob_death': '113',
#   'new_death': '62.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-06T16:23:08.000',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-28T00:00:00.000',
#   'state': 'RMI',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-29T13:42:50.366',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-26T00:00:00.000',
#   'state': 'DC',
#   'tot_cases': '27710',
#   'new_case': '274.0',
#   'pnew_case': '0',
#   'tot_death': '762',
#   'new_death': '6.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-27T14:44:47.209'},
#  {'submission_date': '2020-03-25T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '704',
#   'new_case': '140.0',
#   'tot_death': '10',
#   'new_death': '2.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-11T00:00:00.000',
#   'state': 'TX',
#   'tot_cases': '792478',
#   'new_case': '2418.0',
#   'pnew_case': '0',
#   'tot_death': '16557',
#   'new_death': '31.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-12T14:07:08.478',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-01T00:00:00.000',
#   'state': 'WI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-10T00:00:00.000',
#   'state': 'WA',
#   'tot_cases': '78467',
#   'new_case': '458.0',
#   'pnew_case': '0',
#   'tot_death': '1985',
#   'new_death': '7.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-11T13:51:03.398',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-02-10T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-17T00:00:00.000',
#   'state': 'FSM',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-04-17T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-20T00:00:00.000',
#   'state': 'MP',
#   'tot_cases': '38',
#   'conf_cases': '38.0',
#   'prob_cases': '0',
#   'new_case': '1.0',
#   'pnew_case': '0',
#   'tot_death': '2',
#   'conf_death': '2.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-21T14:50:17.717',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-05T00:00:00.000',
#   'state': 'CT',
#   'tot_cases': '46717',
#   'conf_cases': '44741.0',
#   'prob_cases': '1976',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '4335',
#   'conf_death': '3463.0',
#   'prob_death': '872',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-06T15:16:12.497',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-22T00:00:00.000',
#   'state': 'PA',
#   'tot_cases': '479',
#   'new_case': '108.0',
#   'tot_death': '2',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-01-06T00:00:00.000',
#   'state': 'TN',
#   'tot_cases': '625237',
#   'conf_cases': '542490.0',
#   'prob_cases': '82747',
#   'new_case': '7588.0',
#   'pnew_case': '2226',
#   'tot_death': '7381',
#   'conf_death': '6326.0',
#   'prob_death': '1055',
#   'new_death': '114.0',
#   'pnew_death': '29',
#   'created_at': '2021-01-07T14:56:59.705',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-06T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-07T14:45:17.940'},
#  {'submission_date': '2020-08-01T00:00:00.000',
#   'state': 'AZ',
#   'tot_cases': '177022',
#   'conf_cases': '177022.0',
#   'prob_cases': '0',
#   'new_case': '3012.0',
#   'pnew_case': '0',
#   'tot_death': '3747',
#   'conf_death': '3747.0',
#   'prob_death': '0',
#   'new_death': '53.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-02T14:54:37.126',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-08T00:00:00.000',
#   'state': 'TN',
#   'tot_cases': '209447',
#   'conf_cases': '200103.0',
#   'prob_cases': '9344',
#   'new_case': '1992.0',
#   'pnew_case': '294',
#   'tot_death': '2705',
#   'conf_death': '2591.0',
#   'prob_death': '114',
#   'new_death': '63.0',
#   'pnew_death': '2',
#   'created_at': '2020-10-09T13:43:36.023',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-14T00:00:00.000',
#   'state': 'HI',
#   'tot_cases': '524',
#   'new_case': '11.0',
#   'pnew_case': '0',
#   'tot_death': '9',
#   'new_death': '0.0',
#   'created_at': '2020-04-13T12:22:39.000',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-30T00:00:00.000',
#   'state': 'KS',
#   'tot_cases': '26870',
#   'conf_cases': '26327.0',
#   'prob_cases': '543',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '349',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-31T14:35:06.518',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-09-27T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '21541',
#   'new_case': '408.0',
#   'pnew_case': '0',
#   'tot_death': '218',
#   'conf_death': '216.0',
#   'prob_death': '2',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-28T13:50:59.474',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-22T00:00:00.000',
#   'state': 'CO',
#   'tot_cases': '41698',
#   'conf_cases': '38562.0',
#   'prob_cases': '3136',
#   'new_case': '639.0',
#   'pnew_case': '24',
#   'tot_death': '1771',
#   'conf_death': '1435.0',
#   'prob_death': '336',
#   'new_death': '8.0',
#   'pnew_death': '3',
#   'created_at': '2020-07-23T14:48:19.028',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-26T00:00:00.000',
#   'state': 'PR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-14T00:00:00.000',
#   'state': 'TN',
#   'tot_cases': '670482',
#   'conf_cases': '576406.0',
#   'prob_cases': '94076',
#   'new_case': '4983.0',
#   'pnew_case': '1196',
#   'tot_death': '8232',
#   'conf_death': '6909.0',
#   'prob_death': '1323',
#   'new_death': '84.0',
#   'pnew_death': '31',
#   'created_at': '2021-01-15T14:46:04.456',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-18T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '1542',
#   'new_case': '131.0',
#   'tot_death': '7',
#   'new_death': '0.0',
#   'created_at': '2020-04-18T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-01T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '18743',
#   'conf_cases': '17962.0',
#   'prob_cases': '781',
#   'new_case': '716.0',
#   'pnew_case': '39',
#   'tot_death': '1002',
#   'conf_death': '922.0',
#   'prob_death': '80',
#   'new_death': '27.0',
#   'pnew_death': '3',
#   'created_at': '2020-05-02T15:47:19.352',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-11T00:00:00.000',
#   'state': 'NYC',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-02T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-08T00:00:00.000',
#   'state': 'DC',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
#  {'submission_date': '2020-12-13T00:00:00.000',
#   'state': 'IL',
#   'tot_cases': '848904',
#   'conf_cases': '848904.0',
#   'prob_cases': '0',
#   'new_case': '7216.0',
#   'pnew_case': '0',
#   'tot_death': '15339',
#   'conf_death': '14291.0',
#   'prob_death': '1048',
#   'new_death': '107.0',
#   'pnew_death': '-8',
#   'created_at': '2020-12-14T14:36:45.302',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-18T00:00:00.000',
#   'state': 'AR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-03-20T00:00:00.000',
#   'state': 'NH',
#   'tot_cases': '55',
#   'new_case': '11.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-23T00:00:00.000',
#   'state': 'DC',
#   'tot_cases': '11571',
#   'new_case': '42.0',
#   'pnew_case': '0',
# ...
#   'tot_cases': '457779',
#   'new_case': '1249.0',
#   'pnew_case': '0',
#   'tot_death': '6748',
#   'new_death': '9.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-30T14:43:11.492',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-10T00:00:00.000',
#   'state': 'NH',
#   'tot_cases': '5991',
#   'new_case': '18.0',
#   'pnew_case': '0',
#   'tot_death': '390',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-11T18:25:05.541',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-10-25T00:00:00.000',
#   'state': 'MS',
#   'tot_cases': '115763',
#   'conf_cases': '102211.0',
#   'prob_cases': '13552',
#   'new_case': '447.0',
#   'pnew_case': '107',
#   'tot_death': '3263',
#   'conf_death': '2951.0',
#   'prob_death': '312',
#   'new_death': '6.0',
#   'pnew_death': '1',
#   'created_at': '2020-10-26T13:41:41.106',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-02-03T00:00:00.000',
#   'state': 'GU',
#   'tot_cases': '7622',
#   'new_case': '4.0',
#   'pnew_case': '0',
#   'tot_death': '129',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-02-04T14:53:58.929',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-01-15T00:00:00.000',
#   'state': 'PA',
#   'tot_cases': '754611',
#   'conf_cases': '666521.0',
#   'prob_cases': '88090',
#   'new_case': '6047.0',
#   'pnew_case': '1226',
#   'tot_death': '18957',
#   'new_death': '215.0',
#   'pnew_death': '153',
#   'created_at': '2021-01-16T14:46:10.803',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-09T00:00:00.000',
#   'state': 'VA',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-22T00:00:00.000',
#   'state': 'WI',
#   'tot_cases': '4845',
#   'conf_cases': '4845.0',
#   'prob_cases': '0',
#   'new_case': '225.0',
#   'pnew_case': '0',
#   'tot_death': '246',
#   'conf_death': '246.0',
#   'prob_death': '0',
#   'new_death': '4.0',
#   'pnew_death': '0',
#   'created_at': '2020-04-22T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-10T00:00:00.000',
#   'state': 'LA',
#   'tot_cases': '19253',
#   'new_case': '970.0',
#   'tot_death': '755',
#   'new_death': '53.0',
#   'created_at': '2020-04-09T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-08T00:00:00.000',
#   'state': 'CO',
#   'tot_cases': '5655',
#   'new_case': '226.0',
#   'tot_death': '193',
#   'new_death': '14.0',
#   'created_at': '2020-04-07T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-02-06T00:00:00.000',
#   'state': 'CT',
#   'tot_cases': '259372',
#   'conf_cases': '243583.0',
#   'prob_cases': '15789',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '7214',
#   'conf_death': '5895.0',
#   'prob_death': '1319',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-02-07T14:46:31.377',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-02-10T00:00:00.000',
#   'state': 'AK',
#   'tot_cases': '53991',
#   'new_case': '182.0',
#   'pnew_case': '0',
#   'tot_death': '278',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-02-11T14:50:55.787',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-07-31T00:00:00.000',
#   'state': 'WA',
#   'tot_cases': '55803',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '1564',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-01T14:38:12.337',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-02-16T00:00:00.000',
#   'state': 'IA',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-04-16T00:00:00.000',
#   'state': 'MI',
#   'tot_cases': '29263',
#   'new_case': '1204.0',
#   'tot_death': '2093',
#   'new_death': '172.0',
#   'created_at': '2020-04-16T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-04T00:00:00.000',
#   'state': 'AR',
#   'tot_cases': '3469',
#   'new_case': '38.0',
#   'pnew_case': '0',
#   'tot_death': '80',
#   'new_death': '4.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-05T17:25:08.000',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-06-26T00:00:00.000',
#   'state': 'RMI',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-27T17:51:58.649',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-13T00:00:00.000',
#   'state': 'MO',
#   'tot_cases': '63797',
#   'new_case': '1267.0',
#   'pnew_case': '0',
#   'tot_death': '1325',
#   'new_death': '2.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-14T14:30:03.326',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-12-31T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '99164',
#   'new_case': '444.0',
#   'pnew_case': '119',
#   'tot_death': '1488',
#   'conf_death': '1204.0',
#   'prob_death': '284',
#   'new_death': '24.0',
#   'pnew_death': '6',
#   'created_at': '2021-01-01T14:49:07.256',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-15T00:00:00.000',
#   'state': 'VA',
#   'tot_cases': '29683',
#   'conf_cases': '28233.0',
#   'prob_cases': '1450',
#   'new_case': '1011.0',
#   'pnew_case': '71',
#   'tot_death': '1002',
#   'conf_death': '968.0',
#   'prob_death': '34',
#   'new_death': '25.0',
#   'pnew_death': '1',
#   'created_at': '2020-05-16T15:46:44.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-30T00:00:00.000',
#   'state': 'MT',
#   'tot_cases': '31916',
#   'conf_cases': '31916.0',
#   'prob_cases': '0',
#   'new_case': '1063.0',
#   'pnew_case': '0',
#   'tot_death': '364',
#   'conf_death': '364.0',
#   'prob_death': '0',
#   'new_death': '27.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-31T13:30:31.395',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-26T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '116978',
#   'conf_cases': '93905.0',
#   'prob_cases': '23073',
#   'new_case': '1139.0',
#   'pnew_case': '348',
#   'tot_death': '1928',
#   'new_death': '29.0',
#   'pnew_death': '9',
#   'created_at': '2021-01-27T14:53:24.793',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-05-18T00:00:00.000',
#   'state': 'TX',
#   'tot_cases': '48693',
#   'new_case': '909.0',
#   'pnew_case': '0',
#   'tot_death': '1347',
#   'new_death': '11.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-19T15:45:23.000',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-01-07T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '3',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-08T15:56:01.472'},
#  {'submission_date': '2020-06-15T00:00:00.000',
#   'state': 'OK',
#   'tot_cases': '8251',
#   'conf_cases': '8237.0',
#   'prob_cases': '14',
#   'new_case': '20.0',
#   'pnew_case': '14',
#   'tot_death': '371',
#   'conf_death': '371.0',
#   'prob_death': '0',
#   'new_death': '12.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-16T14:10:11.939',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-16T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-04-16T16:22:39.452'},
#  {'submission_date': '2020-02-03T00:00:00.000',
#   'state': 'NV',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
#  {'submission_date': '2020-05-21T00:00:00.000',
#   'state': 'MN',
#   'tot_cases': '19005',
#   'new_case': '1335.0',
#   'pnew_case': '0',
#   'tot_death': '851',
#   'conf_death': '842.0',
#   'prob_death': '9',
#   'new_death': '65.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-22T15:31:45.000',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-03T00:00:00.000',
#   'state': 'AL',
#   'tot_cases': '195929',
#   'conf_cases': '166627.0',
#   'prob_cases': '29302',
#   'new_case': '1037.0',
#   'pnew_case': '394',
#   'tot_death': '2987',
#   'conf_death': '2782.0',
#   'prob_death': '205',
#   'new_death': '14.0',
#   'pnew_death': '-1',
#   'created_at': '2020-11-04T15:03:00.406',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-26T00:00:00.000',
#   'state': 'WY',
#   'tot_cases': '43146',
#   'conf_cases': '37129.0',
#   'prob_cases': '6017',
#   'new_case': '482.0',
#   'pnew_case': '53',
#   'tot_death': '373',
#   'conf_death': '373.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-27T14:44:47.209',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-16T00:00:00.000',
#   'state': 'VA',
#   'tot_cases': '206763',
#   'conf_cases': '187288.0',
#   'prob_cases': '19475',
#   'new_case': '2125.0',
#   'pnew_case': '363',
#   'tot_death': '3835',
#   'conf_death': '3557.0',
#   'prob_death': '278',
#   'new_death': '30.0',
#   'pnew_death': '6',
#   'created_at': '2020-11-17T14:52:47.621',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-27T00:00:00.000',
#   'state': 'WI',
#   'tot_cases': '30227',
#   'conf_cases': '27286.0',
#   'prob_cases': '2941',
#   'new_case': '559.0',
#   'pnew_case': '20',
#   'tot_death': '784',
#   'conf_death': '777.0',
#   'prob_death': '7',
#   'new_death': '11.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-28T14:59:02.728',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-28T00:00:00.000',
#   'state': 'GU',
#   'tot_cases': '4466',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '76',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-29T14:11:33.577',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-03-21T00:00:00.000',
#   'state': 'WI',
#   'tot_cases': '281',
#   'new_case': '75.0',
#   'tot_death': '4',
#   'new_death': '1.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-27T00:00:00.000',
#   'state': 'AR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-05T00:00:00.000',
#   'state': 'VI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
#  {'submission_date': '2020-02-15T00:00:00.000',
#   'state': 'RI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-03-26T00:00:00.000',
#   'state': 'RMI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-15T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '39',
#   'new_case': '15.0',
#   'tot_death': '1',
#   'new_death': '1.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-10T00:00:00.000',
#   'state': 'MO',
#   'tot_cases': '97591',
#   'new_case': '1116.0',
#   'pnew_case': '0',
#   'tot_death': '1691',
#   'new_death': '18.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-11T13:51:03.398',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-03-18T00:00:00.000',
#   'state': 'CO',
#   'tot_cases': '216',
#   'new_case': '33.0',
#   'tot_death': '2',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-04T00:00:00.000',
#   'state': 'SC',
#   'tot_cases': '181188',
#   'conf_cases': '171159.0',
#   'prob_cases': '10029',
#   'new_case': '1058.0',
#   'pnew_case': '198',
#   'tot_death': '4049',
#   'new_death': '17.0',
#   'pnew_death': '0',
#   'created_at': '2021-02-08T00:00:00.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-06-01T00:00:00.000',
#   'state': 'NH',
#   'tot_cases': '4685',
#   'new_case': '34.0',
#   'pnew_case': '0',
#   'tot_death': '245',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-02T14:16:17.049',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-11-13T00:00:00.000',
#   'state': 'KS',
#   'tot_cases': '115507',
#   'conf_cases': '101914.0',
#   'prob_cases': '13593',
#   'new_case': '6282.0',
#   'pnew_case': '1220',
#   'tot_death': '1259',
#   'new_death': '44.0',
#   'pnew_death': '9',
#   'created_at': '2020-11-14T14:44:40.037',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-03-04T00:00:00.000',
#   'state': 'CT',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-31T00:00:00.000',
#   'state': 'IA',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-12-04T00:00:00.000',
#   'state': 'NM',
#   'tot_cases': '104935',
#   'new_case': '2073.0',
#   'pnew_case': '0',
#   'tot_death': '1706',
#   'new_death': '33.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-05T14:29:17.537',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-10-24T00:00:00.000',
#   'state': 'NC',
#   'tot_cases': '258292',
#   'conf_cases': '248620.0',
#   'prob_cases': '9672',
#   'new_case': '2584.0',
#   'pnew_case': '310',
#   'tot_death': '4144',
#   'conf_death': '4085.0',
#   'prob_death': '59',
#   'new_death': '30.0',
#   'pnew_death': '3',
#   'created_at': '2020-10-25T13:45:35.790',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-08T00:00:00.000',
#   'state': 'AZ',
#   'tot_cases': '10526',
#   'conf_cases': '10526.0',
#   'prob_cases': '0',
#   'new_case': '581.0',
#   'pnew_case': '0',
#   'tot_death': '517',
#   'conf_death': '517.0',
#   'prob_death': '0',
#   'new_death': '67.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-09T21:26:08.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-18T00:00:00.000',
#   'state': 'KS',
#   'tot_cases': '21',
#   'new_case': '5.0',
#   'tot_death': '1',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-01-22T00:00:00.000',
#   'state': 'MD',
#   'tot_cases': '0',
#   'new_case': '0',
#   'tot_death': '0',
#   'new_death': '0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-17T00:00:00.000',
#   'state': 'AR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-04-04T00:00:00.000',
#   'state': 'MO',
#   'tot_cases': '2291',
#   'new_case': '178.0',
#   'tot_death': '24',
#   'new_death': '5.0',
#   'created_at': '2020-04-03T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'}]

# %%
# COVID Cases and Deaths Per State (cont.)

# Create DataFrame out of .json
df_state_data = pd.DataFrame(st_case_death_json)

# Print DF_State_Data
df_state_data
df_state_data.head()

# Select Necessary Data
df_state_data = pd.DataFrame(df_state_data, columns=['submission_date','state','tot_cases','new_case','tot_death','new_death'])

# Print DF_State_Data
df_state_data

# Rename Columns and Print
df_state_data.rename(columns = {'submission_date':'Submission_Date','state':'State','tot_cases':'Tot_Cases','new_case':'New_Case','tot_death':'Tot_Death','new_death':'New_Death'})
# Out:
#              Submission_Date State Tot_Cases New_Case Tot_Death New_Death
# 0    2020-05-04T00:00:00.000    KY      5245    115.0       261       8.0
# 1    2020-03-23T00:00:00.000    NH       101     23.0         1       1.0
# 2    2020-04-11T00:00:00.000    IL     19180   1293.0       677      81.0
# 3    2021-01-01T00:00:00.000    FL   1300528      0.0     21673       0.0
# 4    2020-04-09T00:00:00.000    PA     18228   1989.0       338      28.0
# ..                       ...   ...       ...      ...       ...       ...
# 995  2020-05-08T00:00:00.000    AZ     10526    581.0       517      67.0
# 996  2020-03-18T00:00:00.000    KS        21      5.0         1       0.0
# 997  2020-01-22T00:00:00.000    MD         0        0         0         0
# 998  2020-02-17T00:00:00.000    AR         0      0.0         0       0.0
# 999  2020-04-04T00:00:00.000    MO      2291    178.0        24       5.0
#
# [1000 rows x 6 columns]

# %%
# COVID Cases and Deaths Per State (cont.)

# Build DataFrame for Selected State 
df_tx = df_state_data[df_state_data.state=="TX"][['submission_date','state','tot_cases','new_case','tot_death','new_death']]

# Print
df_tx

# Sort by Increasing Submission Date and Print
sort_by_df_tx = df_tx.sort_values('submission_date')
sort_by_df_tx

# Rename Columns and Print
sort_by_df_tx.rename(columns = {'submission_date':'Submission_Date','state':'State','tot_cases':'Tot_Cases','new_case':'New_Case','tot_death':'Tot_Death','new_death':'New_Death'})
# Out:
#              Submission_Date State Tot_Cases New_Case Tot_Death New_Death
# 816  2020-03-08T00:00:00.000    TX         6      1.0         0       0.0
# 720  2020-04-07T00:00:00.000    TX      8262    986.0       154      14.0
# 215  2020-04-29T00:00:00.000    TX     27054    883.0       732      42.0
# 969  2020-05-18T00:00:00.000    TX     48693    909.0      1347      11.0
# 522  2020-05-29T00:00:00.000    TX     61006   1230.0      1626      25.0
# 946  2020-06-06T00:00:00.000    TX     73553   1940.0      1819      31.0
# 851  2020-08-01T00:00:00.000    TX    430485   9539.0      6837     268.0
# 392  2020-08-16T00:00:00.000    TX    535042   6204.0      9983     143.0
# 124  2020-10-11T00:00:00.000    TX    792478   2418.0     16557      31.0
# 286  2020-11-20T00:00:00.000    TX   1168925  13598.0     20296     183.0
# 359  2020-12-01T00:00:00.000    TX   1296972  18540.0     21549     170.0
# 72   2020-12-29T00:00:00.000    TX   1715978  32552.0     26762     241.0
# 409  2021-01-18T00:00:00.000    TX   2125552  11590.0     32084      46.0

# %%
# Total Shipment Amounts of Moderna Vaccinations - State level

# Moderna API
mod_url = "https://data.cdc.gov/resource/b7pe-5nws.json"

# query_mod_url = f"{mod_url}"

# print(query_url2)
mod_url

# vacc_response = requests.get(query_url2)
mod_json = requests.get(mod_url).json()

mod_json[0]

# Revised DataFrame 
df_mod_vac = pd.DataFrame(mod_json)

#Print
df_mod_vac
df_mod_vac.rename(columns = {'jurisdiction':'Jurisdiction','total_allocation_moderna_second_dose_shipments':'Total_Wk_Two','total_moderna_allocation_first_dose_shipments':'Total_Wk_One'})
# Out:
#        Jurisdiction      week_of_allocations _1st_dose_allocations  \
# 0           Alabama  2021-03-01T00:00:00.000                 47700
# 1            Alaska  2021-03-01T00:00:00.000                 49300
# 2    American Samoa  2021-03-01T00:00:00.000                  4400
# 3           Arizona  2021-03-01T00:00:00.000                 67600
# 4          Arkansas  2021-03-01T00:00:00.000                 28900
# ..              ...                      ...                   ...
# 688        Virginia  2020-12-21T00:00:00.000                146400
# 689      Washington  2020-12-21T00:00:00.000                128000
# 690   West Virginia  2020-12-21T00:00:00.000                 32600
# 691       Wisconsin  2020-12-21T00:00:00.000                101000
# 692         Wyoming  2020-12-21T00:00:00.000                 10000
#
#     _2nd_dose_allocations
# 0                   47700
# 1                   49300
# 2                       0
# 3                   67600
# 4                   28900
# ..                    ...
# 688                146400
# 689                128000
# 690                 32600
# 691                101000
# 692                 10000
#
# [693 rows x 4 columns]

# %%
# Moderna Vacinnations (cont.)

# Filter Out Necessary Data and Create New DataFrame
df_vac_mod = pd.DataFrame(df_mod_vac, columns=['jurisdiction','total_allocation_moderna_second_dose_shipments','total_moderna_allocation_first_dose_shipments'])

# Print 
df_vac_mod

# Set Index Info to Have States as Row Data
df_vac_mod.set_index('jurisdiction')

# Add New Column and Print
df_vac_mod['Total_Doses_Shipped'] = True
df_vac_mod

# Rename Columns and Print
df_vac_mod.rename(columns = {'jurisdiction':'Jurisdiction','total_allocation_moderna_second_dose_shipments':'Total_Wk_Two','total_moderna_allocation_first_dose_shipments':'Total_Wk_One'})
# Out:
#        Jurisdiction  Total_Wk_Two  Total_Wk_One  Total_Doses_Shipped
# 0           Alabama           NaN           NaN                 True
# 1            Alaska           NaN           NaN                 True
# 2    American Samoa           NaN           NaN                 True
# 3           Arizona           NaN           NaN                 True
# 4          Arkansas           NaN           NaN                 True
# ..              ...           ...           ...                  ...
# 688        Virginia           NaN           NaN                 True
# 689      Washington           NaN           NaN                 True
# 690   West Virginia           NaN           NaN                 True
# 691       Wisconsin           NaN           NaN                 True
# 692         Wyoming           NaN           NaN                 True
#
# [693 rows x 4 columns]

# %%
# Moderna Vacinnations (cont.)
# Computing Totals
df_vac_mod["Total_Doses_Shipped"] = df_vac_mod["total_moderna_allocation_first_dose_shipments"] + df_vac_mod["total_allocation_moderna_second_dose_shipments"]

# Print
df_vac_mod

 # Rename
df_vac_mod.rename(columns = {'jurisdiction':'Jurisdiction','total_allocation_moderna_second_dose_shipments':'Total_Wk_Two','total_moderna_allocation_first_dose_shipments':'Total_Wk_One'})
# Out:
#        Jurisdiction  Total_Wk_Two  Total_Wk_One  Total_Doses_Shipped
# 0           Alabama           NaN           NaN                  NaN
# 1            Alaska           NaN           NaN                  NaN
# 2    American Samoa           NaN           NaN                  NaN
# 3           Arizona           NaN           NaN                  NaN
# 4          Arkansas           NaN           NaN                  NaN
# ..              ...           ...           ...                  ...
# 688        Virginia           NaN           NaN                  NaN
# 689      Washington           NaN           NaN                  NaN
# 690   West Virginia           NaN           NaN                  NaN
# 691       Wisconsin           NaN           NaN                  NaN
# 692         Wyoming           NaN           NaN                  NaN
#
# [693 rows x 4 columns]

# %%
# Total Shipment Amounts of Pfizer Vaccinations - State level

# Pfizer API
pfizer_url = "https://data.cdc.gov/resource/saz5-9hgg.json"

# query_pfizer_url = f"{pfizer_url}"

# print(query_url2)
pfizer_url

# vacc_response = requests.get(query_url2)
pf_vacc_json = requests.get(pfizer_url).json()

pf_vacc_json[0]

# Revised DataFrame
df_pf_vacc = pd.DataFrame(pf_vacc_json)

# Print
df_pf_vacc
# Out:
#        jurisdiction      week_of_allocations _1st_dose_allocations  \
# 0           Alabama  2021-03-01T00:00:00.000                 54990
# 1            Alaska  2021-03-01T00:00:00.000                 53820
# 2    American Samoa  2021-03-01T00:00:00.000                  9360
# 3           Arizona  2021-03-01T00:00:00.000                 78390
# 4          Arkansas  2021-03-01T00:00:00.000                 33930
# ..              ...                      ...                   ...
# 751        Virginia  2020-12-14T00:00:00.000                 72150
# 752      Washington  2020-12-14T00:00:00.000                 62400
# 753   West Virginia  2020-12-14T00:00:00.000                 16575
# 754       Wisconsin  2020-12-14T00:00:00.000                 49725
# 755         Wyoming  2020-12-14T00:00:00.000                  4875
#
#     _2nd_dose_allocations
# 0                   54990
# 1                   53820
# 2                       0
# 3                   78390
# 4                   33930
# ..                    ...
# 751                 72150
# 752                 62400
# 753                 16575
# 754                 49725
# 755                  4875
#
# [756 rows x 4 columns]

# %%
# Pfizer Vaccinations (cont.)

# Filter Out Necessary Data and Create New DataFrame
df_vac_pf = pd.DataFrame(df_pf_vacc, columns=['jurisdiction','total_pfizer_allocation_first_dose_shipments','total_allocation_pfizer_second_dose_shipments'])

# Print 
df_vac_pf

# Set Index Info to Have States as Row Data
df_vac_pf.set_index('jurisdiction')

# Add New Column and Print
df_vac_pf['Total_Doses_Shipped'] = True
df_vac_pf


# Rename Columns and Print
df_vac_pf.rename(columns={'jurisdiction':'Jurisdiction','total_pfizer_allocation_first_dose_shipments':'Total_Wk_One','total_allocation_pfizer_second_dose_shipments':'Total_Wk_Two'})
# Out:
#        Jurisdiction  Total_Wk_One  Total_Wk_Two  Total_Doses_Shipped
# 0           Alabama           NaN           NaN                 True
# 1            Alaska           NaN           NaN                 True
# 2    American Samoa           NaN           NaN                 True
# 3           Arizona           NaN           NaN                 True
# 4          Arkansas           NaN           NaN                 True
# ..              ...           ...           ...                  ...
# 751        Virginia           NaN           NaN                 True
# 752      Washington           NaN           NaN                 True
# 753   West Virginia           NaN           NaN                 True
# 754       Wisconsin           NaN           NaN                 True
# 755         Wyoming           NaN           NaN                 True
#
# [756 rows x 4 columns]

# %%
# Import Current Data for Vaccinations Administered per State
vac_admin_df = pd.read_csv(r'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/us_state_vaccinations.csv')

# Print
vac_admin_df

# Selecting Necessary Data
vac_admin_df = pd.DataFrame(vac_admin_df, columns=['date','location','total_vaccinations','total_distributed','people_vaccinated','share_doses_used'])

# Print
vac_admin_df
vac_admin_df.rename(columns = {'date':'Date','location':'Location','total_vaccinations':'Tot_Vaccs','total_distributed':'Tot_Dist','people_vaccinated':'People_Vaccd','share_doses_used':'Percent_Used'})
# Out:
#             Date Location  Tot_Vaccs  Tot_Dist  People_Vaccd  Percent_Used
# 0     2021-01-12  Alabama    78134.0  377025.0       70861.0         0.207
# 1     2021-01-13  Alabama    84040.0  378975.0       74792.0         0.222
# 2     2021-01-14  Alabama    92300.0  435350.0       80480.0         0.212
# 3     2021-01-15  Alabama   100567.0  444650.0       86956.0         0.226
# 4     2021-01-16  Alabama        NaN       NaN           NaN           NaN
# ...          ...      ...        ...       ...           ...           ...
# 2813  2021-02-19  Wyoming   124310.0  150005.0       87289.0         0.829
# 2814  2021-02-20  Wyoming   129060.0  150905.0       89346.0         0.855
# 2815  2021-02-21  Wyoming   129470.0  150905.0       89605.0         0.858
# 2816  2021-02-22  Wyoming   135635.0  150905.0       91931.0         0.899
# 2817  2021-02-23  Wyoming   136163.0  167025.0       92151.0         0.815
#
# [2818 rows x 6 columns]

# %%
# Import Current Data for Vaccinations Administered by Manufacturer - United States
vac_man_admin_df = pd.read_csv(r'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations-by-manufacturer.csv')

# Print
vac_man_admin_df

# Selecting Necessary Data
vac_man_us_df = vac_man_admin_df[vac_man_admin_df.location=="United States"]

# Print
vac_man_us_df

# Rename Columns and Print
vac_man_us_df.rename(columns = {'location':'Location','date':'Date','vaccine':'Vaccine','total_vaccinations':'Total_Vaccinations'})
# Out:
#           Location        Date          Vaccine  Total_Vaccinations
# 820  United States  2021-01-12          Moderna             3835859
# 821  United States  2021-01-12  Pfizer/BioNTech             5488697
# 822  United States  2021-01-13          Moderna             4249795
# 823  United States  2021-01-13  Pfizer/BioNTech             6025872
# 824  United States  2021-01-15          Moderna             5122662
# ..             ...         ...              ...                 ...
# 889  United States  2021-02-20  Pfizer/BioNTech            31270062
# 890  United States  2021-02-21          Moderna            30747615
# 891  United States  2021-02-21  Pfizer/BioNTech            32232422
# 892  United States  2021-02-22          Moderna            31212925
# 893  United States  2021-02-22  Pfizer/BioNTech            32853883
#
# [74 rows x 4 columns]

# %%
# Build DataFrame for Current Data of Moderna Vaccines Administered - United States
vac_man_df = vac_man_us_df[vac_man_us_df.vaccine=="Moderna"]

# Print
vac_man_df
vac_man_df.head()

# Rename Columns and Print
vac_man_df.rename(columns = {'location':'Location','date':'Date','vaccine':'Vaccine','total_vaccinations':'Total_Vaccinations'})
# Out:
#           Location        Date  Vaccine  Total_Vaccinations
# 820  United States  2021-01-12  Moderna             3835859
# 822  United States  2021-01-13  Moderna             4249795
# 824  United States  2021-01-15  Moderna             5122662
# 826  United States  2021-01-19  Moderna             6828561
# 828  United States  2021-01-20  Moderna             7239750
# 830  United States  2021-01-21  Moderna             7724683
# 832  United States  2021-01-22  Moderna             8407909
# 834  United States  2021-01-23  Moderna             9061112
# 836  United States  2021-01-24  Moderna             9689497
# 838  United States  2021-01-25  Moderna            10084432
# 840  United States  2021-01-26  Moderna            10431466
# 842  United States  2021-01-27  Moderna            11001991
# 844  United States  2021-01-28  Moderna            11737592
# 846  United States  2021-01-29  Moderna            12619210
# 848  United States  2021-01-30  Moderna            13499942
# 850  United States  2021-01-31  Moderna            14246089
# 852  United States  2021-02-01  Moderna            14756609
# 854  United States  2021-02-02  Moderna            15006565
# 856  United States  2021-02-03  Moderna            15567188
# 858  United States  2021-02-04  Moderna            16260102
# 860  United States  2021-02-05  Moderna            17133644
# 862  United States  2021-02-06  Moderna            18336515
# 864  United States  2021-02-07  Moderna            19485089
# 866  United States  2021-02-08  Moderna            20066305
# 868  United States  2021-02-09  Moderna            20416765
# 870  United States  2021-02-10  Moderna            21189540
# 872  United States  2021-02-11  Moderna            22038088
# 874  United States  2021-02-12  Moderna            23111715
# 876  United States  2021-02-13  Moderna            24297615
# 878  United States  2021-02-14  Moderna            25505313
# 880  United States  2021-02-16  Moderna            26738383
# 882  United States  2021-02-17  Moderna            27287041
# 884  United States  2021-02-18  Moderna            28043413
# 886  United States  2021-02-19  Moderna            29044336
# 888  United States  2021-02-20  Moderna            29909492
# 890  United States  2021-02-21  Moderna            30747615
# 892  United States  2021-02-22  Moderna            31212925

# %%
# Compute Total Moderna Vaccinations - United States
vac_man_tot= vac_man_df['total_vaccinations'].sum()

# Print
vac_man_tot
# Out:
# 621934808

# %%
# Build DataFrame for Current Data of Pfizer Vaccines Administered - United States
vac_pf_df = vac_man_us_df[vac_man_us_df.vaccine=="Pfizer/BioNTech"]

# Print
vac_pf_df
vac_pf_df.head()

# Rename Columns and Print
vac_pf_df.rename(columns = {'location':'Location','date':'Date','vaccine':'Vaccine','total_vaccinations':'Total_Vaccinations'})
# Out:
#           Location        Date          Vaccine  Total_Vaccinations
# 821  United States  2021-01-12  Pfizer/BioNTech             5488697
# 823  United States  2021-01-13  Pfizer/BioNTech             6025872
# 825  United States  2021-01-15  Pfizer/BioNTech             7153268
# 827  United States  2021-01-19  Pfizer/BioNTech             8874811
# 829  United States  2021-01-20  Pfizer/BioNTech             9281063
# 831  United States  2021-01-21  Pfizer/BioNTech             9817027
# 833  United States  2021-01-22  Pfizer/BioNTech            10695066
# 835  United States  2021-01-23  Pfizer/BioNTech            11471457
# 837  United States  2021-01-24  Pfizer/BioNTech            12153536
# 839  United States  2021-01-25  Pfizer/BioNTech            12551999
# 841  United States  2021-01-26  Pfizer/BioNTech            13009981
# 843  United States  2021-01-27  Pfizer/BioNTech            13550835
# 845  United States  2021-01-28  Pfizer/BioNTech            14355980
# 847  United States  2021-01-29  Pfizer/BioNTech            15164858
# 849  United States  2021-01-30  Pfizer/BioNTech            15977015
# 851  United States  2021-01-31  Pfizer/BioNTech            16775916
# 853  United States  2021-02-01  Pfizer/BioNTech            17364398
# 855  United States  2021-02-02  Pfizer/BioNTech            17672866
# 857  United States  2021-02-03  Pfizer/BioNTech            18209204
# 859  United States  2021-02-04  Pfizer/BioNTech            18841309
# 861  United States  2021-02-05  Pfizer/BioNTech            19582865
# 863  United States  2021-02-06  Pfizer/BioNTech            20598212
# 865  United States  2021-02-07  Pfizer/BioNTech            21622193
# 867  United States  2021-02-08  Pfizer/BioNTech            22247484
# 869  United States  2021-02-09  Pfizer/BioNTech            22685406
# 871  United States  2021-02-10  Pfizer/BioNTech            23475749
# 873  United States  2021-02-11  Pfizer/BioNTech            24246868
# 875  United States  2021-02-12  Pfizer/BioNTech            25192628
# 877  United States  2021-02-13  Pfizer/BioNTech            26237417
# 879  United States  2021-02-14  Pfizer/BioNTech            27271797
# 881  United States  2021-02-16  Pfizer/BioNTech            28374410
# 883  United States  2021-02-17  Pfizer/BioNTech            28886690
# 885  United States  2021-02-18  Pfizer/BioNTech            29585627
# 887  United States  2021-02-19  Pfizer/BioNTech            30431247
# 889  United States  2021-02-20  Pfizer/BioNTech            31270062
# 891  United States  2021-02-21  Pfizer/BioNTech            32232422
# 893  United States  2021-02-22  Pfizer/BioNTech            32853883

# %%
vac_pf_tot= vac_pf_df['total_vaccinations'].sum()

vac_pf_tot
# Out:
# 701230118

# %%
# Import Current Data for Vaccinations Administered - Total Amounts of Both Manufacturers - United States
vac_man_admin_all_df = pd.read_csv(r'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/country_data/United%20States.csv')

# Print
vac_man_admin_all_df

vac_man_admin_all_df = pd.DataFrame(vac_man_admin_all_df, columns=['location','date','vaccine','total_vaccinations','people_vaccinated','people_fully_vaccinated'])

vac_man_admin_all_df.head()
# Out:
#         location        date                   vaccine  total_vaccinations  \
# 0  United States  2020-12-20           Pfizer/BioNTech              556208
# 1  United States  2020-12-21           Pfizer/BioNTech              614117
# 2  United States  2020-12-23  Moderna, Pfizer/BioNTech             1008025
# 3  United States  2020-12-26  Moderna, Pfizer/BioNTech             1944585
# 4  United States  2020-12-28  Moderna, Pfizer/BioNTech             2127143
#
#    people_vaccinated  people_fully_vaccinated
# 0           556208.0                      NaN
# 1           614117.0                      NaN
# 2          1008025.0                      NaN
# 3          1944585.0                      NaN
# 4          2127143.0                      NaN
