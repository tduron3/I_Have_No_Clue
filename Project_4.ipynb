# %%
# Set Dependencies

import csv
import pandas as pd
import numpy as np
import requests
import json
import urllib
import IPython
import lib
import math
import os
import string

# %%
# Output File CSV
output_data_file = "output.proj1.csv"

# %%
# 2020 Presidential Analysis

# Name CSV File and Print
df = pd.read_csv(r'C:\users\tony duron\Project1-TD\Resources\1976-2020-president.csv')
df.head()

# Select Necessary Data
df = pd.DataFrame(df, columns=['year','state','candidate','candidatevotes','party_simplified'])

# Print DataFrame
df

# Rename Columns and Print
df.rename(columns = {'year':'Year','state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#       Year    State                Candidate  Cand_Votes Political_Party
# 0     1976  ALABAMA            CARTER, JIMMY      659170        DEMOCRAT
# 1     1976  ALABAMA             FORD, GERALD      504070      REPUBLICAN
# 2     1976  ALABAMA           MADDOX, LESTER        9198           OTHER
# 3     1976  ALABAMA  BUBAR, BENJAMIN ""BEN""        6669           OTHER
# 4     1976  ALABAMA                HALL, GUS        1954           OTHER
# ...    ...      ...                      ...         ...             ...
# 4282  2020  WYOMING            JORGENSEN, JO        5768     LIBERTARIAN
# 4283  2020  WYOMING            PIERCE, BROCK        2208           OTHER
# 4284  2020  WYOMING                      NaN        1739           OTHER
# 4285  2020  WYOMING                OVERVOTES         279           OTHER
# 4286  2020  WYOMING               UNDERVOTES        1459           OTHER
#
# [4287 rows x 5 columns]

# %%
# 2020 Presidential Analysis (cont.)
# Select 2020 Presidential Election Year
is_2020 = df['year']==2020

# Print
is_2020.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: year, dtype: bool

# %%
# 2020 Presidential Analysis (cont.)
# Select 2020 Presidential Election Year (cont.)
df_2020 = df[is_2020]
df_2020.head()

# Filtering Out Primary Political Parties
value_list = ["DEMOCRAT","REPUBLICAN"]
boolean_series = df_2020.party_simplified.isin(value_list)
dem_rep_df = df_2020[boolean_series]

# Rename Index
dem_rep_df.index.names = ['Def_Index']

# Print New DataFrame
dem_rep_df
dem_rep_df.head()
# Out:
#            year    state            candidate  candidatevotes party_simplified
# Def_Index
# 3740       2020  ALABAMA  BIDEN, JOSEPH R. JR          849624         DEMOCRAT
# 3741       2020  ALABAMA     TRUMP, DONALD J.         1441170       REPUBLICAN
# 3744       2020   ALASKA  BIDEN, JOSEPH R. JR          153778         DEMOCRAT
# 3745       2020   ALASKA     TRUMP, DONALD J.          189951       REPUBLICAN
# 3752       2020  ARIZONA  BIDEN, JOSEPH R. JR         1672143         DEMOCRAT

# %%
# 2020 Presidential Analysis (cont.)
# Select Individual State Data and Create DataFrame
df_al = dem_rep_df[dem_rep_df.state=="ALABAMA"][['year','state','candidate','party_simplified','candidatevotes']]

# Print
df_al
df_al.head()

# Total Votes for Both Parties in Alabama
total_al = df_al['candidatevotes'].sum()

# Print
total_al

# Create New column and Add Result 
df_al['Total_State_Votes'] = df_al['candidatevotes'].sum()

# Print
df_al
df_al.head()

# Insert New Column for Result
df_al.insert(6, "Final_Result (%)", True)

# Compute Percentage Result, Rounding to 2 Decimal Places
df_al['Final_Result (%)']=round((df_al['candidatevotes']).div(df_al['Total_State_Votes']) * 100, 2)

# Print
df_al
df_al.rename(columns = {'year':'Year','state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#            Year    State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 3740       2020  ALABAMA  BIDEN, JOSEPH R. JR        DEMOCRAT      849624
# 3741       2020  ALABAMA     TRUMP, DONALD J.      REPUBLICAN     1441170
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 3740                 2290794             37.09
# 3741                 2290794             62.91

# %%
df_tx = dem_rep_df[dem_rep_df.state=="TEXAS"][['year','state','candidate','party_simplified','candidatevotes']]

df_tx
df_tx.head()

total_tx = df_tx['candidatevotes'].sum()

df_tx['Total_State_Votes'] = df_tx['candidatevotes'].sum()

df_tx.insert(6, "Final_Result (%)", True)

df_tx['Final_Result (%)']=round((df_tx['candidatevotes']).div(df_tx['Total_State_Votes']) * 100, 2)

df_tx
df_tx.rename(columns = {'year':'Year','state':'State','candidate':'Candidate','party_simplified':'Political_Party','candidatevotes':'Cand_Votes'})
# Out:
#            Year  State            Candidate Political_Party  Cand_Votes  \
# Def_Index
# 4201       2020  TEXAS     TRUMP, DONALD J.      REPUBLICAN     5890347
# 4202       2020  TEXAS  BIDEN, JOSEPH R. JR        DEMOCRAT     5259126
#
#            Total_State_Votes  Final_Result (%)
# Def_Index
# 4201                11149473             52.83
# 4202                11149473             47.17

# %%
bigdata = df_tx.append(df_al, ignore_index=True)

bigdata
# Out:
#    year    state            candidate party_simplified  candidatevotes  \
# 0  2020    TEXAS     TRUMP, DONALD J.       REPUBLICAN         5890347
# 1  2020    TEXAS  BIDEN, JOSEPH R. JR         DEMOCRAT         5259126
# 2  2020  ALABAMA  BIDEN, JOSEPH R. JR         DEMOCRAT          849624
# 3  2020  ALABAMA     TRUMP, DONALD J.       REPUBLICAN         1441170
#
#    Total_State_Votes  Final_Result (%)
# 0           11149473             52.83
# 1           11149473             47.17
# 2            2290794             37.09
# 3            2290794             62.91

# %%
new_df = dem_rep_df.groupby(['state','party_simplified','candidate']).sum()

new_df
new_df.reset_index(level=['party_simplified','candidate'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-0129d2986e4d> in <module>
#       4 new_df.reset_index(level=['party_simplified','candidate'])
#       5
# ----> 6 new_df.column(["candidate"])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
new_df['Total_State_Votes'] = new_df['candidatevotes'].sum()

new_df.insert(3, "Final_Result (%)", True)

new_df['Final_Result (%)']=round((new_df['candidatevotes']).div(new_df['Total_State_Votes']) * 100, 2)

new_df
# Out:
#                                                     year  candidatevotes  \
# state         party_simplified candidate
# ALABAMA       DEMOCRAT         BIDEN, JOSEPH R. JR  2020          849624
#               REPUBLICAN       TRUMP, DONALD J.     2020         1441170
# ALASKA        DEMOCRAT         BIDEN, JOSEPH R. JR  2020          153778
#               REPUBLICAN       TRUMP, DONALD J.     2020          189951
# ARIZONA       DEMOCRAT         BIDEN, JOSEPH R. JR  2020         1672143
# ...                                                  ...             ...
# WEST VIRGINIA REPUBLICAN       TRUMP, DONALD J.     2020          545382
# WISCONSIN     DEMOCRAT         BIDEN, JOSEPH R. JR  2020         1630866
#               REPUBLICAN       TRUMP, DONALD J.     2020         1610184
# WYOMING       DEMOCRAT         BIDEN, JOSEPH R. JR  2020           73491
#               REPUBLICAN       TRUMP, DONALD J.     2020          193559
#
#                                                     Total_State_Votes  \
# state         party_simplified candidate
# ALABAMA       DEMOCRAT         BIDEN, JOSEPH R. JR          155485054
#               REPUBLICAN       TRUMP, DONALD J.             155485054
# ALASKA        DEMOCRAT         BIDEN, JOSEPH R. JR          155485054
#               REPUBLICAN       TRUMP, DONALD J.             155485054
# ARIZONA       DEMOCRAT         BIDEN, JOSEPH R. JR          155485054
# ...                                                               ...
# WEST VIRGINIA REPUBLICAN       TRUMP, DONALD J.             155485054
# WISCONSIN     DEMOCRAT         BIDEN, JOSEPH R. JR          155485054
#               REPUBLICAN       TRUMP, DONALD J.             155485054
# WYOMING       DEMOCRAT         BIDEN, JOSEPH R. JR          155485054
#               REPUBLICAN       TRUMP, DONALD J.             155485054
#
#                                                     Final_Result (%)
# state         party_simplified candidate
# ALABAMA       DEMOCRAT         BIDEN, JOSEPH R. JR              0.55
#               REPUBLICAN       TRUMP, DONALD J.                 0.93
# ALASKA        DEMOCRAT         BIDEN, JOSEPH R. JR              0.10
#               REPUBLICAN       TRUMP, DONALD J.                 0.12
# ARIZONA       DEMOCRAT         BIDEN, JOSEPH R. JR              1.08
# ...                                                              ...
# WEST VIRGINIA REPUBLICAN       TRUMP, DONALD J.                 0.35
# WISCONSIN     DEMOCRAT         BIDEN, JOSEPH R. JR              1.05
#               REPUBLICAN       TRUMP, DONALD J.                 1.04
# WYOMING       DEMOCRAT         BIDEN, JOSEPH R. JR              0.05
#               REPUBLICAN       TRUMP, DONALD J.                 0.12
#
# [102 rows x 4 columns]

# %%
# Retrieve Data of COVID Cases and Deaths Per State
url = "https://data.cdc.gov/resource/9mfq-cb36.json"

# Print Query_URL
query_url = f"{url}"

# print
print(query_url)

# vacc_response = requests.get(query_url2)
st_case_death_json = requests.get(url).json()

# Print
st_case_death_json
# Out:
# https://data.cdc.gov/resource/9mfq-cb36.json
# [{'submission_date': '2020-10-15T00:00:00.000',
#   'state': 'DC',
#   'tot_cases': '16166',
#   'new_case': '34.0',
#   'pnew_case': '0',
#   'tot_death': '638',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-16T13:33:55.808'},
#  {'submission_date': '2020-12-08T00:00:00.000',
#   'state': 'NM',
#   'tot_cases': '109947',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '1756',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-09T14:45:40.234',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-01-01T00:00:00.000',
#   'state': 'FL',
#   'tot_cases': '1300528',
#   'new_case': '0.0',
#   'pnew_case': '6063',
#   'tot_death': '21673',
#   'new_death': '0.0',
#   'pnew_death': '7',
#   'created_at': '2021-01-02T14:50:51.219',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-08-29T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '12942',
#   'new_case': '425.0',
#   'pnew_case': '0',
#   'tot_death': '167',
#   'conf_death': '165.0',
#   'prob_death': '2',
#   'new_death': '2.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-30T14:49:52.418',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-30T00:00:00.000',
#   'state': 'IA',
#   'tot_cases': '7145',
#   'new_case': '302.0',
#   'pnew_case': '0',
#   'tot_death': '162',
#   'new_death': '14.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-01T21:00:19.025',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-26T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-12T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '29',
#   'new_case': '6.0',
#   'tot_death': '1',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-21T00:00:00.000',
#   'state': 'MP',
#   'tot_cases': '69',
#   'conf_cases': '69.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '2',
#   'conf_death': '2.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-22T13:51:57.795',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-25T00:00:00.000',
#   'state': 'NE',
#   'tot_cases': '18346',
#   'new_case': '125.0',
#   'pnew_case': '0',
#   'tot_death': '260',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-26T19:18:27.809',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-24T00:00:00.000',
#   'state': 'CA',
#   'tot_cases': '10',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-06-28T00:00:00.000',
#   'state': 'PA',
#   'tot_cases': '85988',
#   'conf_cases': '83529.0',
#   'prob_cases': '2459',
#   'new_case': '492.0',
#   'pnew_case': '13',
#   'tot_death': '6614',
#   'new_death': '8.0',
#   'pnew_death': '4',
#   'created_at': '2020-06-29T14:37:31.240',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-05-04T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '1224',
#   'conf_cases': '1224.0',
#   'prob_cases': '0',
#   'new_case': '29.0',
#   'pnew_case': '0',
#   'tot_death': '50',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-05T17:25:08.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-01T00:00:00.000',
#   'state': 'FSM',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-02T15:10:03.527',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-02T00:00:00.000',
#   'state': 'NY',
#   'tot_cases': '346492',
#   'new_case': '5775.0',
#   'pnew_case': '0',
#   'tot_death': '10117',
#   'new_death': '56.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-03T15:21:08.669',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-01-23T00:00:00.000',
#   'state': 'WY',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-05T00:00:00.000',
#   'state': 'GA',
#   'tot_cases': '28196',
#   'conf_cases': '28182.0',
#   'prob_cases': '14',
#   'new_case': '602.0',
#   'pnew_case': '1',
#   'tot_death': '1258',
#   'conf_death': '1258.0',
#   'prob_death': '0',
#   'new_death': '47.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-06T12:23:08.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-24T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '611039',
#   'new_case': '2520.0',
#   'pnew_case': '0',
#   'tot_death': '9716',
#   'conf_death': '9340.0',
#   'prob_death': '376',
#   'new_death': '23.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-25T14:42:40.885',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-23T00:00:00.000',
#   'state': 'TN',
#   'tot_cases': '143937',
#   'conf_cases': '141000.0',
#   'prob_cases': '2937',
#   'new_case': '1854.0',
#   'pnew_case': '38',
#   'tot_death': '1567',
#   'conf_death': '1527.0',
#   'prob_death': '40',
#   'new_death': '4.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-24T13:54:34.344',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-14T00:00:00.000',
#   'state': 'MS',
#   'tot_cases': '70930',
#   'conf_cases': '69268.0',
#   'prob_cases': '1662',
#   'new_case': '944.0',
#   'pnew_case': '106',
#   'tot_death': '2043',
#   'conf_death': '1965.0',
#   'prob_death': '78',
#   'new_death': '32.0',
#   'pnew_death': '9',
#   'created_at': '2020-08-15T14:02:05.619',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-31T00:00:00.000',
#   'state': 'VI',
#   'tot_cases': '1378',
#   'new_case': '16.0',
#   'pnew_case': '0',
#   'tot_death': '21',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-01T15:03:08.429'},
#  {'submission_date': '2020-09-26T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-27T13:39:49.124'},
#  {'submission_date': '2020-05-16T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-17T15:27:46.000'},
#  {'submission_date': '2020-03-13T00:00:00.000',
#   'state': 'MS',
#   'tot_cases': '1',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-18T00:00:00.000',
#   'state': 'GU',
#   'tot_cases': '136',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '5',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-04-18T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-12-10T00:00:00.000',
#   'state': 'WY',
#   'tot_cases': '38223',
#   'conf_cases': '33203.0',
#   'prob_cases': '5020',
#   'new_case': '338.0',
#   'pnew_case': '24',
#   'tot_death': '299',
#   'conf_death': '299.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-11T15:06:51.565',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-29T00:00:00.000',
#   'state': 'NV',
#   'tot_cases': '46021',
#   'new_case': '870.0',
#   'pnew_case': '0',
#   'tot_death': '806',
#   'new_death': '21.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-30T14:42:43.801'},
#  {'submission_date': '2020-04-15T00:00:00.000',
#   'state': 'MP',
#   'tot_cases': '13',
#   'new_case': '0.0',
#   'tot_death': '2',
#   'new_death': '0.0',
#   'created_at': '2020-04-15T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-27T00:00:00.000',
#   'state': 'NYC',
#   'tot_cases': '592471',
#   'conf_cases': '508530.0',
#   'prob_cases': '83941',
#   'new_case': '6182.0',
#   'pnew_case': '1473',
#   'tot_death': '26858',
#   'conf_death': '21887.0',
#   'prob_death': '4971',
#   'new_death': '93.0',
#   'pnew_death': '26',
#   'created_at': '2021-01-28T14:49:07.741',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-14T00:00:00.000',
#   'state': 'OK',
#   'tot_cases': '20922',
#   'conf_cases': '20755.0',
#   'prob_cases': '167',
#   'new_case': '521.0',
#   'pnew_case': '11',
#   'tot_death': '424',
#   'conf_death': '424.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-15T15:05:12.266',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-18T00:00:00.000',
#   'state': 'IL',
#   'tot_cases': '1072214',
#   'conf_cases': '1072214.0',
#   'prob_cases': '0',
#   'new_case': '3385.0',
#   'pnew_case': '0',
#   'tot_death': '20118',
#   'conf_death': '18258.0',
#   'prob_death': '1860',
#   'new_death': '68.0',
#   'pnew_death': '18',
#   'created_at': '2021-01-19T14:37:00.036',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-07T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-08T14:55:08.000'},
#  {'submission_date': '2020-12-11T00:00:00.000',
#   'state': 'MD',
#   'tot_cases': '232009',
#   'new_case': '3538.0',
#   'pnew_case': '0',
#   'tot_death': '5100',
#   'conf_death': '4937.0',
#   'prob_death': '163',
#   'new_death': '36.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-12T14:59:37.544',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-06T00:00:00.000',
#   'state': 'MS',
#   'tot_cases': '64400',
#   'conf_cases': '63302.0',
#   'prob_cases': '1098',
#   'new_case': '956.0',
#   'pnew_case': '38',
#   'tot_death': '1825',
#   'conf_death': '1772.0',
#   'prob_death': '53',
#   'new_death': '21.0',
#   'pnew_death': '3',
#   'created_at': '2020-08-07T23:57:59.479',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-12T00:00:00.000',
#   'state': 'GA',
#   'tot_cases': '416217',
#   'conf_cases': '379873.0',
#   'prob_cases': '36344',
#   'new_case': '2802.0',
#   'pnew_case': '265',
#   'tot_death': '8881',
#   'conf_death': '8403.0',
#   'prob_death': '478',
#   'new_death': '548.0',
#   'pnew_death': '478',
#   'created_at': '2020-11-13T09:54:34.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-03T00:00:00.000',
#   'state': 'HI',
#   'tot_cases': '12768',
#   'new_case': '69.0',
#   'pnew_case': '0',
#   'tot_death': '142',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-04T09:35:23.000',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-14T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '7572',
#   'new_case': '48.0',
#   'pnew_case': '0',
#   'tot_death': '109',
#   'conf_death': '108.0',
#   'prob_death': '1',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-15T15:05:12.266',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-21T00:00:00.000',
#   'state': 'IA',
#   'tot_cases': '207675',
#   'new_case': '3700.0',
#   'pnew_case': '536',
#   'tot_death': '2160',
#   'new_death': '25.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-22T15:02:23.399',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-10-28T00:00:00.000',
#   'state': 'ID',
#   'tot_cases': '61785',
#   'conf_cases': '54193.0',
#   'prob_cases': '7592',
#   'new_case': '862.0',
#   'pnew_case': '208',
#   'tot_death': '599',
#   'conf_death': '555.0',
#   'prob_death': '44',
#   'new_death': '14.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-29T14:11:33.577',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-31T00:00:00.000',
#   'state': 'DC',
#   'tot_cases': '8801',
#   'new_case': '84.0',
#   'pnew_case': '0',
#   'tot_death': '466',
#   'new_death': '4.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-01T14:17:42.906'},
#  {'submission_date': '2020-05-21T00:00:00.000',
#   'state': 'CO',
#   'tot_cases': '23121',
#   'conf_cases': '20903.0',
#   'prob_cases': '2218',
#   'new_case': '369.0',
#   'pnew_case': '61',
#   'tot_death': '1309',
#   'conf_death': '1036.0',
#   'prob_death': '273',
#   'new_death': '10.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-22T15:31:45.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-17T00:00:00.000',
#   'state': 'GA',
#   'tot_cases': '430571',
#   'conf_cases': '391466.0',
#   'prob_cases': '39105',
#   'new_case': '4335.0',
#   'pnew_case': '799',
#   'tot_death': '9008',
#   'conf_death': '8496.0',
#   'prob_death': '512',
#   'new_death': '41.0',
#   'pnew_death': '16',
#   'created_at': '2020-11-18T14:57:46.366',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-09T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-07T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '53976',
#   'new_case': '1337.0',
#   'pnew_case': '242',
#   'tot_death': '523',
#   'conf_death': '486.0',
#   'prob_death': '37',
#   'new_death': '13.0',
#   'pnew_death': '3',
#   'created_at': '2020-11-08T14:40:34.096',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-09T00:00:00.000',
#   'state': 'NV',
#   'tot_cases': '10030',
#   'new_case': '225.0',
#   'pnew_case': '-19',
#   'tot_death': '444',
#   'new_death': '-17.0',
#   'pnew_death': '-19',
#   'created_at': '2020-06-10T20:56:25.490'},
#  {'submission_date': '2020-10-21T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '35044',
#   'new_case': '587.0',
#   'pnew_case': '22',
#   'tot_death': '333',
#   'conf_death': '320.0',
#   'prob_death': '13',
#   'new_death': '3.0',
#   'pnew_death': '8',
#   'created_at': '2020-10-22T13:34:46.095',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-05T00:00:00.000',
#   'state': 'RMI',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-06T14:31:37.908',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-16T00:00:00.000',
#   'state': 'NV',
#   'tot_cases': '3321',
#   'new_case': '110.0',
#   'tot_death': '142',
#   'new_death': '5.0',
#   'created_at': '2020-04-16T16:22:39.452'},
#  {'submission_date': '2020-02-08T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-23T00:00:00.000',
#   'state': 'NC',
#   'tot_cases': '22726',
#   'conf_cases': '22725.0',
#   'prob_cases': '1',
#   'new_case': '1107.0',
#   'pnew_case': '0',
#   'tot_death': '737',
#   'conf_death': '737.0',
#   'prob_death': '0',
#   'new_death': '9.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-13T19:10:12.893',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-28T00:00:00.000',
#   'state': 'SC',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-26T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-27T15:37:59.621'},
#  {'submission_date': '2020-10-11T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-12T14:07:08.478'},
#  {'submission_date': '2020-03-23T00:00:00.000',
#   'state': 'ME',
#   'tot_cases': '109',
#   'new_case': '16.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-19T00:00:00.000',
#   'state': 'TX',
#   'tot_cases': '1573888',
#   'new_case': '17907.0',
#   'pnew_case': '4102',
#   'tot_death': '25226',
#   'new_death': '272.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-22T22:17:06.352',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-05-01T00:00:00.000',
#   'state': 'MO',
#   'tot_cases': '7835',
#   'new_case': '273.0',
#   'pnew_case': '0',
#   'tot_death': '337',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-02T15:47:19.352',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-09-13T00:00:00.000',
#   'state': 'MS',
#   'tot_cases': '90018',
#   'conf_cases': '84557.0',
#   'prob_cases': '5461',
#   'new_case': '144.0',
#   'pnew_case': '38',
#   'tot_death': '2706',
#   'conf_death': '2523.0',
#   'prob_death': '183',
#   'new_death': '9.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-14T14:01:21.851',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-02-07T00:00:00.000',
#   'state': 'RMI',
#   'tot_cases': '4',
#   'conf_cases': '4.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-02-08T14:53:12.094',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-06T00:00:00.000',
#   'state': 'MT',
#   'tot_cases': '15723',
#   'conf_cases': '15723.0',
#   'prob_cases': '0',
#   'new_case': '425.0',
#   'pnew_case': '0',
#   'tot_death': '192',
#   'conf_death': '192.0',
#   'prob_death': '0',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-07T13:45:01.309',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-03T00:00:00.000',
#   'state': 'NY',
#   'tot_cases': '248091',
#   'new_case': '1519.0',
#   'pnew_case': '0',
#   'tot_death': '9290',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-04T15:03:00.406',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-14T00:00:00.000',
#   'state': 'MS',
#   'tot_cases': '37542',
#   'conf_cases': '37198.0',
#   'prob_cases': '344',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '1272',
#   'conf_death': '1249.0',
#   'prob_death': '23',
#   'new_death': '-1.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-15T15:05:12.266',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-21T00:00:00.000',
#   'state': 'ND',
#   'tot_cases': '9736',
#   'conf_cases': '9736.0',
#   'prob_cases': '0',
#   'new_case': '262.0',
#   'pnew_case': '0',
#   'tot_death': '135',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-22T14:21:09.869',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-10-06T00:00:00.000',
#   'state': 'ID',
#   'tot_cases': '45082',
#   'conf_cases': '40685.0',
#   'prob_cases': '4397',
#   'new_case': '660.0',
#   'pnew_case': '106',
#   'tot_death': '492',
#   'conf_death': '452.0',
#   'prob_death': '40',
#   'new_death': '5.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-07T13:45:01.309',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-20T00:00:00.000',
#   'state': 'LA',
#   'tot_cases': '140821',
#   'new_case': '918.0',
#   'pnew_case': '0',
#   'tot_death': '4637',
#   'conf_death': '4496.0',
#   'prob_death': '141',
#   'new_death': '28.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-21T14:27:34.675',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-27T00:00:00.000',
#   'state': 'WI',
#   'tot_cases': '16462',
#   'conf_cases': '16462.0',
#   'prob_cases': '0',
#   'new_case': '599.0',
#   'pnew_case': '0',
#   'tot_death': '539',
#   'conf_death': '539.0',
#   'prob_death': '0',
#   'new_death': '22.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-28T15:12:25.989',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-12T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '3',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-13T14:44:58.633'},
#  {'submission_date': '2020-03-17T00:00:00.000',
#   'state': 'NM',
#   'tot_cases': '23',
#   'new_case': '2.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-08-31T00:00:00.000',
#   'state': 'KS',
#   'tot_cases': '42612',
#   'conf_cases': '41425.0',
#   'prob_cases': '1187',
#   'new_case': '1564.0',
#   'pnew_case': '0',
#   'tot_death': '446',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-01T14:09:34.811',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-03-11T00:00:00.000',
#   'state': 'NY',
#   'tot_cases': '164',
#   'new_case': '27.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-28T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-29T00:00:00.000',
#   'state': 'TX',
#   'tot_cases': '1715978',
#   'new_case': '32552.0',
#   'pnew_case': '4532',
#   'tot_death': '26762',
#   'new_death': '241.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-30T14:56:20.759',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-11-17T00:00:00.000',
#   'state': 'OK',
#   'tot_cases': '169762',
#   'conf_cases': '143221.0',
#   'prob_cases': '26541',
#   'new_case': '7389.0',
#   'pnew_case': '1406',
#   'tot_death': '1592',
#   'conf_death': '1531.0',
#   'prob_death': '61',
#   'new_death': '49.0',
#   'pnew_death': '6',
#   'created_at': '2020-11-18T14:57:46.366',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-12T00:00:00.000',
#   'state': 'IA',
#   'tot_cases': '298406',
#   'new_case': '1105.0',
#   'pnew_case': '460',
#   'tot_death': '4222',
#   'new_death': '83.0',
#   'pnew_death': '83',
#   'created_at': '2021-01-13T14:44:58.633',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-03-09T00:00:00.000',
#   'state': 'NYC',
#   'tot_cases': '17',
#   'new_case': '5.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-11T00:00:00.000',
#   'state': 'ND',
#   'tot_cases': '94968',
#   'conf_cases': '91357.0',
#   'prob_cases': '3611',
#   'new_case': '138.0',
#   'pnew_case': '89',
#   'tot_death': '1355',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-12T14:48:35.544',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-12-15T00:00:00.000',
#   'state': 'FSM',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-16T14:28:57.146',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-23T00:00:00.000',
#   'state': 'MP',
#   'tot_cases': '38',
#   'conf_cases': '38.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '2',
#   'conf_death': '2.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-24T14:18:40.590',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-30T00:00:00.000',
#   'state': 'TN',
#   'tot_cases': '259488',
#   'conf_cases': '244886.0',
#   'prob_cases': '14602',
#   'new_case': '2608.0',
#   'pnew_case': '297',
#   'tot_death': '3341',
#   'conf_death': '3156.0',
#   'prob_death': '185',
#   'new_death': '78.0',
#   'pnew_death': '9',
#   'created_at': '2020-10-31T13:30:31.395',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-02T00:00:00.000',
#   'state': 'HI',
#   'tot_cases': '956',
#   'new_case': '28.0',
#   'pnew_case': '0',
#   'tot_death': '18',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-03T11:01:33.000',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-10-28T00:00:00.000',
#   'state': 'AR',
#   'tot_cases': '108640',
#   'new_case': '961.0',
#   'pnew_case': '271',
#   'tot_death': '1875',
#   'new_death': '18.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-29T14:11:33.577',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-09-07T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '11575',
#   'conf_cases': '11368.0',
#   'prob_cases': '207',
#   'new_case': '163.0',
#   'pnew_case': '9',
#   'tot_death': '247',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-08T14:47:00.875',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-31T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '66154',
#   'new_case': '901.0',
#   'pnew_case': '0',
#   'tot_death': '2965',
#   'conf_death': '2765.0',
#   'prob_death': '200',
#   'new_death': '19.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-01T14:38:12.337',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-22T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '21057',
#   'conf_cases': '19907.0',
#   'prob_cases': '1150',
#   'new_case': '323.0',
#   'pnew_case': '80',
#   'tot_death': '418',
#   'new_death': '5.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-23T13:44:31.471',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-01-27T00:00:00.000',
#   'state': 'AL',
#   'tot_cases': '449086',
#   'conf_cases': '354967.0',
#   'prob_cases': '94119',
#   'new_case': '3177.0',
#   'pnew_case': '1128',
#   'tot_death': '7172',
#   'conf_death': '5817.0',
#   'prob_death': '1355',
#   'new_death': '276.0',
#   'pnew_death': '97',
#   'created_at': '2021-01-28T14:49:07.741',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-06T00:00:00.000',
#   'state': 'SC',
#   'tot_cases': '14970',
#   'conf_cases': '14970.0',
#   'prob_cases': '0',
#   'new_case': '381.0',
#   'pnew_case': '0',
#   'tot_death': '579',
#   'conf_death': '579.0',
#   'prob_death': '0',
#   'new_death': '12.0',
#   'pnew_death': '0',
#   'created_at': '2021-02-08T00:00:00.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-27T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
#  {'submission_date': '2020-11-27T00:00:00.000',
#   'state': 'KS',
#   'tot_cases': '153021',
#   'conf_cases': '132785.0',
#   'prob_cases': '20236',
#   'new_case': '5224.0',
#   'pnew_case': '588',
#   'tot_death': '1529',
#   'new_death': '26.0',
#   'pnew_death': '5',
#   'created_at': '2020-11-28T14:46:47.693',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-08-17T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-18T14:26:55.280'},
#  {'submission_date': '2021-01-23T00:00:00.000',
#   'state': 'AL',
#   'tot_cases': '439442',
#   'conf_cases': '348017.0',
#   'prob_cases': '91425',
#   'new_case': '3355.0',
#   'pnew_case': '1015',
#   'tot_death': '6657',
#   'conf_death': '5464.0',
#   'prob_death': '1193',
#   'new_death': '171.0',
#   'pnew_death': '57',
#   'created_at': '2021-01-24T14:36:49.208',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-29T00:00:00.000',
#   'state': 'HI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-09T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-08-02T00:00:00.000',
#   'state': 'VT',
#   'tot_cases': '1426',
#   'new_case': '5.0',
#   'pnew_case': '0',
#   'tot_death': '57',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-03T14:31:01.928',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-06-23T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-24T15:03:27.381'},
#  {'submission_date': '2020-09-06T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '55347',
#   'conf_cases': '54878.0',
#   'prob_cases': '469',
#   'new_case': '341.0',
#   'pnew_case': '3',
#   'tot_death': '421',
#   'conf_death': '421.0',
#   'prob_death': '0',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-07T13:37:36.613',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-23T00:00:00.000',
#   'state': 'MN',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-04T00:00:00.000',
#   'state': 'LA',
#   'tot_cases': '152369',
#   'new_case': '822.0',
#   'pnew_case': '0',
#   'tot_death': '5035',
#   'conf_death': '4872.0',
#   'prob_death': '163',
#   'new_death': '14.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-05T14:09:45.109',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-21T00:00:00.000',
#   'state': 'NYC',
#   'tot_cases': '232789',
#   'conf_cases': '228144.0',
#   'prob_cases': '4645',
#   'new_case': '217.0',
#   'pnew_case': '0',
#   'tot_death': '23646',
#   'conf_death': '19014.0',
#   'prob_death': '4632',
#   'new_death': '5.0',
#   'pnew_death': '-2',
#   'created_at': '2020-08-22T14:21:09.869',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-16T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '4657',
#   'conf_cases': '4535.0',
#   'prob_cases': '122',
#   'new_case': '100.0',
#   'pnew_case': '4',
#   'tot_death': '99',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-17T14:31:01.339',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-09T00:00:00.000',
#   'state': 'ND',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-03-12T00:00:00.000',
#   'state': 'PR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-19T00:00:00.000',
#   'state': 'FL',
#   'tot_cases': '673194',
#   'new_case': '3510.0',
#   'pnew_case': '339',
#   'tot_death': '13287',
#   'new_death': '62.0',
#   'pnew_death': '9',
#   'created_at': '2020-09-20T13:53:10.094',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-09-23T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '113337',
#   'new_case': '711.0',
#   'pnew_case': '0',
#   'tot_death': '3530',
#   'conf_death': '3305.0',
#   'prob_death': '225',
#   'new_death': '10.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-24T13:54:02.843',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-20T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '12919',
#   'conf_cases': '12516.0',
#   'prob_cases': '403',
#   'new_case': '1317.0',
#   'pnew_case': '93',
#   'tot_death': '509',
#   'conf_death': '491.0',
#   'prob_death': '18',
#   'new_death': '38.0',
#   'pnew_death': '0',
#   'created_at': '2020-04-20T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-24T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '102196',
#   'conf_cases': '102196.0',
#   'prob_cases': '0',
#   'new_case': '2207.0',
#   'pnew_case': '0',
#   'tot_death': '5617',
#   'conf_death': '5617.0',
#   'prob_death': '0',
#   'new_death': '249.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-25T15:38:40.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-10T00:00:00.000',
#   'state': 'AL',
#   'tot_cases': '164526',
#   'conf_cases': '144901.0',
#   'prob_cases': '19625',
#   'new_case': '1061.0',
#   'pnew_case': '60',
#   'tot_death': '2664',
#   'conf_death': '2508.0',
#   'prob_death': '156',
#   'new_death': '11.0',
#   'pnew_death': '-1',
#   'created_at': '2020-10-11T13:47:22.472',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-15T00:00:00.000',
#   'state': 'KS',
#   'tot_cases': '7886',
#   'conf_cases': '7886.0',
#   'prob_cases': '0',
#   'new_case': '418.0',
#   'pnew_case': '0',
#   'tot_death': '172',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-16T15:46:44.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-12-26T00:00:00.000',
#   'state': 'FSM',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-27T14:44:47.209',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-12T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-07T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '102132',
#   'new_case': '448.0',
#   'pnew_case': '157',
#   'tot_death': '1544',
#   'conf_death': '1247.0',
#   'prob_death': '297',
#   'new_death': '25.0',
#   'pnew_death': '4',
#   'created_at': '2021-01-08T15:56:01.472',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-20T00:00:00.000',
#   'state': 'MD',
#   'tot_cases': '334519',
#   'new_case': '2166.0',
#   'pnew_case': '0',
#   'tot_death': '6735',
#   'conf_death': '6560.0',
#   'prob_death': '175',
#   'new_death': '46.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-21T14:44:32.423',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-07T00:00:00.000',
#   'state': 'PA',
#   'tot_cases': '166552',
#   'conf_cases': '160772.0',
#   'prob_cases': '5780',
#   'new_case': '1309.0',
#   'pnew_case': '127',
#   'tot_death': '8272',
#   'new_death': '28.0',
#   'pnew_death': '-16',
#   'created_at': '2020-10-08T13:56:57.885',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-10-20T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '96643',
#   'conf_cases': '96643.0',
#   'prob_cases': '0',
#   'new_case': '1081.0',
#   'pnew_case': '0',
#   'tot_death': '551',
#   'conf_death': '546.0',
#   'prob_death': '5',
#   'new_death': '5.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-21T13:34:31.370',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-26T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-16T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '821507',
#   'conf_cases': '725111.0',
#   'prob_cases': '96396',
#   'new_case': '7065.0',
#   'pnew_case': '1596',
#   'tot_death': '10135',
#   'conf_death': '9080.0',
#   'prob_death': '1055',
#   'new_death': '78.0',
#   'pnew_death': '28',
#   'created_at': '2021-01-17T15:43:14.832',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-16T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '225188',
#   'new_case': '1043.0',
#   'pnew_case': '233',
#   'tot_death': '16202',
#   'conf_death': '14413.0',
#   'prob_death': '1789',
#   'new_death': '5.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-07T18:54:20.981',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-13T00:00:00.000',
#   'state': 'VA',
#   'tot_cases': '417839',
#   'conf_cases': '343304.0',
#   'prob_cases': '74535',
#   'new_case': '5294.0',
#   'pnew_case': '1458',
#   'tot_death': '5626',
#   'conf_death': '4952.0',
#   'prob_death': '674',
#   'new_death': '74.0',
#   'pnew_death': '14',
#   'created_at': '2021-01-14T15:12:46.601',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-06T00:00:00.000',
#   'state': 'AL',
#   'tot_cases': '44909',
#   'conf_cases': '44405.0',
#   'prob_cases': '504',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '1009',
#   'conf_death': '986.0',
#   'prob_death': '23',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-07T14:58:02.598',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-25T00:00:00.000',
#   'state': 'MN',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-11T00:00:00.000',
#   'state': 'WV',
#   'tot_cases': '102282',
#   'conf_cases': '82440.0',
#   'prob_cases': '19842',
#   'new_case': '1070.0',
#   'pnew_case': '211',
#   'tot_death': '1594',
#   'new_death': '12.0',
#   'pnew_death': '3',
#   'created_at': '2021-01-12T14:48:35.544',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-01-02T00:00:00.000',
#   'state': 'PA',
#   'tot_cases': '657292',
#   'conf_cases': '589213.0',
#   'prob_cases': '68079',
#   'new_case': '9253.0',
#   'pnew_case': '1300',
#   'tot_death': '16239',
#   'new_death': '25.0',
#   'pnew_death': '23',
#   'created_at': '2021-01-03T14:53:25.031',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-05-05T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '21033',
#   'new_case': '526.0',
#   'pnew_case': '0',
#   'tot_death': '1326',
#   'conf_death': '1213.0',
#   'prob_death': '113',
#   'new_death': '62.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-06T16:23:08.000',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-28T00:00:00.000',
#   'state': 'RMI',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-29T13:42:50.366',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-12-26T00:00:00.000',
#   'state': 'DC',
#   'tot_cases': '27710',
#   'new_case': '274.0',
#   'pnew_case': '0',
#   'tot_death': '762',
#   'new_death': '6.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-27T14:44:47.209'},
#  {'submission_date': '2020-03-25T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '704',
#   'new_case': '140.0',
#   'tot_death': '10',
#   'new_death': '2.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-11T00:00:00.000',
#   'state': 'TX',
#   'tot_cases': '792478',
#   'new_case': '2418.0',
#   'pnew_case': '0',
#   'tot_death': '16557',
#   'new_death': '31.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-12T14:07:08.478',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-02-01T00:00:00.000',
#   'state': 'WI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-10T00:00:00.000',
#   'state': 'WA',
#   'tot_cases': '78467',
#   'new_case': '458.0',
#   'pnew_case': '0',
#   'tot_death': '1985',
#   'new_death': '7.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-11T13:51:03.398',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-02-10T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-25T00:00:00.000',
#   'state': 'FSM',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-26T13:46:07.689',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-28T00:00:00.000',
#   'state': 'ME',
#   'tot_cases': '11508',
#   'conf_cases': '10315.0',
#   'prob_cases': '1193',
#   'new_case': '220.0',
#   'pnew_case': '30',
#   'tot_death': '191',
#   'conf_death': '190.0',
#   'prob_death': '1',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-29T14:49:08.286',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-31T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '91159',
#   'conf_cases': '86333.0',
#   'prob_cases': '4826',
#   'new_case': '1533.0',
#   'pnew_case': '62',
#   'tot_death': '3489',
#   'conf_death': '3222.0',
#   'prob_death': '267',
#   'new_death': '47.0',
#   'pnew_death': '2',
#   'created_at': '2020-08-01T14:38:12.337',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-19T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '105786',
#   'new_case': '127.0',
#   'pnew_case': '15',
#   'tot_death': '1667',
#   'conf_death': '1346.0',
#   'prob_death': '321',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-20T14:44:03.544',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-19T00:00:00.000',
#   'state': 'UT',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-21T00:00:00.000',
#   'state': 'PA',
#   'tot_cases': '82186',
#   'conf_cases': '79859.0',
#   'prob_cases': '2327',
#   'new_case': '456.0',
#   'pnew_case': '2',
#   'tot_death': '6426',
#   'new_death': '3.0',
#   'pnew_death': '-2',
#   'created_at': '2020-06-22T15:24:02.542',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-01-17T00:00:00.000',
#   'state': 'MO',
#   'tot_cases': '437549',
#   'new_case': '1350.0',
#   'pnew_case': '0',
#   'tot_death': '6254',
#   'new_death': '1.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-18T14:39:32.141',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-10-06T00:00:00.000',
#   'state': 'WY',
#   'tot_cases': '6770',
#   'conf_cases': '5751.0',
#   'prob_cases': '1019',
#   'new_case': '141.0',
#   'pnew_case': '50',
#   'tot_death': '53',
#   'conf_death': '53.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-07T13:45:01.309',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-27T00:00:00.000',
#   'state': 'MD',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-31T00:00:00.000',
#   'state': 'GA',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-27T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '21541',
#   'new_case': '408.0',
#   'pnew_case': '0',
#   'tot_death': '218',
#   'conf_death': '216.0',
#   'prob_death': '2',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-28T13:50:59.474',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-22T00:00:00.000',
#   'state': 'CO',
#   'tot_cases': '41698',
#   'conf_cases': '38562.0',
#   'prob_cases': '3136',
#   'new_case': '639.0',
#   'pnew_case': '24',
#   'tot_death': '1771',
#   'conf_death': '1435.0',
#   'prob_death': '336',
#   'new_death': '8.0',
#   'pnew_death': '3',
#   'created_at': '2020-07-23T14:48:19.028',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-26T00:00:00.000',
#   'state': 'PR',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-14T00:00:00.000',
#   'state': 'TN',
#   'tot_cases': '670482',
#   'conf_cases': '576406.0',
#   'prob_cases': '94076',
#   'new_case': '4983.0',
#   'pnew_case': '1196',
#   'tot_death': '8232',
#   'conf_death': '6909.0',
#   'prob_death': '1323',
#   'new_death': '84.0',
#   'pnew_death': '31',
#   'created_at': '2021-01-15T14:46:04.456',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-06T00:00:00.000',
#   'state': 'ID',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-26T00:00:00.000',
#   'state': 'RI',
#   'tot_cases': '112396',
#   'new_case': '642.0',
#   'pnew_case': '0',
#   'tot_death': '2126',
#   'new_death': '16.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-27T14:53:24.793',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-01-23T00:00:00.000',
#   'state': 'MS',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-26T00:00:00.000',
#   'state': 'NV',
#   'tot_cases': '43067',
#   'new_case': '1030.0',
#   'pnew_case': '3',
#   'tot_death': '760',
#   'new_death': '2.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-27T14:16:42.667'},
#  {'submission_date': '2020-05-24T00:00:00.000',
#   'state': 'CA',
#   'tot_cases': '92710',
#   'new_case': '2079.0',
#   'pnew_case': '0',
#   'tot_death': '3774',
#   'new_death': '66.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-25T14:12:49.524',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-09-14T00:00:00.000',
#   'state': 'MT',
#   'tot_cases': '9107',
#   'conf_cases': '9107.0',
#   'prob_cases': '0',
#   'new_case': '86.0',
#   'pnew_case': '0',
#   'tot_death': '138',
#   'conf_death': '138.0',
#   'prob_death': '0',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-15T14:03:59.985',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-19T00:00:00.000',
#   'state': 'DC',
#   'tot_cases': '71',
#   'new_case': '32.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
#  {'submission_date': '2020-02-23T00:00:00.000',
#   'state': 'NY',
#   'tot_cases': '0',
#   'new_case': '0.0',
# ...
#   'pnew_death': '0',
#   'created_at': '2020-05-05T17:25:08.000',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-06-26T00:00:00.000',
#   'state': 'RMI',
#   'tot_cases': '0',
#   'conf_cases': '0.0',
#   'prob_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-27T17:51:58.649',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-13T00:00:00.000',
#   'state': 'MO',
#   'tot_cases': '63797',
#   'new_case': '1267.0',
#   'pnew_case': '0',
#   'tot_death': '1325',
#   'new_death': '2.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-14T14:30:03.326',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-11-19T00:00:00.000',
#   'state': 'NYC',
#   'tot_cases': '292718',
#   'conf_cases': '276498.0',
#   'prob_cases': '16220',
#   'new_case': '1930.0',
#   'pnew_case': '438',
#   'tot_death': '24188',
#   'conf_death': '19517.0',
#   'prob_death': '4671',
#   'new_death': '21.0',
#   'pnew_death': '9',
#   'created_at': '2020-11-20T15:06:16.717',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-11T00:00:00.000',
#   'state': 'SC',
#   'tot_cases': '378731',
#   'conf_cases': '339673.0',
#   'prob_cases': '39058',
#   'new_case': '4738.0',
#   'pnew_case': '765',
#   'tot_death': '6288',
#   'conf_death': '5680.0',
#   'prob_death': '608',
#   'new_death': '52.0',
#   'pnew_death': '9',
#   'created_at': '2021-02-08T00:00:00.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-30T00:00:00.000',
#   'state': 'MT',
#   'tot_cases': '31916',
#   'conf_cases': '31916.0',
#   'prob_cases': '0',
#   'new_case': '1063.0',
#   'pnew_case': '0',
#   'tot_death': '364',
#   'conf_death': '364.0',
#   'prob_death': '0',
#   'new_death': '27.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-31T13:30:31.395',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-04-12T00:00:00.000',
#   'state': 'NV',
#   'tot_cases': '2836',
#   'new_case': '136.0',
#   'tot_death': '114',
#   'new_death': '2.0',
#   'created_at': '2020-04-11T16:22:39.452'},
#  {'submission_date': '2020-06-13T00:00:00.000',
#   'state': 'AZ',
#   'tot_cases': '34458',
#   'conf_cases': '34146.0',
#   'prob_cases': '312',
#   'new_case': '1540.0',
#   'pnew_case': '-4',
#   'tot_death': '1183',
#   'conf_death': '1116.0',
#   'prob_death': '67',
#   'new_death': '39.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-14T14:19:43.716',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-18T00:00:00.000',
#   'state': 'TX',
#   'tot_cases': '48693',
#   'new_case': '909.0',
#   'pnew_case': '0',
#   'tot_death': '1347',
#   'new_death': '11.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-19T15:45:23.000',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2021-01-07T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '3',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-08T15:56:01.472'},
#  {'submission_date': '2020-06-15T00:00:00.000',
#   'state': 'OK',
#   'tot_cases': '8251',
#   'conf_cases': '8237.0',
#   'prob_cases': '14',
#   'new_case': '20.0',
#   'pnew_case': '14',
#   'tot_death': '371',
#   'conf_death': '371.0',
#   'prob_death': '0',
#   'new_death': '12.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-16T14:10:11.939',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-02T00:00:00.000',
#   'state': 'NC',
#   'tot_cases': '1',
#   'conf_cases': '1.0',
#   'prob_cases': '0',
#   'new_case': '1.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'conf_death': '0.0',
#   'prob_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-13T19:10:12.893',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-15T00:00:00.000',
#   'state': 'MN',
#   'tot_cases': '117106',
#   'new_case': '1163.0',
#   'pnew_case': '61',
#   'tot_death': '2199',
#   'conf_death': '2192.0',
#   'prob_death': '7',
#   'new_death': '-28.0',
#   'pnew_death': '-46',
#   'created_at': '2020-10-16T13:33:55.808',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-10T00:00:00.000',
#   'state': 'OK',
#   'tot_cases': '103382',
#   'conf_cases': '91591.0',
#   'prob_cases': '11791',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '1097',
#   'conf_death': '1077.0',
#   'prob_death': '20',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-11T13:47:22.472',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-27T00:00:00.000',
#   'state': 'CT',
#   'tot_cases': '1291',
#   'new_case': '279.0',
#   'tot_death': '27',
#   'new_death': '6.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-07-06T00:00:00.000',
#   'state': 'CT',
#   'tot_cases': '46976',
#   'conf_cases': '44997.0',
#   'prob_cases': '1979',
#   'new_case': '259.0',
#   'pnew_case': '3',
#   'tot_death': '4338',
#   'conf_death': '3466.0',
#   'prob_death': '872',
#   'new_death': '3.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-07T14:58:02.598',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-29T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-10T00:00:00.000',
#   'state': 'SD',
#   'tot_cases': '9663',
#   'new_case': '58.0',
#   'pnew_case': '0',
#   'tot_death': '146',
#   'conf_death': '144.0',
#   'prob_death': '2',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-11T14:16:27.891',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-23T00:00:00.000',
#   'state': 'OH',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-08-05T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-08-06T14:12:27.571'},
#  {'submission_date': '2020-11-09T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-10T14:45:45.196'},
#  {'submission_date': '2020-03-31T00:00:00.000',
#   'state': 'AL',
#   'tot_cases': '999',
#   'new_case': '52.0',
#   'tot_death': '13',
#   'new_death': '7.0',
#   'created_at': '2020-03-30T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-09T00:00:00.000',
#   'state': 'RI',
#   'tot_cases': '38009',
#   'new_case': '1629.0',
#   'pnew_case': '0',
#   'tot_death': '1233',
#   'new_death': '9.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-10T14:45:45.196',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-10-21T00:00:00.000',
#   'state': 'NH',
#   'tot_cases': '9917',
#   'new_case': '89.0',
#   'pnew_case': '40',
#   'tot_death': '469',
#   'new_death': '1.0',
#   'pnew_death': '1',
#   'created_at': '2020-10-22T13:34:46.095',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-03-26T00:00:00.000',
#   'state': 'RMI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-15T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '39',
#   'new_case': '15.0',
#   'tot_death': '1',
#   'new_death': '1.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-09-10T00:00:00.000',
#   'state': 'MO',
#   'tot_cases': '97591',
#   'new_case': '1116.0',
#   'pnew_case': '0',
#   'tot_death': '1691',
#   'new_death': '18.0',
#   'pnew_death': '0',
#   'created_at': '2020-09-11T13:51:03.398',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-11-01T00:00:00.000',
#   'state': 'SC',
#   'tot_cases': '180096',
#   'conf_cases': '170290.0',
#   'prob_cases': '9806',
#   'new_case': '893.0',
#   'pnew_case': '69',
#   'tot_death': '4021',
#   'conf_death': '3771.0',
#   'prob_death': '250',
#   'new_death': '18.0',
#   'pnew_death': '2',
#   'created_at': '2021-02-08T00:00:00.000',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-18T00:00:00.000',
#   'state': 'CO',
#   'tot_cases': '216',
#   'new_case': '33.0',
#   'tot_death': '2',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-01-06T00:00:00.000',
#   'state': 'TX',
#   'tot_cases': '1867163',
#   'new_case': '24010.0',
#   'pnew_case': '4196',
#   'tot_death': '28545',
#   'new_death': '326.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-07T14:56:59.705',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-11-13T00:00:00.000',
#   'state': 'KS',
#   'tot_cases': '115507',
#   'conf_cases': '101914.0',
#   'prob_cases': '13593',
#   'new_case': '6282.0',
#   'pnew_case': '1220',
#   'tot_death': '1259',
#   'new_death': '44.0',
#   'pnew_death': '9',
#   'created_at': '2020-11-14T14:44:40.037',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-03-04T00:00:00.000',
#   'state': 'CT',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-31T00:00:00.000',
#   'state': 'IA',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-12-04T00:00:00.000',
#   'state': 'NM',
#   'tot_cases': '104935',
#   'new_case': '2073.0',
#   'pnew_case': '0',
#   'tot_death': '1706',
#   'new_death': '33.0',
#   'pnew_death': '0',
#   'created_at': '2020-12-05T14:29:17.537',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-07-17T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '54813',
#   'new_case': '733.0',
#   'pnew_case': '0',
#   'tot_death': '2803',
#   'conf_death': '2610.0',
#   'prob_death': '193',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2020-07-18T16:14:26.601',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-29T00:00:00.000',
#   'state': 'VI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
#  {'submission_date': '2020-03-07T00:00:00.000',
#   'state': 'OR',
#   'tot_cases': '7',
#   'new_case': '4.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-05-12T00:00:00.000',
#   'state': 'NJ',
#   'tot_cases': '140851',
#   'new_case': '814.0',
#   'pnew_case': '16',
#   'tot_death': '9508',
#   'conf_death': '9508.0',
#   'prob_death': '0',
#   'new_death': '198.0',
#   'pnew_death': '0',
#   'created_at': '2021-01-07T18:54:20.981',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-01-22T00:00:00.000',
#   'state': 'MD',
#   'tot_cases': '0',
#   'new_case': '0',
#   'tot_death': '0',
#   'new_death': '0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-02-16T00:00:00.000',
#   'state': 'CT',
#   'tot_cases': '270822',
#   'conf_cases': '254194.0',
#   'prob_cases': '16628',
#   'new_case': '580.0',
#   'pnew_case': '42',
#   'tot_death': '7449',
#   'conf_death': '6106.0',
#   'prob_death': '1343',
#   'new_death': '2.0',
#   'pnew_death': '1',
#   'created_at': '2021-02-17T14:51:58.706',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-06-10T00:00:00.000',
#   'state': 'MN',
#   'tot_cases': '29316',
#   'new_case': '447.0',
#   'pnew_case': '0',
#   'tot_death': '1280',
#   'conf_death': '1249.0',
#   'prob_death': '31',
#   'new_death': '13.0',
#   'pnew_death': '0',
#   'created_at': '2020-06-11T14:48:51.509',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2021-02-16T00:00:00.000',
#   'state': 'DE',
#   'tot_cases': '83369',
#   'conf_cases': '79071.0',
#   'prob_cases': '4298',
#   'new_case': '130.0',
#   'pnew_case': '13',
#   'tot_death': '1291',
#   'conf_death': '1168.0',
#   'prob_death': '123',
#   'new_death': '8.0',
#   'pnew_death': '0',
#   'created_at': '2021-02-17T14:51:58.706',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-17T00:00:00.000',
#   'state': 'PW',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'pnew_case': '0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-18T14:57:46.366'},
#  {'submission_date': '2020-06-10T00:00:00.000',
#   'state': 'IN',
#   'tot_cases': '38337',
#   'new_case': '304.0',
#   'pnew_case': '0',
#   'tot_death': '2355',
#   'conf_death': '2173.0',
#   'prob_death': '182',
#   'new_death': '16.0',
#   'pnew_death': '1',
#   'created_at': '2020-06-11T14:48:51.509',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-03-16T00:00:00.000',
#   'state': 'TN',
#   'tot_cases': '52',
#   'new_case': '13.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-02-21T00:00:00.000',
#   'state': 'VI',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
#  {'submission_date': '2021-01-28T00:00:00.000',
#   'state': 'VA',
#   'tot_cases': '497912',
#   'conf_cases': '399577.0',
#   'prob_cases': '98335',
#   'new_case': '4238.0',
#   'pnew_case': '1101',
#   'tot_death': '6379',
#   'conf_death': '5606.0',
#   'prob_death': '773',
#   'new_death': '71.0',
#   'pnew_death': '31',
#   'created_at': '2021-01-29T14:42:19.981',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-10-06T00:00:00.000',
#   'state': 'WA',
#   'tot_cases': '90663',
#   'new_case': '387.0',
#   'pnew_case': '0',
#   'tot_death': '2165',
#   'new_death': '7.0',
#   'pnew_death': '0',
#   'created_at': '2020-10-07T13:45:01.309',
#   'consent_cases': 'N/A',
#   'consent_deaths': 'N/A'},
#  {'submission_date': '2020-03-23T00:00:00.000',
#   'state': 'AS',
#   'tot_cases': '0',
#   'new_case': '0.0',
#   'tot_death': '0',
#   'new_death': '0.0',
#   'created_at': '2020-03-26T16:22:39.452'},
#  {'submission_date': '2021-01-05T00:00:00.000',
#   'state': 'TN',
#   'tot_cases': '617649',
#   'conf_cases': '537128.0',
#   'prob_cases': '80521',
#   'new_case': '5399.0',
#   'pnew_case': '2745',
#   'tot_death': '7267',
#   'conf_death': '6241.0',
#   'prob_death': '1026',
#   'new_death': '99.0',
#   'pnew_death': '40',
#   'created_at': '2021-01-06T14:58:26.308',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Agree'},
#  {'submission_date': '2020-11-24T00:00:00.000',
#   'state': 'ND',
#   'tot_cases': '75478',
#   'conf_cases': '75478.0',
#   'prob_cases': '0',
#   'new_case': '1077.0',
#   'pnew_case': '0',
#   'tot_death': '887',
#   'new_death': '4.0',
#   'pnew_death': '0',
#   'created_at': '2020-11-25T14:53:15.184',
#   'consent_cases': 'Agree',
#   'consent_deaths': 'Not agree'},
#  {'submission_date': '2020-04-25T00:00:00.000',
#   'state': 'TX',
#   'tot_cases': '23773',
#   'new_case': '967.0',
#   'pnew_case': '0',
#   'tot_death': '623',
#   'new_death': '30.0',
#   'pnew_death': '0',
#   'created_at': '2020-05-25T15:38:40.000',
#   'consent_cases': 'Not agree',
#   'consent_deaths': 'Not agree'}]

# %%
# COVID Cases and Deaths Per State (cont.)

# Create DataFrame out of .json
df_state_data = pd.DataFrame(st_case_death_json)

# Print DF_State_Data
df_state_data
df_state_data.head()

# Select Necessary Data
df_state_data = pd.DataFrame(df_state_data, columns=['submission_date','state','tot_cases','new_case','tot_death','new_death'])

# Print DF_State_Data
df_state_data

# Rename Columns and Print
df_state_data.rename(columns = {'submission_date':'Submission_Date','state':'State','tot_cases':'Tot_Cases','new_case':'New_Case','tot_death':'Tot_Death','new_death':'New_Death'})
# Out:
#              Submission_Date State Tot_Cases New_Case Tot_Death New_Death
# 0    2020-05-04T00:00:00.000    KY      5245    115.0       261       8.0
# 1    2020-03-23T00:00:00.000    NH       101     23.0         1       1.0
# 2    2020-12-08T00:00:00.000    OK    205999      0.0      1752       0.0
# 3    2020-10-28T00:00:00.000    RI     31944    499.0      1192       4.0
# 4    2020-08-21T00:00:00.000    MD    103523    624.0      3685      11.0
# ..                       ...   ...       ...      ...       ...       ...
# 995  2021-01-04T00:00:00.000    MS    225444   1767.0      4975      91.0
# 996  2020-08-07T00:00:00.000    PW         0      0.0         0       0.0
# 997  2020-12-09T00:00:00.000    OK    228413  22414.0      1930     178.0
# 998  2021-01-29T00:00:00.000    WA    309801   1992.0      4285      42.0
# 999  2020-09-23T00:00:00.000    TX    719599   3392.0     15129     135.0
#
# [1000 rows x 6 columns]

# %%
# COVID Cases and Deaths Per State (cont.)

# Build DataFrame for Selected State 
df_tx = df_state_data[df_state_data.state=="TX"][['submission_date','state','tot_cases','new_case','tot_death','new_death']]

# Print
df_tx

# Sort by Increasing Submission Date and Print
sort_by_df_tx = df_tx.sort_values('submission_date')
sort_by_df_tx

# Rename Columns and Print
sort_by_df_tx.rename(columns = {'submission_date':'Submission_Date','state':'State','tot_cases':'Tot_Cases','new_case':'New_Case','tot_death':'Tot_Death','new_death':'New_Death'})
# Out:
#              Submission_Date State Tot_Cases New_Case Tot_Death New_Death
# 802  2020-03-08T00:00:00.000    TX         6      1.0         0       0.0
# 903  2020-03-23T00:00:00.000    TX       507      0.0         8       3.0
# 955  2020-05-18T00:00:00.000    TX     48693    909.0      1347      11.0
# 932  2020-06-06T00:00:00.000    TX     73553   1940.0      1819      31.0
# 930  2020-09-12T00:00:00.000    TX    657589   4233.0     14143     146.0
# 999  2020-09-23T00:00:00.000    TX    719599   3392.0     15129     135.0
# 851  2020-10-02T00:00:00.000    TX    756004   3503.0     15895      72.0
# 120  2020-10-11T00:00:00.000    TX    792478   2418.0     16557      31.0
# 43   2020-11-09T00:00:00.000    TX   1038964   4849.0     18769      26.0
# 682  2020-11-10T00:00:00.000    TX   1052159  13195.0     18863      94.0
# 400  2020-12-03T00:00:00.000    TX   1333746  17552.0     22000     244.0
# 68   2020-12-29T00:00:00.000    TX   1715978  32552.0     26762     241.0
# 977  2021-01-06T00:00:00.000    TX   1867163  24010.0     28545     326.0
# 355  2021-02-01T00:00:00.000    TX   2392443  31811.0     36539      48.0
# 135  2021-02-06T00:00:00.000    TX   2476783  13897.0     38476     348.0

# %%
# Total Shipment Amounts of Moderna Vaccinations - State level

# Moderna API
mod_url = "https://data.cdc.gov/resource/b7pe-5nws.json"

# query_mod_url = f"{mod_url}"

# print(query_url2)
mod_url

# vacc_response = requests.get(query_url2)
mod_json = requests.get(mod_url).json()

mod_json[0]

# Revised DataFrame 
df_mod_vac = pd.DataFrame(mod_json)

#Print
df_mod_vac
df_mod_vac.rename(columns = {'jurisdiction':'Jurisdiction','total_allocation_moderna_second_dose_shipments':'Total_Wk_Two','total_moderna_allocation_first_dose_shipments':'Total_Wk_One'})
# Out:
#              Jurisdiction hhs_region doses_allocated_week_12_21  \
# 0             Connecticut   Region 1                     63,300
# 1                   Maine   Region 1                     24,200
# 2           Massachusetts   Region 1                    121,900
# 3           New Hampshire   Region 1                     24,200
# 4            Rhode Island   Region 1                     19,000
# ..                    ...        ...                        ...
# 61                  Idaho  Region 10                     28,000
# 62              Oregon***  Region 10                     72,100
# 63          Washington***  Region 10                    128,000
# 64  Federal Entities ****        N/A                    298,200
# 65                  Total        NaN                  5,990,000
#
#    second_dose_shipment_12_21 doses_allocated_week_12_28  \
# 0                      63,300                     21,900
# 1                      24,200                      8,400
# 2                     121,900                     42,100
# 3                      24,200                      8,400
# 4                      19,000                      6,600
# ..                        ...                        ...
# 61                     28,000                      9,700
# 62                     72,100                     25,000
# 63                    128,000                     44,300
# 64                    289,200                    100,000
# 65                  5,948,600                  2,047,300
#
#    second_dose_shipment_12_28 doses_allocated_week_01_04  \
# 0                      21,900                     21,800
# 1                       8,400                      8,300
# 2                      42,100                     42,000
# 3                       8,400                      8,400
# 4                       6,600                      6,600
# ..                        ...                        ...
# 61                      9,700                      9,700
# 62                     25,000                     24,800
# 63                     44,300                     44,100
# 64                    100,000                    108,400
# 65                  2,047,300                  2,104,400
#
#    second_dose_shipment_01_04 doses_allocated_week_of_01_10  \
# 0                      21,800                        21,900
# 1                       8,300                         8,400
# 2                      42,000                        42,100
# 3                       8,400                         8,400
# 4                       6,600                         6,600
# ..                        ...                           ...
# 61                      9,700                         9,700
# 62                     24,800                        25,000
# 63                     44,100                        44,300
# 64                     99,600                        99,900
# 65                  2,064,400                     2,047,200
#
#    second_dose_shipment_week_of_01_10  ... doses_allocated_week_of_02_01  \
# 0                              21,900  ...                        30,300
# 1                               8,400  ...                        11,600
# 2                              42,100  ...                        58,400
# 3                               8,400  ...                        11,600
# 4                               6,600  ...                         9,100
# ..                                ...  ...                           ...
# 61                              9,700  ...                        13,400
# 62                             25,000  ...                        34,600
# 63                             44,300  ...                        61,300
# 64                             99,900  ...                       149,400
# 65                          2,047,200  ...                     2,913,400
#
#    second_dose_shipment_week_of_02_01 doses_allocated_week_of_02_08  \
# 0                              30,300                        33,100
# 1                              11,600                        12,700
# 2                              58,400                        63,800
# 3                              11,600                        12,700
# 4                               9,100                        10,000
# ..                                ...                           ...
# 61                             13,400                        14,700
# 62                             34,600                        37,800
# 63                             61,300                        67,000
# 64                            138,600                       481,400
# 65                          2,868,200                     3,430,000
#
#    second_dose_shipment_week_of_02_08 doses_allocated_week_of_02_15  \
# 0                              33,100                        35,800
# 1                              12,700                        13,700
# 2                              63,800                        69,000
# 3                              12,700                        13,700
# 4                              10,000                        10,800
# ..                                ...                           ...
# 61                             14,700                        15,800
# 62                             37,800                        40,800
# 63                             67,000                        72,400
# 64                            481,400                       165,500
# 65                          3,430,000                     3,352,000
#
#    second_dose_shipment_week_of_02_15 doses_allocated_week_of_02_22  \
# 0                              35,800                        35,800
# 1                              13,700                        13,700
# 2                              69,000                        69,000
# 3                              13,700                        13,700
# 4                              10,800                        10,800
# ..                                ...                           ...
# 61                             15,800                        15,800
# 62                             40,800                        40,800
# 63                             72,400                        72,400
# 64                            165,500                       163,500
# 65                          3,352,000                     3,350,000
#
#    second_dose_week_of_02_22 Total_Wk_One Total_Wk_Two
# 0                     35,800      309,900      309,900
# 1                     13,700      118,600      118,600
# 2                     69,000      596,900      596,900
# 3                     13,700      118,700      118,700
# 4                     10,800       93,300       93,300
# ..                       ...          ...          ...
# 61                    15,800      137,200      137,200
# 62                    40,800      353,300      353,300
# 63                    72,400      626,800      626,800
# 64                   163,500    1,776,300    1,747,700
# 65                 3,350,000          NaN          NaN
#
# [66 rows x 24 columns]

# %%
# Moderna Vacinnations (cont.)

# Filter Out Necessary Data and Create New DataFrame
df_vac_mod = pd.DataFrame(df_mod_vac, columns=['jurisdiction','total_allocation_moderna_second_dose_shipments','total_moderna_allocation_first_dose_shipments'])

# Print 
df_vac_mod

# Set Index Info to Have States as Row Data
df_vac_mod.set_index('jurisdiction')

# Add New Column and Print
df_vac_mod['Total_Doses_Shipped'] = True
df_vac_mod

# Rename Columns and Print
df_vac_mod.rename(columns = {'jurisdiction':'Jurisdiction','total_allocation_moderna_second_dose_shipments':'Total_Wk_Two','total_moderna_allocation_first_dose_shipments':'Total_Wk_One'})
# Out:
#              Jurisdiction Total_Wk_Two Total_Wk_One  Total_Doses_Shipped
# 0             Connecticut      309,900      309,900                 True
# 1                   Maine      118,600      118,600                 True
# 2           Massachusetts      596,900      596,900                 True
# 3           New Hampshire      118,700      118,700                 True
# 4            Rhode Island       93,300       93,300                 True
# ..                    ...          ...          ...                  ...
# 61                  Idaho      137,200      137,200                 True
# 62              Oregon***      353,300      353,300                 True
# 63          Washington***      626,800      626,800                 True
# 64  Federal Entities ****    1,747,700    1,776,300                 True
# 65                  Total          NaN          NaN                 True
#
# [66 rows x 4 columns]

# %%
# Moderna Vacinnations (cont.)
# Computing Totals
df_vac_mod["Total_Doses_Shipped"] = df_vac_mod["total_moderna_allocation_first_dose_shipments"] + df_vac_mod["total_allocation_moderna_second_dose_shipments"]

# Print
df_vac_mod

 # Rename
df_vac_mod.rename(columns = {'jurisdiction':'Jurisdiction','total_allocation_moderna_second_dose_shipments':'Total_Wk_Two','total_moderna_allocation_first_dose_shipments':'Total_Wk_One'})
# Out:
#              Jurisdiction Total_Wk_Two Total_Wk_One Total_Doses_Shipped
# 0             Connecticut      309,900      309,900      309,900309,900
# 1                   Maine      118,600      118,600      118,600118,600
# 2           Massachusetts      596,900      596,900      596,900596,900
# 3           New Hampshire      118,700      118,700      118,700118,700
# 4            Rhode Island       93,300       93,300        93,30093,300
# ..                    ...          ...          ...                 ...
# 61                  Idaho      137,200      137,200      137,200137,200
# 62              Oregon***      353,300      353,300      353,300353,300
# 63          Washington***      626,800      626,800      626,800626,800
# 64  Federal Entities ****    1,747,700    1,776,300  1,776,3001,747,700
# 65                  Total          NaN          NaN                 NaN
#
# [66 rows x 4 columns]

# %%
# Total Shipment Amounts of Pfizer Vaccinations - State level

# Pfizer API
pfizer_url = "https://data.cdc.gov/resource/saz5-9hgg.json"

# query_pfizer_url = f"{pfizer_url}"

# print(query_url2)
pfizer_url

# vacc_response = requests.get(query_url2)
pf_vacc_json = requests.get(pfizer_url).json()

pf_vacc_json[0]

# Revised DataFrame
df_pf_vacc = pd.DataFrame(pf_vacc_json)

# Print
df_pf_vacc
# Out:
#              jurisdiction hhs_region first_doses_12_14  \
# 0             Connecticut   Region 1            31,200
# 1                   Maine   Region 1            12,675
# 2           Massachusetts   Region 1            59,475
# 3           New Hampshire   Region 1            12,675
# 4            Rhode Island   Region 1             9,750
# ..                    ...        ...               ...
# 61                  Idaho  Region 10            13,650
# 62              Oregon***  Region 10            35,100
# 63          Washington***  Region 10            62,400
# 64  Federal Entities ****        N/A            156000
# 65                  Total        NaN         2,980,575
#
#    second_doses_shipment_12_14 doses_allocated_week_of_12_21  \
# 0                       31,200                        22,425
# 1                       12,675                         8,775
# 2                       59,475                        42,900
# 3                       12,675                         8,775
# 4                        9,750                         6,825
# ..                         ...                           ...
# 61                      13,650                         9,750
# 62                      35,100                        25,350
# 63                      62,400                        44,850
# 64                      142350                       102,375
# 65                   2,943,525                     2,071,875
#
#    second_dose_shipment_12_17 doses_allocated_week_of_12_28  \
# 0                      22,425                        28,275
# 1                       8,775                        10,725
# 2                      42,900                        54,600
# 3                       8,775                        10,725
# 4                       6,825                         8,775
# ..                        ...                           ...
# 61                      9,750                        12,675
# 62                     25,350                        32,175
# 63                     44,850                        57,525
# 64                    102,375                       128,700
# 65                  2,071,875                     2,643,225
#
#    second_dose_shipment_12_28 doses_allocated_week_of_01_04  \
# 0                      28,275                        22,425
# 1                      10,725                         8,775
# 2                      54,600                        42,900
# 3                      10,725                         8,775
# 4                       8,775                         6,825
# ..                        ...                           ...
# 61                     12,675                         9,750
# 62                     32,175                        25,350
# 63                     57,525                        44,850
# 64                    128,700                       117,000
# 65                  2,643,225                     2,131,350
#
#    second_dose_shipment_01_04  ... doses_allocated_for_week_of_02_01  \
# 0                      22,425  ...                            23,400
# 1                       8,775  ...                             8,775
# 2                      42,900  ...                            43,875
# 3                       8,775  ...                             8,775
# 4                       6,825  ...                             6,825
# ..                        ...  ...                               ...
# 61                      9,750  ...                            10,725
# 62                     25,350  ...                            26,325
# 63                     44,850  ...                            45,825
# 64                    101,400  ...                           119,925
# 65                  2,092,350  ...                         2,204,475
#
#    second_dose_shipment_week_of_02_21 doses_allocated_for_week_of_02_08  \
# 0                              23,400                            23,400
# 1                               8,775                             8,775
# 2                              43,875                            43,875
# 3                               8,775                             8,775
# 4                               6,825                             6,825
# ..                                ...                               ...
# 61                             10,725                            10,725
# 62                             26,325                            26,325
# 63                             45,825                            46,800
# 64                            104,325                           105,300
# 65                          2,165,475                         2,149,875
#
#    second_dose_shipment_week_of_02_08 doses_allocated_week_of_02_15  \
# 0                              23,400                        23,400
# 1                               8,775                         8,775
# 2                              43,875                        43,875
# 3                               8,775                         8,775
# 4                               6,825                         6,825
# ..                                ...                           ...
# 61                             10,725                        10,725
# 62                             26,325                        26,325
# 63                             46,800                        46,800
# 64                            105,300                       105,300
# 65                          2,149,875                     2,149,875
#
#    second_dose_week_of_02_15 doses_allocated_week_of_02_22  \
# 0                     23,400                        36,270
# 1                      8,775                        14,040
# 2                     43,875                        70,200
# 3                      8,775                        14,040
# 4                      6,825                        11,700
# ..                       ...                           ...
# 61                    10,725                        16,380
# 62                    26,325                        42,120
# 63                    46,800                        73,710
# 64                   105,300                       166,140
# 65                 2,149,875                     3,400,020
#
#    second_dose_week_of_02_22 total_pfizer_allocation_first_dose_shipments  \
# 0                     36,270                                      280,020
# 1                     14,040                                      107,640
# 2                     70,200                                      532,350
# 3                     14,040                                      107,640
# 4                     11,700                                       84,825
# ..                       ...                                          ...
# 61                    16,380                                      125,580
# 62                    42,120                                      317,070
# 63                    73,710                                      573,885
# 64                   166,140                                    1,313,715
# 65                 3,400,020                                          NaN
#
#    total_allocation_pfizer_second_dose_shipments
# 0                                        280,020
# 1                                        107,640
# 2                                        532,350
# 3                                        107,640
# 4                                         84,825
# ..                                           ...
# 61                                       125,580
# 62                                       317,070
# 63                                       573,885
# 64                                     1,268,865
# 65                                           NaN
#
# [66 rows x 26 columns]

# %%
# Pfizer Vaccinations (cont.)

# Filter Out Necessary Data and Create New DataFrame
df_vac_pf = pd.DataFrame(df_pf_vacc, columns=['jurisdiction','total_pfizer_allocation_first_dose_shipments','total_allocation_pfizer_second_dose_shipments'])

# Print 
df_vac_pf

# Set Index Info to Have States as Row Data
df_vac_pf.set_index('jurisdiction')

# Add New Column and Print
df_vac_pf['Total_Doses_Shipped'] = True
df_vac_pf


# Rename Columns and Print
df_vac_pf.rename(columns={'jurisdiction':'Jurisdiction','total_pfizer_allocation_first_dose_shipments':'Total_Wk_One','total_allocation_pfizer_second_dose_shipments':'Total_Wk_Two'})
# Out:
#              Jurisdiction Total_Wk_One Total_Wk_Two  Total_Doses_Shipped
# 0             Connecticut      280,020      280,020                 True
# 1                   Maine      107,640      107,640                 True
# 2           Massachusetts      532,350      532,350                 True
# 3           New Hampshire      107,640      107,640                 True
# 4            Rhode Island       84,825       84,825                 True
# ..                    ...          ...          ...                  ...
# 61                  Idaho      125,580      125,580                 True
# 62              Oregon***      317,070      317,070                 True
# 63          Washington***      573,885      573,885                 True
# 64  Federal Entities ****    1,313,715    1,268,865                 True
# 65                  Total          NaN          NaN                 True
#
# [66 rows x 4 columns]

# %%
# Import Current Data for Vaccinations Administered per State
vac_admin_df = pd.read_csv(r'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/us_state_vaccinations.csv')

# Print
vac_admin_df

# Selecting Necessary Data
vac_admin_df = pd.DataFrame(vac_admin_df, columns=['date','location','total_vaccinations','total_distributed','people_vaccinated','share_doses_used'])

# Print
vac_admin_df
vac_admin_df.rename(columns = {'date':'Date','location':'Location','total_vaccinations':'Tot_Vaccs','total_distributed':'Tot_Dist','people_vaccinated':'People_Vaccd','share_doses_used':'Percent_Used'})
# Out:
#             Date Location  Tot_Vaccs  Tot_Dist  People_Vaccd  Percent_Used
# 0     2021-01-12  Alabama    78134.0  377025.0       70861.0         0.207
# 1     2021-01-13  Alabama    84040.0  378975.0       74792.0         0.222
# 2     2021-01-14  Alabama    92300.0  435350.0       80480.0         0.212
# 3     2021-01-15  Alabama   100567.0  444650.0       86956.0         0.226
# 4     2021-01-16  Alabama        NaN       NaN           NaN           NaN
# ...          ...      ...        ...       ...           ...           ...
# 2423  2021-02-13  Wyoming    89138.0  122000.0       65857.0         0.731
# 2424  2021-02-14  Wyoming    99099.0  122200.0       71653.0         0.811
# 2425  2021-02-15  Wyoming        NaN       NaN           NaN           NaN
# 2426  2021-02-16  Wyoming   100186.0  122200.0       72339.0         0.820
# 2427  2021-02-17  Wyoming   100186.0  127075.0       72339.0         0.788
#
# [2428 rows x 6 columns]

# %%
# Import Current Data for Vaccinations Administered by Manufacturer - United States
vac_man_admin_df = pd.read_csv(r'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations-by-manufacturer.csv')

# Print
vac_man_admin_df

# Selecting Necessary Data
vac_man_us_df = vac_man_admin_df[vac_man_admin_df.location=="United States"]

# Print
vac_man_us_df

# Rename Columns and Print
vac_man_us_df.rename(columns = {'location':'Location','date':'Date','vaccine':'Vaccine','total_vaccinations':'Total_Vaccinations'})
# Out:
#           Location        Date          Vaccine  Total_Vaccinations
# 699  United States  2021-01-12          Moderna           3835859.0
# 700  United States  2021-01-12  Pfizer/BioNTech           5488697.0
# 701  United States  2021-01-13          Moderna           4249795.0
# 702  United States  2021-01-13  Pfizer/BioNTech           6025872.0
# 703  United States  2021-01-15          Moderna           5122662.0
# ..             ...         ...              ...                 ...
# 756  United States  2021-02-13  Pfizer/BioNTech          26237417.0
# 757  United States  2021-02-14          Moderna          25505313.0
# 758  United States  2021-02-14  Pfizer/BioNTech          27271797.0
# 759  United States  2021-02-16          Moderna          26738383.0
# 760  United States  2021-02-16  Pfizer/BioNTech          28374410.0
#
# [62 rows x 4 columns]

# %%
# Build DataFrame for Current Data of Moderna Vaccines Administered - United States
vac_man_df = vac_man_us_df[vac_man_us_df.vaccine=="Moderna"]

# Print
vac_man_df
vac_man_df.head()

# Rename Columns and Print
vac_man_df.rename(columns = {'location':'Location','date':'Date','vaccine':'Vaccine','total_vaccinations':'Total_Vaccinations'})
# Out:
#           Location        Date  Vaccine  Total_Vaccinations
# 699  United States  2021-01-12  Moderna           3835859.0
# 701  United States  2021-01-13  Moderna           4249795.0
# 703  United States  2021-01-15  Moderna           5122662.0
# 705  United States  2021-01-19  Moderna           6828561.0
# 707  United States  2021-01-20  Moderna           7239750.0
# 709  United States  2021-01-21  Moderna           7724683.0
# 711  United States  2021-01-22  Moderna           8407909.0
# 713  United States  2021-01-23  Moderna           9061112.0
# 715  United States  2021-01-24  Moderna           9689497.0
# 717  United States  2021-01-25  Moderna          10084432.0
# 719  United States  2021-01-26  Moderna          10431466.0
# 721  United States  2021-01-27  Moderna          11001991.0
# 723  United States  2021-01-28  Moderna          11737592.0
# 725  United States  2021-01-29  Moderna          12619210.0
# 727  United States  2021-01-30  Moderna          13499942.0
# 729  United States  2021-01-31  Moderna          14246089.0
# 731  United States  2021-02-01  Moderna          14756609.0
# 733  United States  2021-02-02  Moderna          15006565.0
# 735  United States  2021-02-03  Moderna          15567188.0
# 737  United States  2021-02-04  Moderna          16260102.0
# 739  United States  2021-02-05  Moderna          17133644.0
# 741  United States  2021-02-06  Moderna          18336515.0
# 743  United States  2021-02-07  Moderna          19485089.0
# 745  United States  2021-02-08  Moderna          20066305.0
# 747  United States  2021-02-09  Moderna          20416765.0
# 749  United States  2021-02-10  Moderna          21189540.0
# 751  United States  2021-02-11  Moderna          22038088.0
# 753  United States  2021-02-12  Moderna          23111715.0
# 755  United States  2021-02-13  Moderna          24297615.0
# 757  United States  2021-02-14  Moderna          25505313.0
# 759  United States  2021-02-16  Moderna          26738383.0

# %%
# Compute Total Moderna Vaccinations - United States
vac_man_tot= vac_man_df['total_vaccinations'].sum()

# Print
vac_man_tot
# Out:
# 445689986.0

# %%
# Build DataFrame for Current Data of Pfizer Vaccines Administered - United States
vac_pf_df = vac_man_us_df[vac_man_us_df.vaccine=="Pfizer/BioNTech"]

# Print
vac_pf_df
vac_pf_df.head()

# Rename Columns and Print
vac_pf_df.rename(columns = {'location':'Location','date':'Date','vaccine':'Vaccine','total_vaccinations':'Total_Vaccinations'})
# Out:
#           Location        Date          Vaccine  Total_Vaccinations
# 700  United States  2021-01-12  Pfizer/BioNTech           5488697.0
# 702  United States  2021-01-13  Pfizer/BioNTech           6025872.0
# 704  United States  2021-01-15  Pfizer/BioNTech           7153268.0
# 706  United States  2021-01-19  Pfizer/BioNTech           8874811.0
# 708  United States  2021-01-20  Pfizer/BioNTech           9281063.0
# 710  United States  2021-01-21  Pfizer/BioNTech           9817027.0
# 712  United States  2021-01-22  Pfizer/BioNTech          10695066.0
# 714  United States  2021-01-23  Pfizer/BioNTech          11471457.0
# 716  United States  2021-01-24  Pfizer/BioNTech          12153536.0
# 718  United States  2021-01-25  Pfizer/BioNTech          12551999.0
# 720  United States  2021-01-26  Pfizer/BioNTech          13009981.0
# 722  United States  2021-01-27  Pfizer/BioNTech          13550835.0
# 724  United States  2021-01-28  Pfizer/BioNTech          14355980.0
# 726  United States  2021-01-29  Pfizer/BioNTech          15164858.0
# 728  United States  2021-01-30  Pfizer/BioNTech          15977015.0
# 730  United States  2021-01-31  Pfizer/BioNTech          16775916.0
# 732  United States  2021-02-01  Pfizer/BioNTech          17364398.0
# 734  United States  2021-02-02  Pfizer/BioNTech          17672866.0
# 736  United States  2021-02-03  Pfizer/BioNTech          18209204.0
# 738  United States  2021-02-04  Pfizer/BioNTech          18841309.0
# 740  United States  2021-02-05  Pfizer/BioNTech          19582865.0
# 742  United States  2021-02-06  Pfizer/BioNTech          20598212.0
# 744  United States  2021-02-07  Pfizer/BioNTech          21622193.0
# 746  United States  2021-02-08  Pfizer/BioNTech          22247484.0
# 748  United States  2021-02-09  Pfizer/BioNTech          22685406.0
# 750  United States  2021-02-10  Pfizer/BioNTech          23475749.0
# 752  United States  2021-02-11  Pfizer/BioNTech          24246868.0
# 754  United States  2021-02-12  Pfizer/BioNTech          25192628.0
# 756  United States  2021-02-13  Pfizer/BioNTech          26237417.0
# 758  United States  2021-02-14  Pfizer/BioNTech          27271797.0
# 760  United States  2021-02-16  Pfizer/BioNTech          28374410.0

# %%
vac_pf_tot= vac_pf_df['total_vaccinations'].sum()

vac_pf_tot
# Out:
# 515970187.0

# %%
# Import Current Data for Vaccinations Administered - Total Amounts of Both Manufacturers - United States
vac_man_admin_all_df = pd.read_csv(r'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/country_data/United%20States.csv')

# Print
vac_man_admin_all_df

vac_man_admin_all_df = pd.DataFrame(vac_man_admin_all_df, columns=['location','date','vaccine','total_vaccinations','people_vaccinated','people_fully_vaccinated'])

vac_man_admin_all_df.head()
# Out:
#         location        date                   vaccine  total_vaccinations  \
# 0  United States  2020-12-20           Pfizer/BioNTech              556208
# 1  United States  2020-12-21           Pfizer/BioNTech              614117
# 2  United States  2020-12-23  Moderna, Pfizer/BioNTech             1008025
# 3  United States  2020-12-26  Moderna, Pfizer/BioNTech             1944585
# 4  United States  2020-12-28  Moderna, Pfizer/BioNTech             2127143
#
#    people_vaccinated  people_fully_vaccinated
# 0           556208.0                      NaN
# 1           614117.0                      NaN
# 2          1008025.0                      NaN
# 3          1944585.0                      NaN
# 4          2127143.0                      NaN
